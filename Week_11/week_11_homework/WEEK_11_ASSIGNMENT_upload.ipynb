# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Week 11 Assignment</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# <strong><u>Due: Saturday, November 15 at 11:59PM</u></strong>
#
# <strong><u>Total points: 5 pts</u></strong>
#
# <strong><u>To turn in your assignment:</u></strong>
# <ol>
#     <li>Complete assignment and make sure you have all the outputs requested for the notebook</li>
#     <li>Go to your server's file directory and locate the <code>week_11_homework</code> directory containing all your outputs from this assignment including this notebook</li>
#     <li>Right click and select <strong>Download as an Archive</strong> to download the <code>week_11_homework</code> directory as a ZIP folder. Do not mix up with <strong>Download Current Folder as an Archive</strong></li>
#     <li>Upload your ZIP folder to your individual feedback Google Drive folder under <code>MCB201B</code></li>
# </ol>
#
# <strong><u>How this assignment will be graded:</u></strong>
#
# You will be graded on whether or not you have <u>all requested outputs and files</u> and if your output is correct. You will also be graded on if your code is expected to be able to run without errors. For those of you running code in Terminal or on your own computer, you will need to write out your input(s) into the empty code cell for this notebook. You don't need to run them here. If you used line breaks, make sure not to transfer over the <code>&gt;</code> symbol at the start of each new line. There can be more than one correct way to answer a question. If you find that you prefer to separate your answer for a single question into multiple code cells, feel free to do so.
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%px;"></hr>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns

# %% [markdown]
# <h2>Question 1</h2>

# %% [markdown]
# 1pt

# %% [markdown]
# Import your group's read counts <code>.txt</code> output from <code>htseq-count</code> into this notebook. Pull out the read counts statistics for each sample condition for the following into its own DataFrame.
# <ul>
#     <li>total reads counted</li>
#     <li>of the reads not counted:</li>
#     <ul>
#         <li>alignment not unique</li>
#         <li>not aligned</li>
#         <li>too low alignment quality</li>
#         <li>ambiguous</li>
#         <li>did not align to an exon</li>
#     </ul>
# </ul>
#
# Output the DataFrame as a stylized table into this notebook.

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%px;"></hr>

# %% [markdown]
# <h2>Question 2</h2>

# %% [markdown]
# 1pt

# %% [markdown]
# Filter your original DataFrame to obtain just the genes along with their associated counts. Export this DataFrame as a <code>.csv</code> file to be included with your assignment submission.

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%px;"></hr>

# %% [markdown]
# <h2>Question 3</h2>

# %% [markdown]
# 1pt

# %% [markdown]
# Create a stacked bar plot visualizing both sample conditions' count statistics as percents of their respective total using the data from question 1. Add axis labels and legend as appropriate, and output your stacked bar plot as a PDF to be included with your assignment submission.

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%px;"></hr>

# %% [markdown]
# <h2>Question 4</h2>

# %% [markdown]
# 2pt

# %% [markdown]
# Visualize each gene's read counts as a scatter plot with the x-axis as each gene's read count for the control condition and the y-axis as each gene's read count for the tazko condition. Highlight using different colors the points for TAZ (WWTR1) and YAP1, and add text annotations to label TAZ and YAP1 in your visualization. Add axis labels as appropriate, and output your scatterplot as a PDF to be included with your assignment submission.

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%px;"></hr>
