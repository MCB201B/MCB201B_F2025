# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Week 8 Assignment</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# <strong><u>Due: Saturday, October 25 at 11:59PM</u></strong>
#
# <strong><u>Total points: 5 pts</u></strong>
#
# <strong><u>To turn in your assignment:</u></strong>
# <ol>
#     <li>Complete assignment and make sure you have all the outputs requested for the notebook</li>
#     <li>Go to your server's file directory and locate the <code>week_8_homework</code> directory containing all your outputs from this assignment including this notebook</li>
#     <li>Right click and select <strong>Download as an Archive</strong> to download the <code>week_8_homework</code> directory as a ZIP folder. Do not mix up with <strong>Download Current Folder as an Archive</strong></li>
#     <li>Upload your ZIP folder to your individual feedback Google Drive folder under <code>MCB201B</code></li>
# </ol>
#
# <strong><u>How this assignment will be graded:</u></strong>
#
# You will be graded on whether or not you have <u>all requested outputs and files</u> and if your output is correct. You will also be graded on if your code is expected to be able to run without errors. For those of you running code in Terminal or on your own computer, you will need to write out your input(s) into the empty code cell for this notebook. You don't need to run them here. If you used line breaks, make sure not to transfer over the <code>&gt;</code> symbol at the start of each new line. There can be more than one correct way to answer a question. If you find that you prefer to separate your answer for a single question into multiple code cells, feel free to do so.
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%px;"></hr>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h2>Question 1</h2>

# %% [markdown]
# 1pt

# %% [markdown]
# This question is a housekeeping question. Now that we're done with our alignment files, we'll clear them from our servers so that we can help keep storage usage minimal. First run the bash command below using this notebook to output the size of your server, excluding the shared directories.

# %%
# %%bash
#
# cd ~
#
# du -sh --exclude=./shared --exclude=./_shared .

# %% [markdown]
# Go ahead and delete any SAM and BAM alignment files associated with our ChIP-seq module. We have the <code>macs2</code> outputs now, so we won't need to work with the SAM and BAM files. Once you've deleted those SAM and BAM files, run the code cell below:

# %%
# %%bash
#
# cd ~
#
# du -sh --exclude=./shared --exclude=./_shared --exclude=./homer .

# %% [markdown]
# And now run the two code cells below to see if you have any remaining SAMs and BAMs.

# %%
# %%bash
#
# cd ~
#
# find . -type f -name "*.sam"

# %%
# %%bash
#
# cd ~
#
# find . -type f -name "*.bam"

# %% [markdown]
# If you have remaining BAMs and SAMs, go ahead and delete them to save space. You can also download them from the Biology Hub if you'd like to keep them as a backup before deleting them from your server. Now do one final check by running the code cell below.

# %%
# %%bash
#
# cd ~
#
# find . -type f -name "*.sam"

# %%
# %%bash
#
# cd ~
#
# find . -type f -name "*.bam"

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%px;"></hr>

# %% [markdown]
# <h2>Question 2</h2>

# %% [markdown]
# 2pt

# %% [markdown]
# Using your called peaks from the full ChIP-seq dataset, plot the peak profiles of both replicates of TAZ with both peak profiles on the same plot. Add x-axis and y-axis labels as appropriate and a legend. Output your plot as a PDF file to be included in your assignment submission.
#
# Include below the code you used to obtain the data from HOMER.

# %%
#Copy over your command line inputs into this code cell. You don't need to run it here.

# %%
#You can add additional code cells as needed for your Python code to plot the peak profile.

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%px;"></hr>

# %% [markdown]
# <h2>Question 3</h2>

# %% [markdown]
# 2pt

# %% [markdown]
# Using your called peaks from the full ChIP-seq dataset, determine each peak's distance to the nearest TSS for both replicates of TAZ. Then plot a histogram with the following bins:
#
# <ul>
#     <li>0-1kb</li>
#     <li>1-10kb</li>
#     <li>10-100kb</li>
#     <li>100+ kb</li>
# </ul>
#
# Adjust opacity (alpha) as needed to be able to see the histograms of both replicates on the same plot. Output your plot as a PDF file to be included in your assignment submission.

# %%
#Copy over your command line inputs into this code cell. You don't need to run it here.

# %%
#You can add additional code cells as needed for your Python code to plot the histograms.

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%px;"></hr>
