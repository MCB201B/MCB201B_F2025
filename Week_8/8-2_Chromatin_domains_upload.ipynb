# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">8.2 Exploring chromatin domains</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# If we have time, we'll take a look at chromatin markers that signify an active enhancer region, specifically around our focused set of overlapping peaks. This will give us an idea of which of our peaks overlap with enhancers that have been marked as active based on the region's epigenetic signature.
#
# <strong>Learning objectives:</strong>
#
# <ul>
#     <li>Continue to practice using HOMER to analyze CHIP-seq data</li>
#     <li>Plot chromatin ChIP-seq data</li>
#     <li>Infer transcriptional activity based on epigenetic signatures</li>
#     <li>Plot TF read coverage with histone read coverage</li>
# </ul>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Analyze epigenetic signatures</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# I have a <code>histone</code> directory located within our shared <code>chip</code> directory, containing the bedGraph files from <a href="https://doi.org/10.1186/1471-2164-15-331" rel="noopener noreferrer"><u>Rhie et al 2014</u></a> (<a href="https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE49651" rel="noopener noreferrer" target="_blank"><u>GSE49651</u></a>), which Zanconato et al 2015 also used in their analyses. We'll be using their read coverage data to get an idea of the epigenetic signature around our peaks.
#
# This notebook will be on the independent side, where you'll make use of the commands we used in notebook 8-1 but applied now to chromatin coverage data. As you're analyzing the data, you'll want to think about what the epigenetic signatures are telling us about the activity of the enhancers that is associated with these set of peaks and what that means for TEAD+TAZ regulation of gene transcription.

# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Exercise set</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# <h2>Exercise #1: Obtain average coverage profile around our concordant peaks</h2>

# %% [markdown]
# Using the focused set of peaks that we identified in notebook 8-1, use HOMER to analyze the epigenetic signatures in a &plusmn;1kb region. You'll need to separately analyze each <code>.bedGraph</code> file in the <code>histone</code> subdirectory.

# %%
# %%bash

# %% [markdown]
# <h2>Exercise #2: Plot the profile for all three histone marks overlaid on a single plot</h2>

# %% [markdown]
# What does the average epigenetic signature tell us about how TEAD+TAZ is potentially regulating transcription of their target genes for these top peaks we're focusing on?

# %% [markdown]
# <h2>Exercise #3: Overlay our two TAZ replicate's plot profiles</h2>

# %% [markdown]
# Now let's get the plot profile for both TAZ replicates but just for the focused set of peaks and then overlay that on top of the histone coverage plot that we generated. So we can rerun our HOMER analysis, but using now our concordant peaks file instead of the full set of peaks for each replicate.

# %%
# %%bash

# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">References</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# <a href="https://bmcgenomics.biomedcentral.com/articles/10.1186/1471-2164-15-331" rel="noopener noreferrer"><u>Rhie et al 2014 BMC Genomics:</u></a> Nucleosome positioning and histone modifications define relationships between regulatory elements and nearby gene expression in breast epithelial cells
