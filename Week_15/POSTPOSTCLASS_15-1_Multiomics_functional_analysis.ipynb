# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">15.1 Multiomics and functional analysis</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# In notebook 13-1, we explored our transcriptome data at the level of each gene, and today, we'll take a look at our data with respect to groups of genes through a functional analysis of our differential expression results. While looking at the changes in expression of individual genes can provide insight into the gene-level impacts of experimental manipulations, we can also look for groups of genes that change together through functional analysis. This type of analysis can give us insight into broader biological changes that are occurring as a result of experimental manipulations, such as knocking down TAZ. So rather than asking about what is happening to a specific gene, we are instead asking about what biological processes, signaling pathways, or other functional groups are changing in our cells.
#
# Of particular interest to us is also how our transcriptome analysis intersects with our ChIP analysis. Recall that from our ChIP-seq analysis, we identified a set of reproducible peaks where TAZ-TEAD are likely to bind to DNA. Our analysis showed that TAZ-TEAD primarily bind to regions distant from the transcription start site (TSS) rather than the nearby promoter region, suggesting a longer range regulation of target gene expression through distant enhancers.
#
# In this notebook, we'll be taking a basic multiomics approach by integrating our two big data analyses together in order to identify overlapping sets of genes from our two analyses. This approach can give us insight into the regulation of TAZ target genes and potentially identify some direct targets of TAZ and determine how TAZ regulates their transcription. We'll then take a look to see what functional groups are directly affected by TAZ KO compared to the overall changes that we see when we look at the full transcriptomic profile.
#
# <strong>Learning objectives:</strong>
# <ul>
#     <li>Identify intersections between datasets</li>
#     <li>Explore databases for functional analysis</li>
#     <li>Review and perform an over-representation analysis</li>
#     <li>Review and perform gene set enrichment analysis (GSEA)</li>
# </ul>

# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Load in packages</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# To visualize intersections, we'll make use of a package called <code>BioVenn</code>, which was developed by Tim Hulsen (<a href="https://journals.sagepub.com/doi/10.3233/DS-210032" rel="noopener noreferrer"><u>Hulsen 2021</u></a>). It allows us to readily pull together our datasets and visualize their intersections as a Venn diagram. Another common way to visualize Venn diagrams is <code>matplotlib-venn</code>, which allows for a bit more customization, but won't simultaneously identify intersections.
#
# <a href="https://pypi.org/project/BioVenn/" rel="noopener noreferrer"><u>Documentation for <code>BioVenn</code> can be found here.</u></a>
#
# <a href="https://pypi.org/project/matplotlib-venn/" rel="noopener noreferrer"><u>Documentation for <code>matplotlib-venn</code> can be found here.</u></a>
#
# We'll be performing both the over-representation analysis and GSEA using Python, and to do this, we'll make use of a package called <code>GSEApy</code>, which was developed by Zhuoqing Fang, Xinyuan Liu, and Gary Peltz (<a href="https://academic.oup.com/bioinformatics/article/39/1/btac757/6847088" rel="noopener noreferrer"><u>Fang et al 2022</u></a>). It also allows us to directly pull into our notebook, a bunch of different databases all containing their own gene sets, which we can then use to identify functional groups that may be impacted when we knocked down TAZ.
#
# <a href="https://gseapy.readthedocs.io/en/latest/index.html" rel="noopener noreferrer"><u>Documentation for <code>GSEApy</code> can be found here.</u></a>

# %%
pip install BioVenn
# Out:
# Requirement already satisfied: BioVenn in /srv/conda/lib/python3.11/site-packages (1.1.3)
# Requirement already satisfied: biomart>=0.9.2 in /srv/conda/lib/python3.11/site-packages (from BioVenn) (0.9.2)
# Requirement already satisfied: matplotlib>=3.3.3 in /srv/conda/lib/python3.11/site-packages (from BioVenn) (3.10.1)
# Requirement already satisfied: numpy>=1.19.4 in /srv/conda/lib/python3.11/site-packages (from BioVenn) (1.23.5)
# Requirement already satisfied: requests>=2.2 in /srv/conda/lib/python3.11/site-packages (from biomart>=0.9.2->BioVenn) (2.32.3)
# Requirement already satisfied: contourpy>=1.0.1 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.3->BioVenn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.3->BioVenn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.3->BioVenn) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.3->BioVenn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.3->BioVenn) (24.2)
# Requirement already satisfied: pillow>=8 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.3->BioVenn) (9.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.3->BioVenn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=3.3.3->BioVenn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.3->BioVenn) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/lib/python3.11/site-packages (from requests>=2.2->biomart>=0.9.2->BioVenn) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.11/site-packages (from requests>=2.2->biomart>=0.9.2->BioVenn) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.11/site-packages (from requests>=2.2->biomart>=0.9.2->BioVenn) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.11/site-packages (from requests>=2.2->biomart>=0.9.2->BioVenn) (2025.8.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gseapy
# Out:
# Requirement already satisfied: gseapy in /srv/conda/lib/python3.11/site-packages (1.1.11)
# Requirement already satisfied: numpy>=1.13.0 in /srv/conda/lib/python3.11/site-packages (from gseapy) (1.23.5)
# Requirement already satisfied: scipy in /srv/conda/lib/python3.11/site-packages (from gseapy) (1.10.1)
# Requirement already satisfied: pandas in /srv/conda/lib/python3.11/site-packages (from gseapy) (1.5.3)
# Requirement already satisfied: matplotlib>=2.2 in /srv/conda/lib/python3.11/site-packages (from gseapy) (3.10.1)
# Requirement already satisfied: requests in /srv/conda/lib/python3.11/site-packages (from gseapy) (2.32.3)
# Requirement already satisfied: contourpy>=1.0.1 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=2.2->gseapy) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=2.2->gseapy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=2.2->gseapy) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=2.2->gseapy) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=2.2->gseapy) (24.2)
# Requirement already satisfied: pillow>=8 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=2.2->gseapy) (9.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=2.2->gseapy) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/lib/python3.11/site-packages (from matplotlib>=2.2->gseapy) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->gseapy) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/lib/python3.11/site-packages (from pandas->gseapy) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/lib/python3.11/site-packages (from requests->gseapy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.11/site-packages (from requests->gseapy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.11/site-packages (from requests->gseapy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.11/site-packages (from requests->gseapy) (2025.8.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import BioVenn as bv
import seaborn as sns
import scipy.stats as stats
import gseapy as gp
import os

# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Load in ChIP-seq and RNA-seq data</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# <h2>Load in RNA-seq data</h2>

# %% [markdown]
# Let's go ahead and load in our RNA-seq differential expression results that we got from <code>DESeq2</code>.

# %%
res = pd.read_csv('../Week_10/differential-expression-analysis/1M_results.csv')

# %% [markdown]
# Then now let's take a quick sanity check to make sure it imported properly.

# %%
res.head().style
# Out:
# <style type="text/css">
# </style>
# <table id="T_1e5f0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e5f0_level0_col0" class="col_heading level0 col0" >Unnamed: 0</th>
#       <th id="T_1e5f0_level0_col1" class="col_heading level0 col1" >baseMean</th>
#       <th id="T_1e5f0_level0_col2" class="col_heading level0 col2" >log2FoldChange</th>
#       <th id="T_1e5f0_level0_col3" class="col_heading level0 col3" >lfcSE</th>
#       <th id="T_1e5f0_level0_col4" class="col_heading level0 col4" >stat</th>
#       <th id="T_1e5f0_level0_col5" class="col_heading level0 col5" >pvalue</th>
#       <th id="T_1e5f0_level0_col6" class="col_heading level0 col6" >padj</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e5f0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1e5f0_row0_col0" class="data row0 col0" >A1BG-AS1</td>
#       <td id="T_1e5f0_row0_col1" class="data row0 col1" >1.717396</td>
#       <td id="T_1e5f0_row0_col2" class="data row0 col2" >1.579446</td>
#       <td id="T_1e5f0_row0_col3" class="data row0 col3" >0.747265</td>
#       <td id="T_1e5f0_row0_col4" class="data row0 col4" >2.113634</td>
#       <td id="T_1e5f0_row0_col5" class="data row0 col5" >0.034547</td>
#       <td id="T_1e5f0_row0_col6" class="data row0 col6" >0.105928</td>
#     </tr>
#     <tr>
#       <th id="T_1e5f0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1e5f0_row1_col0" class="data row1 col0" >A4GALT</td>
#       <td id="T_1e5f0_row1_col1" class="data row1 col1" >10.639844</td>
#       <td id="T_1e5f0_row1_col2" class="data row1 col2" >-0.064188</td>
#       <td id="T_1e5f0_row1_col3" class="data row1 col3" >0.276068</td>
#       <td id="T_1e5f0_row1_col4" class="data row1 col4" >-0.232508</td>
#       <td id="T_1e5f0_row1_col5" class="data row1 col5" >0.816143</td>
#       <td id="T_1e5f0_row1_col6" class="data row1 col6" >0.904300</td>
#     </tr>
#     <tr>
#       <th id="T_1e5f0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1e5f0_row2_col0" class="data row2 col0" >AAAS</td>
#       <td id="T_1e5f0_row2_col1" class="data row2 col1" >28.134083</td>
#       <td id="T_1e5f0_row2_col2" class="data row2 col2" >-0.029254</td>
#       <td id="T_1e5f0_row2_col3" class="data row2 col3" >0.173522</td>
#       <td id="T_1e5f0_row2_col4" class="data row2 col4" >-0.168591</td>
#       <td id="T_1e5f0_row2_col5" class="data row2 col5" >0.866118</td>
#       <td id="T_1e5f0_row2_col6" class="data row2 col6" >0.930518</td>
#     </tr>
#     <tr>
#       <th id="T_1e5f0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1e5f0_row3_col0" class="data row3 col0" >AACS</td>
#       <td id="T_1e5f0_row3_col1" class="data row3 col1" >28.101282</td>
#       <td id="T_1e5f0_row3_col2" class="data row3 col2" >-0.139976</td>
#       <td id="T_1e5f0_row3_col3" class="data row3 col3" >0.158908</td>
#       <td id="T_1e5f0_row3_col4" class="data row3 col4" >-0.880861</td>
#       <td id="T_1e5f0_row3_col5" class="data row3 col5" >0.378393</td>
#       <td id="T_1e5f0_row3_col6" class="data row3 col6" >0.577812</td>
#     </tr>
#     <tr>
#       <th id="T_1e5f0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1e5f0_row4_col0" class="data row4 col0" >AADAT</td>
#       <td id="T_1e5f0_row4_col1" class="data row4 col1" >3.955065</td>
#       <td id="T_1e5f0_row4_col2" class="data row4 col2" >0.101844</td>
#       <td id="T_1e5f0_row4_col3" class="data row4 col3" >0.421201</td>
#       <td id="T_1e5f0_row4_col4" class="data row4 col4" >0.241794</td>
#       <td id="T_1e5f0_row4_col5" class="data row4 col5" >0.808940</td>
#       <td id="T_1e5f0_row4_col6" class="data row4 col6" >0.901120</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We'll need to use the first column because it contains the gene names that we'll use to identify intersections with our ChIP-seq dataset, so let's go ahead and update the column header to <code>'gene'</code>.

# %%
res.rename(columns={res.columns[0] : 'gene'},
           inplace=True
          )

# %%
res.head().style
# Out:
# <style type="text/css">
# </style>
# <table id="T_070d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_070d1_level0_col0" class="col_heading level0 col0" >gene</th>
#       <th id="T_070d1_level0_col1" class="col_heading level0 col1" >baseMean</th>
#       <th id="T_070d1_level0_col2" class="col_heading level0 col2" >log2FoldChange</th>
#       <th id="T_070d1_level0_col3" class="col_heading level0 col3" >lfcSE</th>
#       <th id="T_070d1_level0_col4" class="col_heading level0 col4" >stat</th>
#       <th id="T_070d1_level0_col5" class="col_heading level0 col5" >pvalue</th>
#       <th id="T_070d1_level0_col6" class="col_heading level0 col6" >padj</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_070d1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_070d1_row0_col0" class="data row0 col0" >A1BG-AS1</td>
#       <td id="T_070d1_row0_col1" class="data row0 col1" >1.717396</td>
#       <td id="T_070d1_row0_col2" class="data row0 col2" >1.579446</td>
#       <td id="T_070d1_row0_col3" class="data row0 col3" >0.747265</td>
#       <td id="T_070d1_row0_col4" class="data row0 col4" >2.113634</td>
#       <td id="T_070d1_row0_col5" class="data row0 col5" >0.034547</td>
#       <td id="T_070d1_row0_col6" class="data row0 col6" >0.105928</td>
#     </tr>
#     <tr>
#       <th id="T_070d1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_070d1_row1_col0" class="data row1 col0" >A4GALT</td>
#       <td id="T_070d1_row1_col1" class="data row1 col1" >10.639844</td>
#       <td id="T_070d1_row1_col2" class="data row1 col2" >-0.064188</td>
#       <td id="T_070d1_row1_col3" class="data row1 col3" >0.276068</td>
#       <td id="T_070d1_row1_col4" class="data row1 col4" >-0.232508</td>
#       <td id="T_070d1_row1_col5" class="data row1 col5" >0.816143</td>
#       <td id="T_070d1_row1_col6" class="data row1 col6" >0.904300</td>
#     </tr>
#     <tr>
#       <th id="T_070d1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_070d1_row2_col0" class="data row2 col0" >AAAS</td>
#       <td id="T_070d1_row2_col1" class="data row2 col1" >28.134083</td>
#       <td id="T_070d1_row2_col2" class="data row2 col2" >-0.029254</td>
#       <td id="T_070d1_row2_col3" class="data row2 col3" >0.173522</td>
#       <td id="T_070d1_row2_col4" class="data row2 col4" >-0.168591</td>
#       <td id="T_070d1_row2_col5" class="data row2 col5" >0.866118</td>
#       <td id="T_070d1_row2_col6" class="data row2 col6" >0.930518</td>
#     </tr>
#     <tr>
#       <th id="T_070d1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_070d1_row3_col0" class="data row3 col0" >AACS</td>
#       <td id="T_070d1_row3_col1" class="data row3 col1" >28.101282</td>
#       <td id="T_070d1_row3_col2" class="data row3 col2" >-0.139976</td>
#       <td id="T_070d1_row3_col3" class="data row3 col3" >0.158908</td>
#       <td id="T_070d1_row3_col4" class="data row3 col4" >-0.880861</td>
#       <td id="T_070d1_row3_col5" class="data row3 col5" >0.378393</td>
#       <td id="T_070d1_row3_col6" class="data row3 col6" >0.577812</td>
#     </tr>
#     <tr>
#       <th id="T_070d1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_070d1_row4_col0" class="data row4 col0" >AADAT</td>
#       <td id="T_070d1_row4_col1" class="data row4 col1" >3.955065</td>
#       <td id="T_070d1_row4_col2" class="data row4 col2" >0.101844</td>
#       <td id="T_070d1_row4_col3" class="data row4 col3" >0.421201</td>
#       <td id="T_070d1_row4_col4" class="data row4 col4" >0.241794</td>
#       <td id="T_070d1_row4_col5" class="data row4 col5" >0.808940</td>
#       <td id="T_070d1_row4_col6" class="data row4 col6" >0.901120</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <h2>Load in ChIP-seq data</h2>

# %% [markdown]
# Now let's load in our ChIP-seq data. Recall that we can use HOMER to annotate peaks based on the nearest TSS to get an idea of what gene each peak may potentially be regulating. In this week's directory, there is a <code>data</code> subdirectory containing an annotated peaks file generated by HOMER for the full ChIP-seq dataset. For this notebook, we'll make use of the full set to be able to work with more peaks identified as significantly enriched when pulling down TAZ.
#
# First, let's go ahead and load in our annotated peaks.

# %%
peaks = pd.read_csv('./data/annotated-peaks-full-set.txt',
                    sep='\t',
                   )

#This dataset was obtained from our full set ChIP-seq analysis not the truncated one
#Which gives us (as you probably saw from your homework results) a lot more merged peaks to play with
#We can take the merged peaks from the top 2000 or so that are concordant (rather than top 500 like we did with our truncated data)
#That gives us a lot of peaks to play with and then we can use HOMER to annotate them based on the nearest TSS
#Recall from Dr. Ingolia's Week 15 lecture that annotating peaks based on nearest TSS is a common way to infer what gene is regulated by a ChIP-peak

# %% [markdown]
# Now let's perform a quick sanity check and take a look at the dataset.

# %%
peaks
#What is particularly important for us is the gene type and the gene name
# Out:
#      PeakID (cmd=annotatePeaks.pl ./top_concordant_peaks_full-set.narrowPeak hg19 -noann)  \
# 0                               Merged-chr19-39184227-2
# 1                               Merged-chr10-91038033-2
# 2                                Merged-chr2-65886199-2
# 3                               Merged-chr19-48991373-2
# 4                                Merged-chr6-50055081-2
# ...                                                 ...
# 1864                              Merged-chr17-855149-2
# 1865                            Merged-chr14-23398869-2
# 1866                             Merged-chr4-77532537-2
# 1867                             Merged-chr6-37210436-2
# 1868                            Merged-chr12-66173098-2
#
#         Chr     Start       End Strand  Peak Score  \
# 0     chr19  39184140  39184315      +         0.0
# 1     chr10  91037981  91038085      +         0.0
# 2      chr2  65886111  65886288      +         0.0
# 3     chr19  48991289  48991457      +         0.0
# 4      chr6  50055014  50055148      +         0.0
# ...     ...       ...       ...    ...         ...
# 1864  chr17    855097    855201      +         0.0
# 1865  chr14  23398813  23398925      +         0.0
# 1866   chr4  77532472  77532602      +         0.0
# 1867   chr6  37210351  37210521      +         0.0
# 1868  chr12  66173044  66173152      +         0.0
#
#                                 Focus Ratio/Region Size  Annotation  \
# 0     /home/jovyan/shared/course/mcb201b-shared/chip...         NaN
# 1     /home/jovyan/shared/course/mcb201b-shared/chip...         NaN
# 2     /home/jovyan/shared/course/mcb201b-shared/chip...         NaN
# 3     /home/jovyan/shared/course/mcb201b-shared/chip...         NaN
# 4     /home/jovyan/shared/course/mcb201b-shared/chip...         NaN
# ...                                                 ...         ...
# 1864  /home/jovyan/shared/course/mcb201b-shared/chip...         NaN
# 1865  /home/jovyan/shared/course/mcb201b-shared/chip...         NaN
# 1866  /home/jovyan/shared/course/mcb201b-shared/chip...         NaN
# 1867  /home/jovyan/shared/course/mcb201b-shared/chip...         NaN
# 1868  /home/jovyan/shared/course/mcb201b-shared/chip...         NaN
#
#       Detailed Annotation  Distance to TSS Nearest PromoterID    Entrez ID  \
# 0                     NaN            45938       NM_001322033         81.0
# 1                     NaN           -23770          NM_001547       3433.0
# 2                     NaN          -226466          NM_181784     200734.0
# 3                     NaN            18747          NM_004228       9266.0
# 4                     NaN           -37439       NM_001369057     245915.0
# ...                   ...              ...                ...          ...
# 1864                  NaN            27867          NM_022463      64359.0
# 1865                  NaN               51          NR_110002  101926933.0
# 1866                  NaN            35833          NR_039655  100616254.0
# 1867                  NaN            14939          NM_145316     221468.0
# 1868                  NaN           -45142       NM_001300918       8091.0
#
#       Nearest Unigene Nearest Refseq  Nearest Ensembl Gene Name  \
# 0                 NaN      NM_004924  ENSG00000130402     ACTN4
# 1                 NaN      NM_001547  ENSG00000119922     IFIT2
# 2                 NaN      NM_181784  ENSG00000198369    SPRED2
# 3                 NaN      NM_004228  ENSG00000105443     CYTH2
# 4                 NaN   NM_001037498  ENSG00000180872   DEFB112
# ...               ...            ...              ...       ...
# 1864              NaN      NM_022463  ENSG00000167693       NXN
# 1865              NaN      NR_110002  ENSG00000257285  PRMT5-DT
# 1866              NaN      NR_039655  ENSG00000283682  MIR548AH
# 1867              NaN      NM_145316  ENSG00000172738   TMEM217
# 1868              NaN      NM_003483  ENSG00000149948     HMGA2
#
#                                              Gene Alias  \
# 0                                  ACTININ-4|FSGS|FSGS1
# 1     G10P2|GARG-39|IFI-54|IFI-54K|IFI54|IFIT-2|ISG-...
# 2                                          NS14|Spred-2
# 3     ARNO|CTS18|CTS18.1|PSCD2|PSCD2L|SEC7L|Sec7p-L|...
# 4                                               DEFB-12
# ...                                                 ...
# 1864                                     NRX|RRS2|TRG-4
# 1865                                                  -
# 1866                                                  -
# 1867                                 C6orf128|dJ355M6.2
# 1868                 BABL|HMGI-C|HMGIC|LIPO|SRS5|STQTL9
#
#                                        Gene Description       Gene Type
# 0                                       actinin alpha 4  protein-coding
# 1     interferon induced protein with tetratricopept...  protein-coding
# 2              sprouty related EVH1 domain containing 2  protein-coding
# 3                                           cytohesin 2  protein-coding
# 4                                     defensin beta 112  protein-coding
# ...                                                 ...             ...
# 1864                                      nucleoredoxin  protein-coding
# 1865                         PRMT5 divergent transcript           ncRNA
# 1866                                     microRNA 548ah           ncRNA
# 1867                          transmembrane protein 217  protein-coding
# 1868                      high mobility group AT-hook 2  protein-coding
#
# [1869 rows x 19 columns]

# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Identify and visualize intersection between datasets</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# Now that we have both datasets loaded in, let's proceed with identifying their intersections.
#
# What we're interested in is the gene names, and recall that our library was based on RNA samples that were enriched for mRNA. So we're particularly interested in the gene names for protein-coding genes since that is what we're analyzing with our RNA-seq data.
#
# Let's go ahead and pull out the gene names from our datasets.

# %% [markdown]
# <h2>Pull out gene names for genes that are differentially expressed</h2>

# %% [markdown]
# We'll first pull out genes that are significantly differentially expressed based on our RNA-seq analysis p-adjusted values.

# %%
res
# Out:
#            gene    baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# 0      A1BG-AS1    1.717396        1.579446  0.747265  2.113634  0.034547
# 1        A4GALT   10.639844       -0.064188  0.276068 -0.232508  0.816143
# 2          AAAS   28.134083       -0.029254  0.173522 -0.168591  0.866118
# 3          AACS   28.101282       -0.139976  0.158908 -0.880861  0.378393
# 4         AADAT    3.955065        0.101844  0.421201  0.241794  0.808940
# ...         ...         ...             ...       ...       ...       ...
# 17301    ZYG11A    6.760829       -0.063447  0.361171 -0.175671  0.860552
# 17302    ZYG11B   30.511184        0.004179  0.170884  0.024453  0.980491
# 17303       ZYX  144.918149       -0.324147  0.088009 -3.683103  0.000230
# 17304     ZZEF1   28.852060        0.103463  0.219259  0.471875  0.637016
# 17305      ZZZ3   65.752887        0.074821  0.125279  0.597231  0.550353
#
#            padj
# 0      0.105928
# 1      0.904300
# 2      0.930518
# 3      0.577812
# 4      0.901120
# ...         ...
# 17301  0.926733
# 17302  0.994338
# 17303  0.001677
# 17304  0.789957
# 17305  0.725226
#
# [17306 rows x 7 columns]

# %%
#We can apply a filter for what we want to focus on, specifically we can pull out significant genes
#We can use these gene names to then find which ones are shared with our ChIP-seq dataset
de_genes = res.loc[(res['padj'] < 0.05), 'gene']

# %%
#Let's take a look to see what is pulled out
#These are just genes identified as significant from just RNA-seq differential expression analysis
#We haven't identified intersections yet
de_genes[0:10]
# Out:
# 11    AARS1
# 21    ABCA1
# 26    ABCA2
# 27    ABCA3
# 31    ABCA7
# 37    ABCB8
# 42    ABCC3
# 44    ABCC5
# 49    ABCD1
# 58    ABCG1
# Name: gene, dtype: object

# %% [markdown]
# <h2>Pull out gene names for protein-coding genes</h2>

# %% [markdown]
# You can see that the annotations identify the <code>'Gene Type'</code>, which we can use to pull out just the protein-coding genes.

# %%
#Our RNA-seq is on mRNA, so we're focusing on protein-coding genes
#So we can also pull those out from our ChIP peak annotation table to get our list of ChIP genes
chip_genes = peaks.loc[peaks['Gene Type'] == 'protein-coding', 'Gene Name']

# %%
chip_genes[0:10]
# Out:
# 0      ACTN4
# 1      IFIT2
# 2     SPRED2
# 3      CYTH2
# 4    DEFB112
# 5    CCDC115
# 6       SYBU
# 7    TMEM45A
# 8       MYH9
# 9      ILDR2
# Name: Gene Name, dtype: object

# %% [markdown]
# <h2>Generate an empty list</h2>

# %% [markdown]
# If we dig into the documentation for <code>BioVenn</code>, you can see that there is a quirk in terms of how the function is set up. It's built to identify and visualize intersections of three datasets, and since we're only interested in comparing our two datasets, we can get around this by feeding it an empty list, which will satisfy it's requirements.

# %%
the_void = []
#The draw_venn() function requires 3 lists, so we can just give it an empty one to satisfy its required parameters
#nothing will intersect with this so it's effectively ignored

# %% [markdown]
# <h2>Visualize intersections as a Venn diagram</h2>

# %% [markdown]
# With our lists of gene names from our datasets (and one empty one), we can generate a Venn diagram using <code>BioVenn</code>.

# %%
#Now we can draw our Venn diagram to visualize the intersection
#The draw_venn() function will output a visualization as well as a dictionary of results corresponding to different intersections
venn = bv.draw_venn(list_x=de_genes,                 #We give it our first list - our RNAseq hits
                    list_y=chip_genes,               #and then our second one - our ChIPseq hits
                    list_z=the_void,                 #and our empty list
                    title='MCB201B Multi-omics',     #update title
                    subtitle=None,                   #remove the default subtitle
                    xtitle='RNA-seq',                #update label for our list_x (rnaseq)
                    ytitle='Chip-seq',               #update the label for our list_y (chipseq)
                    x_c='#F5E4CC',                   #update color for list_x circle in Venn diagram
                    y_c='#FFD1DC',                   #update color for list_y circle in Venn diagram
                   )
# Out:
# x total: 3574
# y total: 1028
# z total: 0
# x only: 3255
# y only: 709
# z only: 0
# x-y total overlap: 319
# x-z total overlap: 0
# y-z total overlap: 0
# x-y only overlap: 319
# x-z only overlap: 0
# y-z only overlap: 0
# x-y-z overlap: 0

# %% [markdown]
# <h2>Identify the overlapping genes</h2>

# %% [markdown]
# Let's go ahead and identify the differentially expressed genes that also correspond to a peak based on our analyses.
#
# While the documentation is a bit limited, we can see from the paper <a href="https://journals.sagepub.com/doi/10.3233/DS-210032" rel="noopener noreferrer"><u>Hulsen 2021</u></a> that the returned objects for different set operations can be pulled out of our <code>venn</code> variable, and specifically we can pull out the intersection between <code>list_x</code> and <code>list_y</code> as <code>xy_only</code>.

# %%
#The output is a dictionary that we can then pull out what we're interested using their key
venn['xy_only'][0:10]
#Here we pull out the intersection between list_x and list_y, which is our rna-seq and our chip-seq datasets
# Out:
# ['ESRP2',
#  'TGFBI',
#  'MTMR1',
#  'IER5',
#  'PALLD',
#  'LAYN',
#  'HEG1',
#  'ZNF395',
#  'CRYBG2',
#  'SLC2A1']

# %% [markdown]
# We can also do it ourselves using set operators to identify the intersection.

# %%
type(de_genes)
# Out:
# pandas.core.series.Series

# %%
#We can use set operators to do the same thing that draw_venn() does when it generates the Venn diagram
list(set(de_genes) & set(chip_genes))[0:10]
#The extra list notation is just to pull out the first 10, so it's not outputting everything
#Recall from lecture that the intersection tells us that these differentially expressed genes are likely direct targets of TAZ
# Out:
# ['TGFBI',
#  'IER5',
#  'PALLD',
#  'LAYN',
#  'CRYBG2',
#  'SLC2A1',
#  'SERPINE1',
#  'JARID2',
#  'SHROOM3',
#  'FAM83A']

# %% [markdown]
# What can we infer about this set of overlapping genes in terms of how TAZ is regulating them?

# %% [markdown]
# <h2>Identify the differentially expressed genes without a peak</h2>

# %% [markdown]
# Let's go ahead and also pull out the differentially expressed genes that don't correspond to a ChIP-seq peak. In other words, we would be identifying the genes that are present from our RNA-seq analysis but not in our ChIP-seq annotation. We can pull these out from our <code>venn</code> object, or we can identify these genes using set operators.

# %%
#We can pull out the difference as well, specifically just our RNA-seq hits that DO NOT intersect with our ChIP peaks
venn['x_only'][0:10]
# Out:
# ['PARP1',
#  'NACC1',
#  'VPS9D1',
#  'ELF3',
#  'FN1',
#  'NCOA4',
#  'ALKBH8',
#  'RABGGTB',
#  'PHLDA2',
#  'NAGLU']

# %%
#We can also do the same with set operators to find the difference
list(set(de_genes) - set(chip_genes))[0:10]

#These genes are likely indirectly regulated by TAZ
#Since they don't intersect with a ChIP peak, it's possible that things directly regulated by TAZ
#or other secondary changes within the cell drive the changes in gene expression that we see with these genes
# Out:
# ['PARP1',
#  'NACC1',
#  'VPS9D1',
#  'ELF3',
#  'FN1',
#  'NCOA4',
#  'ALKBH8',
#  'RABGGTB',
#  'PHLDA2',
#  'RITA1']

# %% [markdown]
# How are these genes different than the overlapping set of genes in terms of how TAZ is regulating them?

# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Exercise: Compare expression changes between directly and indirectly regulated genes</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# For this exercise, take a look at the expression changes between genes directly regulated by TAZ and those that have their expression impacted based on more indirect regulation/effects.

# %% [markdown]
# <h2>1. Create DataFrames for overlapping and non-overlapping sets containing <code>DESeq2</code> results</h2>

# %% [markdown]
# For this part, you can set up two DataFrames, one for the overlapping set and the other for the non-overlapping set (RNA-seq only) with the <code>DESeq2</code> results pulled into them.

# %%
#We can then use the pd.Series.isin() function to pull out the information just for genes contained within the intersection
overlap = res.loc[res.gene.isin(venn['xy_only']), :]
#So this would just be information on genes that are directly regulated by TAZ

# %%
overlap.head().style
# Out:
# <style type="text/css">
# </style>
# <table id="T_5bf9e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5bf9e_level0_col0" class="col_heading level0 col0" >gene</th>
#       <th id="T_5bf9e_level0_col1" class="col_heading level0 col1" >baseMean</th>
#       <th id="T_5bf9e_level0_col2" class="col_heading level0 col2" >log2FoldChange</th>
#       <th id="T_5bf9e_level0_col3" class="col_heading level0 col3" >lfcSE</th>
#       <th id="T_5bf9e_level0_col4" class="col_heading level0 col4" >stat</th>
#       <th id="T_5bf9e_level0_col5" class="col_heading level0 col5" >pvalue</th>
#       <th id="T_5bf9e_level0_col6" class="col_heading level0 col6" >padj</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5bf9e_level0_row0" class="row_heading level0 row0" >84</th>
#       <td id="T_5bf9e_row0_col0" class="data row0 col0" >ABI3BP</td>
#       <td id="T_5bf9e_row0_col1" class="data row0 col1" >2.217591</td>
#       <td id="T_5bf9e_row0_col2" class="data row0 col2" >-3.911127</td>
#       <td id="T_5bf9e_row0_col3" class="data row0 col3" >0.806348</td>
#       <td id="T_5bf9e_row0_col4" class="data row0 col4" >-4.850422</td>
#       <td id="T_5bf9e_row0_col5" class="data row0 col5" >0.000001</td>
#       <td id="T_5bf9e_row0_col6" class="data row0 col6" >0.000015</td>
#     </tr>
#     <tr>
#       <th id="T_5bf9e_level0_row1" class="row_heading level0 row1" >97</th>
#       <td id="T_5bf9e_row1_col0" class="data row1 col0" >ABTB2</td>
#       <td id="T_5bf9e_row1_col1" class="data row1 col1" >24.241325</td>
#       <td id="T_5bf9e_row1_col2" class="data row1 col2" >0.442388</td>
#       <td id="T_5bf9e_row1_col3" class="data row1 col3" >0.171200</td>
#       <td id="T_5bf9e_row1_col4" class="data row1 col4" >2.584034</td>
#       <td id="T_5bf9e_row1_col5" class="data row1 col5" >0.009765</td>
#       <td id="T_5bf9e_row1_col6" class="data row1 col6" >0.039476</td>
#     </tr>
#     <tr>
#       <th id="T_5bf9e_level0_row2" class="row_heading level0 row2" >115</th>
#       <td id="T_5bf9e_row2_col0" class="data row2 col0" >ACAT2</td>
#       <td id="T_5bf9e_row2_col1" class="data row2 col1" >58.251661</td>
#       <td id="T_5bf9e_row2_col2" class="data row2 col2" >-0.310600</td>
#       <td id="T_5bf9e_row2_col3" class="data row2 col3" >0.113016</td>
#       <td id="T_5bf9e_row2_col4" class="data row2 col4" >-2.748280</td>
#       <td id="T_5bf9e_row2_col5" class="data row2 col5" >0.005991</td>
#       <td id="T_5bf9e_row2_col6" class="data row2 col6" >0.026466</td>
#     </tr>
#     <tr>
#       <th id="T_5bf9e_level0_row3" class="row_heading level0 row3" >173</th>
#       <td id="T_5bf9e_row3_col0" class="data row3 col0" >ACTN1</td>
#       <td id="T_5bf9e_row3_col1" class="data row3 col1" >527.742339</td>
#       <td id="T_5bf9e_row3_col2" class="data row3 col2" >-0.292663</td>
#       <td id="T_5bf9e_row3_col3" class="data row3 col3" >0.062124</td>
#       <td id="T_5bf9e_row3_col4" class="data row3 col4" >-4.710941</td>
#       <td id="T_5bf9e_row3_col5" class="data row3 col5" >0.000002</td>
#       <td id="T_5bf9e_row3_col6" class="data row3 col6" >0.000029</td>
#     </tr>
#     <tr>
#       <th id="T_5bf9e_level0_row4" class="row_heading level0 row4" >175</th>
#       <td id="T_5bf9e_row4_col0" class="data row4 col0" >ACTN4</td>
#       <td id="T_5bf9e_row4_col1" class="data row4 col1" >1001.076407</td>
#       <td id="T_5bf9e_row4_col2" class="data row4 col2" >-0.293635</td>
#       <td id="T_5bf9e_row4_col3" class="data row4 col3" >0.055564</td>
#       <td id="T_5bf9e_row4_col4" class="data row4 col4" >-5.284628</td>
#       <td id="T_5bf9e_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_5bf9e_row4_col6" class="data row4 col6" >0.000002</td>
#     </tr>
#   </tbody>
# </table>

# %%
#We can use the same setup to also pull those that are indirect targets
no_overlap = res.loc[res.gene.isin(venn['x_only']), :]

# %%
no_overlap.head().style
# Out:
# <style type="text/css">
# </style>
# <table id="T_70fb6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70fb6_level0_col0" class="col_heading level0 col0" >gene</th>
#       <th id="T_70fb6_level0_col1" class="col_heading level0 col1" >baseMean</th>
#       <th id="T_70fb6_level0_col2" class="col_heading level0 col2" >log2FoldChange</th>
#       <th id="T_70fb6_level0_col3" class="col_heading level0 col3" >lfcSE</th>
#       <th id="T_70fb6_level0_col4" class="col_heading level0 col4" >stat</th>
#       <th id="T_70fb6_level0_col5" class="col_heading level0 col5" >pvalue</th>
#       <th id="T_70fb6_level0_col6" class="col_heading level0 col6" >padj</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70fb6_level0_row0" class="row_heading level0 row0" >11</th>
#       <td id="T_70fb6_row0_col0" class="data row0 col0" >AARS1</td>
#       <td id="T_70fb6_row0_col1" class="data row0 col1" >75.605433</td>
#       <td id="T_70fb6_row0_col2" class="data row0 col2" >-0.433385</td>
#       <td id="T_70fb6_row0_col3" class="data row0 col3" >0.100656</td>
#       <td id="T_70fb6_row0_col4" class="data row0 col4" >-4.305609</td>
#       <td id="T_70fb6_row0_col5" class="data row0 col5" >0.000017</td>
#       <td id="T_70fb6_row0_col6" class="data row0 col6" >0.000164</td>
#     </tr>
#     <tr>
#       <th id="T_70fb6_level0_row1" class="row_heading level0 row1" >21</th>
#       <td id="T_70fb6_row1_col0" class="data row1 col0" >ABCA1</td>
#       <td id="T_70fb6_row1_col1" class="data row1 col1" >41.210361</td>
#       <td id="T_70fb6_row1_col2" class="data row1 col2" >-0.653427</td>
#       <td id="T_70fb6_row1_col3" class="data row1 col3" >0.163851</td>
#       <td id="T_70fb6_row1_col4" class="data row1 col4" >-3.987933</td>
#       <td id="T_70fb6_row1_col5" class="data row1 col5" >0.000067</td>
#       <td id="T_70fb6_row1_col6" class="data row1 col6" >0.000564</td>
#     </tr>
#     <tr>
#       <th id="T_70fb6_level0_row2" class="row_heading level0 row2" >26</th>
#       <td id="T_70fb6_row2_col0" class="data row2 col0" >ABCA2</td>
#       <td id="T_70fb6_row2_col1" class="data row2 col1" >65.941915</td>
#       <td id="T_70fb6_row2_col2" class="data row2 col2" >0.342784</td>
#       <td id="T_70fb6_row2_col3" class="data row2 col3" >0.119841</td>
#       <td id="T_70fb6_row2_col4" class="data row2 col4" >2.860329</td>
#       <td id="T_70fb6_row2_col5" class="data row2 col5" >0.004232</td>
#       <td id="T_70fb6_row2_col6" class="data row2 col6" >0.020035</td>
#     </tr>
#     <tr>
#       <th id="T_70fb6_level0_row3" class="row_heading level0 row3" >27</th>
#       <td id="T_70fb6_row3_col0" class="data row3 col0" >ABCA3</td>
#       <td id="T_70fb6_row3_col1" class="data row3 col1" >32.013130</td>
#       <td id="T_70fb6_row3_col2" class="data row3 col2" >0.697068</td>
#       <td id="T_70fb6_row3_col3" class="data row3 col3" >0.193700</td>
#       <td id="T_70fb6_row3_col4" class="data row3 col4" >3.598708</td>
#       <td id="T_70fb6_row3_col5" class="data row3 col5" >0.000320</td>
#       <td id="T_70fb6_row3_col6" class="data row3 col6" >0.002232</td>
#     </tr>
#     <tr>
#       <th id="T_70fb6_level0_row4" class="row_heading level0 row4" >31</th>
#       <td id="T_70fb6_row4_col0" class="data row4 col0" >ABCA7</td>
#       <td id="T_70fb6_row4_col1" class="data row4 col1" >10.881120</td>
#       <td id="T_70fb6_row4_col2" class="data row4 col2" >-0.842159</td>
#       <td id="T_70fb6_row4_col3" class="data row4 col3" >0.288254</td>
#       <td id="T_70fb6_row4_col4" class="data row4 col4" >-2.921590</td>
#       <td id="T_70fb6_row4_col5" class="data row4 col5" >0.003483</td>
#       <td id="T_70fb6_row4_col6" class="data row4 col6" >0.017020</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <h2>2. Visualize distribution of <code>'log2FoldChange'</code> for both sets</h2>

# %% [markdown]
# Once you have the <code>DESeq2</code> results corresponding to each set, visualize the distribution of the expression changes between the two to see if there may be differences in how the loss of TAZ affects their expression.

# %%
#Let's take a look at the distribution of the expression changes for direct vs indirect targets
#We can plot a histogram for the direct targets' log2FoldChange
sns.histplot(overlap.log2FoldChange,
             bins=np.arange(-10, 10, 0.25),
             stat='proportion',
             label='overlapping',
            )

#We can also do the same for the indirect targets' log2FoldChange
sns.histplot(no_overlap.log2FoldChange,
             bins=np.arange(-10, 10, 0.25),
             stat='proportion',
             label='non-overlapping',
            )

#We set stat='proportion' to more easily compare the distributions visually
# Out:
# <Axes: xlabel='log2FoldChange', ylabel='Proportion'>

# %% [markdown]
# <h2>3. Determine if there is a statistically significant difference in their distribution</h2>

# %% [markdown]
# See if you can set up a Mann-Whitney U-test to determine if there is a significant difference between their distributions.

# %%
#Can see maybe there is a difference in the distribution
#Let's check statistically if there is a difference
stats.mannwhitneyu(overlap.log2FoldChange,
                   no_overlap.log2FoldChange,
                  )

#We can see in this case that there is
# Out:
# MannwhitneyuResult(statistic=397436.0, pvalue=4.468576593091868e-12)

# %% [markdown]
# What does the distribution tell us about how TAZ loss impacts the genes that are directly regulated vs indirectly regulated?

# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Functional analysis of RNA-seq results</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# Here, we'll proceed with a functional analysis of our RNA-seq results, and then we'll also run the analysis on our set of genes identified as potentially regulated directly by TAZ.

# %% [markdown]
# <h2>Explore databases</h2>

# %% [markdown]
# Recall from Dr. Ingolia's lecture that there are a large number of different databases curated by different organizations and people. Each database will group genes a little differently depending on their own classification scheme, and so selecting a database can affect how you interpret your functional analysis. Some may allow you to gain insight into the regulation of different pathways and others may provide information on how biological processes are altered in your experimental manipulation.
#
# Let's briefly take some time to take a look at some databases to see how they organize their gene sets.

# %% [markdown]
# <h2>Pull in Molecular Signatures Database (MSigDB)</h2>

# %% [markdown]
# One of the major databases is the <a href="https://www.gsea-msigdb.org/gsea/msigdb" rel="noopener noreferrer"><u>Molecular Signatures Database (MSigDB)</u></a>, which contains annotated gene sets for functional analysis. MSigDB is a joint project between UC San Diego and the Broad Institute (<a href="https://www.pnas.org/doi/10.1073/pnas.0506580102" rel="noopener norferrer"><u>Subramanian, Tamayo et al 2005</u></a>, <a href="https://pmc.ncbi.nlm.nih.gov/articles/PMC4707969/" rel="noopener norferrer"><u>Liberzon et al 2015</u></a>) and funded by the National Cancer Institute's Informatics Technology for Cancer Research.
#
# <code>GSEApy</code> allows us to pull in information on the current <a href="https://data.broadinstitute.org/gsea-msigdb/msigdb/release/" rel="noopener noreferrer"><u>MSigDB database from the Broad Institute.</u></a>
#
# To do this, we'll make use of the <code>gp.Msigdb()</code> function from the GSEApy package.

# %%
#To better understand these parts, explore the Molecular Signatures DataBase (the first and last links in the above markdown cell)
msig = gp.Msigdb()
#Here, we're pulling in information of the directories for the MsSigDB database releases

# %%
#We can take a look at the object
msig
#Which isn't the most informative for us

# %% [markdown]
# We can then take a look to see what directories the server currently has:

# %%
#But we can pull out the information within the object
msig.list_dbver()
#We can see the directories containing the different MSigDB releases
#Can see that MSigDB contains curated gene sets for mice (Mus musculus (Mm)) and humans (Homo sapiens (Hs))
#To better understand, go into the releases for MSigDB using the link contained in the link for "MSigDB databse from the Broad Institute"
#You'll be able to manually navigate through the different files
#Information on the annotations like c5 or h are better explained in the link for "Molecular Signatures Database (MSigDB)" link
#h stands for Hallmark gene sets
#c5 is the gene ontology one
#Both are commonly used and other ones are also commonly used like KEGG
# Out:
#          Name     Last modified
# 0         6.0  2018-12-17 16:29
# 1         6.1  2018-12-17 16:29
# 2         6.2  2018-12-17 16:29
# 3         7.0  2020-01-27 04:43
# 4         7.1  2020-03-30 16:55
# 5         7.2  2020-09-18 23:33
# 6         7.3  2021-03-22 15:09
# 7         7.4  2021-04-02 14:38
# 8       7.5.1  2023-03-09 19:38
# 9         7.5  2022-01-13 01:00
# 10  2022.1.Hs  2023-03-09 19:37
# 11  2022.1.Mm  2023-03-09 19:37
# 12  2023.1.Hs  2023-08-19 15:08
# 13  2023.1.Mm  2023-08-19 15:09
# 14  2023.2.Hs  2023-10-21 01:29
# 15  2023.2.Mm  2023-10-20 08:32
# 16  2024.1.Hs  2024-09-03 14:38
# 17  2024.1.Mm  2024-09-03 14:38
# 18  2025.1.Hs  2025-06-08 14:03
# 19  2025.1.Mm  2025-06-08 14:03

# %% [markdown]
# To get the <code>gmt</code> file, we will make use of the function <code>msig.get_gmt()</code>, where <code>msig</code> is the <code>msigdb</code> object that we created earlier with the <code>Msigdb()</code> function.

# %%
#Here we'll pull in all the Hallmark gene sets contained within the 2025 release for humans
#Category specifies essentially what is the gmt file we want and dbver specifies the release version
hallmark_db = msig.get_gmt(category='h.all', dbver='2025.1.Hs')

# %%
#Can see that we get a dictionary
#The dictionary contains key:value pairs
#the keys are the different Hallmark gene sets like HALLMARK_ADIPOGENESIS
#the values are all the genes annotated to that specific grouping
#When we run our functional analysis, we'll be taking a look to see if there is enrichment within our results compared to what would be expected by chance
type(hallmark_db)
#The functional groupings then give us an idea of what biological process or moelcular function or signaling pathway etc
#is being changed following TAZ KO
#Which can form the basis for potential further questions to explore (like for your final project)
# Out:
# dict

# %% [markdown]
# <h2>Let's break down the code:</h2>

# %% [markdown]
# <code>hallmark_db</code>
#
# This is the variable that we will save our database. The database is imported into Python as a <code>dict</code> (dictionary) object, so it has <code>key:value</code> pairs, where the key is the category or group that a gene or genes belong to, and the value is the gene name.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>&equals;</code>
#
# Our assignment operator.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>msig.get_gmt()</code>
#
# This function allows us to pull in the database that we want to use for our functional analysis. The files are usually in a <a href="https://software.broadinstitute.org/cancer/software/gsea/wiki/index.php/Data_formats#GMT:_Gene_Matrix_Transposed_file_format_.28.2A.gmt.29" rel="noopener noreferrer"><u>.gmt (Gene Matrix Transposed) format</u></a>.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>category='h.all'</code>
#
# This is the database that we want to pull in, since if we take a look at the directory, it contains a bunch of different .gmt files. Here, we're pulling in the MSigDB Hallmark database.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>dbver='2025.1.Hs'</code>
#
# This is the database version that we're pulling in. As you saw when we took a look at the <code>msigdb</code> object, there were different versions of the MSigDB for both humans and mice, and the <code>dbver</code> parameter allows us to select which version we want to pull into our notebook.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>

# %% [markdown]
# Since the object is a dictionary, we can pull all the values associated with a specific key. In other words, pull all the genes associated with a specific MSigDB Hallmark category.

# %%
hallmark_db['HALLMARK_HEDGEHOG_SIGNALING'][0:10]
# Out:
# ['ACHE',
#  'ADGRG1',
#  'AMOT',
#  'CDK5R1',
#  'CDK6',
#  'CELSR1',
#  'CNTFR',
#  'CRMP1',
#  'DPYSL2',
#  'ETS2']

# %% [markdown]
# What you should see is a list of genes that have been categorized as being involved in adipogenesis by MSigDB. We can also take a look at the whole database by converting the dictionary to a DataFrame:

# %%
#This is just to let us more easily see all the Hallmark gene sets at once
#Keep in mind that gene sets can have different numbers of genes annotated to them
#So it's not required that every gene set has the same number of genes
#You can also see that a single gene can be annotated to more than one gene set as well
#Which isn't too suprising since we know that a gene can be involved in multiple things
pd.DataFrame.from_dict(hallmark_db, orient='index').T
# Out:
#     HALLMARK_ADIPOGENESIS HALLMARK_ALLOGRAFT_REJECTION  \
# 0                   ABCA1                        AARS1
# 1                   ABCB8                        ABCE1
# 2                   ACAA2                         ABI1
# 3                   ACADL                         ACHE
# 4                   ACADM                       ACVR2A
# ..                    ...                          ...
# 195                UQCR11                       UBE2D1
# 196                UQCRC1                        UBE2N
# 197                 UQCRQ                        WARS1
# 198                 VEGFB                          WAS
# 199                 YWHAG                        ZAP70
#
#     HALLMARK_ANDROGEN_RESPONSE HALLMARK_ANGIOGENESIS HALLMARK_APICAL_JUNCTION  \
# 0                        ABCC4                  APOH                    ACTA1
# 1                        ABHD2                   APP                     ACTB
# 2                        ACSL3                 CCND2                    ACTC1
# 3                        ACTN1                COL3A1                    ACTG1
# 4                      ADAMTS1                COL5A2                    ACTG2
# ..                         ...                   ...                      ...
# 195                       None                  None                      VWF
# 196                       None                  None                     WASL
# 197                       None                  None                     WNK4
# 198                       None                  None                    YWHAH
# 199                       None                  None                      ZYX
#
#     HALLMARK_APICAL_SURFACE HALLMARK_APOPTOSIS HALLMARK_BILE_ACID_METABOLISM  \
# 0                    ADAM10               ADD1                         ABCA1
# 1                   ADIPOR2              AIFM3                         ABCA2
# 2                   AFAP1L2               ANKH                         ABCA3
# 3                     AKAP7              ANXA1                         ABCA4
# 4                       APP                APP                         ABCA5
# ..                      ...                ...                           ...
# 195                    None               None                          None
# 196                    None               None                          None
# 197                    None               None                          None
# 198                    None               None                          None
# 199                    None               None                          None
#
#     HALLMARK_CHOLESTEROL_HOMEOSTASIS HALLMARK_COAGULATION  ...  \
# 0                              ABCA2                  A2M  ...
# 1                              ACAT2                ACOX2  ...
# 2                              ACSS2                ADAM9  ...
# 3                              ACTG1                  ANG  ...
# 4                               ADH4                ANXA1  ...
# ..                               ...                  ...  ...
# 195                             None                 None  ...
# 196                             None                 None  ...
# 197                             None                 None  ...
# 198                             None                 None  ...
# 199                             None                 None  ...
#
#     HALLMARK_PROTEIN_SECRETION HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY  \
# 0                        ABCA1                                    ABCC1
# 1                       ADAM10                                    ATOX1
# 2                       ANP32E                                      CAT
# 3                        AP1G1                                   CDKN2D
# 4                        AP2B1                                    EGLN2
# ..                         ...                                      ...
# 195                       None                                     None
# 196                       None                                     None
# 197                       None                                     None
# 198                       None                                     None
# 199                       None                                     None
#
#     HALLMARK_SPERMATOGENESIS HALLMARK_TGF_BETA_SIGNALING  \
# 0                        ACE                       ACVR1
# 1                      ACRBP                         APC
# 2                      ACRV1                      ARID4B
# 3                     ACTL7B                       BCAR3
# 4                      ADAD1                        BMP2
# ..                       ...                         ...
# 195                     None                        None
# 196                     None                        None
# 197                     None                        None
# 198                     None                        None
# 199                     None                        None
#
#     HALLMARK_TNFA_SIGNALING_VIA_NFKB HALLMARK_UNFOLDED_PROTEIN_RESPONSE  \
# 0                              ABCA1                           ALDH18A1
# 1                              ACKR3                            ARFGAP1
# 2                               AREG                               ASNS
# 3                               ATF3                               ATF3
# 4                             ATP2B1                               ATF4
# ..                               ...                                ...
# 195                            VEGFA                               None
# 196                             YRDC                               None
# 197                           ZBTB10                               None
# 198                          ZC3H12A                               None
# 199                            ZFP36                               None
#
#     HALLMARK_UV_RESPONSE_DN HALLMARK_UV_RESPONSE_UP  \
# 0                     ABCC1                   ABCB1
# 1                    ACVR2A                   ACAA1
# 2                      ADD3                    AGO2
# 3                    ADGRL2                   ALAS1
# 4                   ADORA2B                   ALDOA
# ..                      ...                     ...
# 195                    None                    None
# 196                    None                    None
# 197                    None                    None
# 198                    None                    None
# 199                    None                    None
#
#     HALLMARK_WNT_BETA_CATENIN_SIGNALING HALLMARK_XENOBIOTIC_METABOLISM
# 0                                ADAM17                          ABCC2
# 1                                 AXIN1                          ABCC3
# 2                                 AXIN2                          ABCD2
# 3                                 CCND2                          ABHD6
# 4                                CSNK1E                           ACO2
# ..                                  ...                            ...
# 195                                None                           UPB1
# 196                                None                           UPP1
# 197                                None                           VNN1
# 198                                None                            VTN
# 199                                None                            XDH
#
# [200 rows x 50 columns]

# %% [markdown]
# For this version of the MSigDB Hallmark human database, you can see that there are 50 different categories ranging from adipogenesis to xenobiotic metabolism with varying numbers of genes inside of them. <a href="https://www.gsea-msigdb.org/gsea/msigdb/human/genesets.jsp?collection=H" rel="noopener noreferrer"><u>We can also find more information on these gene sets by diving into the MSigDB page on their Hallmark database.</u></a>

# %% [markdown]
# <h2>Use GSEApy to pull Enrichr library of databases</h2>

# %% [markdown]
# GSEApy also functions as an Enrichr wrapper, meaning that it allows you to use the Enrichr web program through Python. <a href="https://maayanlab.cloud/Enrichr/" rel="noopener noreferrer"><u>Enrichr is developed and maintained by the Ma'ayan lab at the Icahn School of Medicine, Mount Sinai, Center for Bioinformatics</u></a> (<a href="https://bmcbioinformatics.biomedcentral.com/articles/10.1186/1471-2105-14-128" rel="noopener noreferrer"><u>Chen et al 2013</u></a>), and it's one of many web-based tools/programs that allow you to perform functional analyses, such as the ones we're doing in this lesson.
#
# To take a look at what human-specific databases we can work with for functional analysis, we can make use of the <code>gp.get_library_name()</code> function.

# %%
#This example is another way to pull in other databases too
#Here we'll pull from Enrichr - see the Enrichr link in the Markdown cell above
databases = gp.get_library_name(organism='Human')

# %% [markdown]
# Let's take a look at what we pulled into our notebook:

# %%
#Just outputing the first 10 databases that we pulled in from Enrichr
databases[0:10]
# Out:
# ['ARCHS4_Cell-lines',
#  'ARCHS4_IDG_Coexp',
#  'ARCHS4_Kinases_Coexp',
#  'ARCHS4_TFs_Coexp',
#  'ARCHS4_Tissues',
#  'Achilles_fitness_decrease',
#  'Achilles_fitness_increase',
#  'Aging_Perturbations_from_GEO_down',
#  'Aging_Perturbations_from_GEO_up',
#  'Allen_Brain_Atlas_10x_scRNA_2021']

# %% [markdown]
# You should see that we now have a long list of different human-specific databases that have categorized genes in a variety of different ways.
#
# Some commonly used ones that Dr. Ingolia mentioned in lecture are those databases from the <a href="https://geneontology.org/" rel="noopener noreferrer"><u>Gene Ontology (GO) resource</u></a>, the MSigDB, and the <a href="https://www.genome.jp/kegg/" rel="noopener noreferrer"><u>Kyoto Encyclopedia of Genes and Genomes (KEGG)</u></a>. Recall that GO is at the highest level of grouping, divided into three major categories: biological process, cell component, and molecular function, and you should be able to see in this list of databases, these three categories as their own database for functional analysis.
#
# Note that these are pulled from the Enrichr library, and that they might not always be the most up-to-date. Note the date for their repository of the MSigDB Hallmark database, <code>MSigDB_Hallmark_2020</code>, while we can directly download or pull the most up-to-date version directly from MSigDB.

# %% [markdown]
# <h2>Using databases</h2>

# %% [markdown]
# These databases often can be used through web or desktop programs that have been developed, and we'll explore some of them towards the end of this lesson if we have time.
#
# To use these databases via <code>GSEApy</code>, we can just pass the name or the variable for the gene set that we want to use for our functional analysis.

# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Load in and prepare data</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# Let's go ahead and load in our RNA-seq data that we'll use for this part of our notebook:

# %%
#Let's now go ahead and load in our data so we can play around with some functional analyses
#We'll be focusing on over-representation analysis and gene set enrichment analysis (GSEA)
#These two are fairly common approaches to look for enrichment of functional groups or processes etc
#We'll use normalized counts for GSEA and shrunken logfoldchange for over-representation analysis
norm_counts = pd.read_csv('../Week_10/differential-expression-analysis/1M_class_norm_counts.csv')
shrinklfc = pd.read_csv('../Week_10/differential-expression-analysis/1M_results_lfcShrink.csv')

# %% [markdown]
# Let's take a look at our imported data as a sanity check.

# %%
shrinklfc.head().style
# Out:
# <style type="text/css">
# </style>
# <table id="T_a4797">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4797_level0_col0" class="col_heading level0 col0" >Unnamed: 0</th>
#       <th id="T_a4797_level0_col1" class="col_heading level0 col1" >baseMean</th>
#       <th id="T_a4797_level0_col2" class="col_heading level0 col2" >log2FoldChange</th>
#       <th id="T_a4797_level0_col3" class="col_heading level0 col3" >lfcSE</th>
#       <th id="T_a4797_level0_col4" class="col_heading level0 col4" >pvalue</th>
#       <th id="T_a4797_level0_col5" class="col_heading level0 col5" >padj</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4797_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a4797_row0_col0" class="data row0 col0" >A1BG-AS1</td>
#       <td id="T_a4797_row0_col1" class="data row0 col1" >1.717396</td>
#       <td id="T_a4797_row0_col2" class="data row0 col2" >0.530432</td>
#       <td id="T_a4797_row0_col3" class="data row0 col3" >0.753164</td>
#       <td id="T_a4797_row0_col4" class="data row0 col4" >0.034547</td>
#       <td id="T_a4797_row0_col5" class="data row0 col5" >0.105928</td>
#     </tr>
#     <tr>
#       <th id="T_a4797_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a4797_row1_col0" class="data row1 col0" >A4GALT</td>
#       <td id="T_a4797_row1_col1" class="data row1 col1" >10.639844</td>
#       <td id="T_a4797_row1_col2" class="data row1 col2" >-0.039800</td>
#       <td id="T_a4797_row1_col3" class="data row1 col3" >0.218284</td>
#       <td id="T_a4797_row1_col4" class="data row1 col4" >0.816143</td>
#       <td id="T_a4797_row1_col5" class="data row1 col5" >0.904300</td>
#     </tr>
#     <tr>
#       <th id="T_a4797_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a4797_row2_col0" class="data row2 col0" >AAAS</td>
#       <td id="T_a4797_row2_col1" class="data row2 col1" >28.134083</td>
#       <td id="T_a4797_row2_col2" class="data row2 col2" >-0.023496</td>
#       <td id="T_a4797_row2_col3" class="data row2 col3" >0.155790</td>
#       <td id="T_a4797_row2_col4" class="data row2 col4" >0.866118</td>
#       <td id="T_a4797_row2_col5" class="data row2 col5" >0.930518</td>
#     </tr>
#     <tr>
#       <th id="T_a4797_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a4797_row3_col0" class="data row3 col0" >AACS</td>
#       <td id="T_a4797_row3_col1" class="data row3 col1" >28.101282</td>
#       <td id="T_a4797_row3_col2" class="data row3 col2" >-0.117385</td>
#       <td id="T_a4797_row3_col3" class="data row3 col3" >0.146797</td>
#       <td id="T_a4797_row3_col4" class="data row3 col4" >0.378393</td>
#       <td id="T_a4797_row3_col5" class="data row3 col5" >0.577812</td>
#     </tr>
#     <tr>
#       <th id="T_a4797_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a4797_row4_col0" class="data row4 col0" >AADAT</td>
#       <td id="T_a4797_row4_col1" class="data row4 col1" >3.955065</td>
#       <td id="T_a4797_row4_col2" class="data row4 col2" >0.042448</td>
#       <td id="T_a4797_row4_col3" class="data row4 col3" >0.272361</td>
#       <td id="T_a4797_row4_col4" class="data row4 col4" >0.808940</td>
#       <td id="T_a4797_row4_col5" class="data row4 col5" >0.901120</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Now let's quickly update the column header for the first row to make things a little easier.

# %%
norm_counts.rename(columns={norm_counts.columns[0] : 'gene'},
                   inplace=True
                  )

shrinklfc.rename(columns={shrinklfc.columns[0] : 'gene'},
                 inplace=True
                )

# %% [markdown]
# Then let's pull just the gene names for the significant hits from our differential expression analysis.

# %%
#We are the ones that decide what is "interesting" for our over-representation analysis
#This is where its a bit subjective and what you set for a threshold of "interesting" will dictate how you interpret your results
#For example, here we're pulling all significant hits that are 2-fold different from control (so both upreg and downreg)
sig_genes = shrinklfc.loc[(shrinklfc.padj < 0.05) & (shrinklfc.log2FoldChange.abs() >= 1), :]

#However, you can also consider only the signficantly upregulated genes as "interesting"
#Or just the significantly downregulated genes as "interesting"
#Or even just only those that are significantly and super highly upregulated based on some threshold like 10X greater or w/e

#In any case, you'll need to keep in mind how it then affects your interpretation of the enriched gene sets

# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Over-representation analysis</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# This type of functional analysis asks if there is an over-representation of sets of genes among the differentially expressed genes you identified through your RNA-seq analysis. The statistical test used by this type of analysis is a hypergeometric test which tells us if the level of enrichment we see is true or just due to random chance.
#
# Gene sets that are enriched would then suggest that the biological process, molecular function, or other functional group that they belong to is being broadly affected by the experimental manipulation that was done.

# %% [markdown]
# <h2>Deciding on background for analysis</h2>

# %% [markdown]
# Recall from Dr. Ingolia's lecture that an important thing to consider for your over-representation analysis is "What is the universe of genes that you are looking in?". In other words, what is the background set of genes that will form your reference point? While the human genome has ~25,000 genes, a typical cell will usually express maybe ~10,000 to ~12,000 genes. So you'll want to take into account the fact that your cells probably aren't going to be expressing all genes in the genome by limiting your "universe of genes" to the data that you have rather than all the genes in the genome.
#
# What that means for our experiment is that we'll generate a list of all expressed genes based on our RNA-seq data and that will be the background for our over-representation analysis.

# %%
#An important consideration is what the "background" enrichment level is since that is what will be used to determine if we do have enrichment
#So here, we'll use only the expressed genes that were also factored into our DESeq2 analysis
#Recall weird things that were omitted automatically by DESeq2 due to the presence of weird outliers
#Those were indicated by a padj of NA
#We can use pd.isna() to identify them and then the bitwise inversion ~ to pull just those that DO NOT have padj of NA
bg_genes = shrinklfc.loc[~pd.isna(shrinklfc.padj), 'gene'].to_list()

# %%
bg_genes[0:10]
# Out:
# ['A1BG-AS1',
#  'A4GALT',
#  'AAAS',
#  'AACS',
#  'AADAT',
#  'AAGAB',
#  'AAK1',
#  'AAMDC',
#  'AAMP',
#  'AAR2']

# %% [markdown]
# <h2>Run an over-representation analysis</h2>

# %% [markdown]
# <code>GSEApy</code> contains a couple of ways to run an over-representation analysis, either through Enrichr web program or within Python. We'll perform the hypergeometric test in Python using the function <code>gp.enrich()</code>. <a href="https://gseapy.readthedocs.io/en/latest/run.html#gseapy.enrich" rel="noopener noreferrer"><u>Documentation for <code>gp.enrich()</code> can be found here.</u></a>

# %%
#Now we can run our over-representation analysis
#To better understand, dig into the documentation for this function
#We feed it lists for our "interesting" genes and the background
#And we provide it with the dict of our Hallmark gene set
ora = gp.enrich(gene_list=sig_genes.gene.to_list(),
                gene_sets=hallmark_db,
                background=bg_genes,
                outdir=None,
               )

#You can also refer to detailed code breakdown below.

# %% [markdown]
# <h2>Let's break down the code:</h2>

# %% [markdown]
# <code>ora</code>
#
# Our variable that will hold the results of the over-representation analysis.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>&equals;</code>
#
# Assignment operator.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>gp.enrich()</code>
#
# We're calling up this function to perform an over-representation analysis.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>gene_list=sig_genes.gene.to_list()</code>
#
# Here, we pass to the function our list of significant genes as a list that we pulled out of our <code>sig_genes</code> DataFrame.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>gene_sets=hallmark_db</code>
#
# This is the database that we want it to use when performing the functional analysis.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>background=bg_genes</code>
#
# Here, we provide the list of background genes. In our case, we pulled all the expressed genes from our RNA-seq analysis. Recall that we filtered out genes that weren't expressed (mean == 0) prior to performing our differential expression analysis. So all the output genes showed some level of expression in our cells.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>outdir=None</code>
#
# We specify that we don't want the function to output the results of the analysis to a file yet.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>

# %% [markdown]
# Now let's take a look at our output object.

# %%
ora
#The object itself is not super informative, so we'll have to pull out our results as attributes

# %% [markdown]
# You can see that the results are stored in an Enrichr object, and if we dig into <a href="https://gseapy.readthedocs.io/en/latest/run.html#gseapy.enrich" rel="noopener noreferrer"><u>the documentation</u></a>, we find that there are two ways to pull out the results. We can either pull it out using the <code>res2d</code> attribute or <code>results</code> attribute. The documentation notes that <code>res2d</code> will pull the most recent query while <code>results</code> will pull all queries.
#
# Let's pull our most recent query:

# %%
#We can pull out using ora.res2d
#Here we also simultaneously sort by the Adjusted P-value and output a stylized table
ora.res2d.sort_values(by='Adjusted P-value').style
#We'll then get an output that is sorted with most significant enrichment up at the top
# Out:
# <style type="text/css">
# </style>
# <table id="T_0b512">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b512_level0_col0" class="col_heading level0 col0" >Gene_set</th>
#       <th id="T_0b512_level0_col1" class="col_heading level0 col1" >Term</th>
#       <th id="T_0b512_level0_col2" class="col_heading level0 col2" >Overlap</th>
#       <th id="T_0b512_level0_col3" class="col_heading level0 col3" >P-value</th>
#       <th id="T_0b512_level0_col4" class="col_heading level0 col4" >Adjusted P-value</th>
#       <th id="T_0b512_level0_col5" class="col_heading level0 col5" >Odds Ratio</th>
#       <th id="T_0b512_level0_col6" class="col_heading level0 col6" >Combined Score</th>
#       <th id="T_0b512_level0_col7" class="col_heading level0 col7" >Genes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b512_level0_row0" class="row_heading level0 row0" >13</th>
#       <td id="T_0b512_row0_col0" class="data row0 col0" >gs_ind_0</td>
#       <td id="T_0b512_row0_col1" class="data row0 col1" >HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION</td>
#       <td id="T_0b512_row0_col2" class="data row0 col2" >32/157</td>
#       <td id="T_0b512_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_0b512_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_0b512_row0_col5" class="data row0 col5" >4.132167</td>
#       <td id="T_0b512_row0_col6" class="data row0 col6" >85.615963</td>
#       <td id="T_0b512_row0_col7" class="data row0 col7" >FSTL1;SERPINE2;PLAUR;OXTR;MATN2;ACTA2;THBS2;ITGA2;MEST;NNMT;ITGB3;COL12A1;ABI3BP;DKK1;PMEPA1;COL1A2;FZD8;CXCL1;TNC;CDH11;GJA1;THBS1;TIMP3;INHBA;SAT1;COL6A2;PDGFRB;FLNA;WNT5A;MYLK;VCAM1;ADAM12</td>
#     </tr>
#     <tr>
#       <th id="T_0b512_level0_row1" class="row_heading level0 row1" >14</th>
#       <td id="T_0b512_row1_col0" class="data row1 col0" >gs_ind_0</td>
#       <td id="T_0b512_row1_col1" class="data row1 col1" >HALLMARK_ESTROGEN_RESPONSE_EARLY</td>
#       <td id="T_0b512_row1_col2" class="data row1 col2" >30/162</td>
#       <td id="T_0b512_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_0b512_row1_col4" class="data row1 col4" >0.000001</td>
#       <td id="T_0b512_row1_col5" class="data row1 col5" >3.661751</td>
#       <td id="T_0b512_row1_col6" class="data row1 col6" >62.946727</td>
#       <td id="T_0b512_row1_col7" class="data row1 col7" >KRT18;CALCR;ESRP2;ELF3;KAZN;SCNN1A;TIAM1;INHBB;SLC2A1;PTGES;RAB17;RETREG1;DHCR7;SLC1A1;CLIC3;RPS6KA2;GJA1;PAPSS2;SYT12;KRT19;DHRS3;TPD52L1;KRT8;UGCG;MAPT;CELSR1;FHL2;MUC1;CLDN7;CALB2</td>
#     </tr>
#     <tr>
#       <th id="T_0b512_level0_row2" class="row_heading level0 row2" >28</th>
#       <td id="T_0b512_row2_col0" class="data row2 col0" >gs_ind_0</td>
#       <td id="T_0b512_row2_col1" class="data row2 col1" >HALLMARK_KRAS_SIGNALING_UP</td>
#       <td id="T_0b512_row2_col2" class="data row2 col2" >23/132</td>
#       <td id="T_0b512_row2_col3" class="data row2 col3" >0.000004</td>
#       <td id="T_0b512_row2_col4" class="data row2 col4" >0.000064</td>
#       <td id="T_0b512_row2_col5" class="data row2 col5" >3.390333</td>
#       <td id="T_0b512_row2_col6" class="data row2 col6" >42.145458</td>
#       <td id="T_0b512_row2_col7" class="data row2 col7" >CFH;ITGB2;GALNT3;SATB1;PLAUR;TNFRSF1B;ITGA2;EMP1;KCNN4;ANGPTL4;NGF;INHBA;CMKLR1;CAB39L;ETV1;TSPAN13;GPRC5B;LCP1;PLEK2;SERPINA3;ADAM8;ST6GAL1;GFPT2</td>
#     </tr>
#     <tr>
#       <th id="T_0b512_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_0b512_row3_col0" class="data row3 col0" >gs_ind_0</td>
#       <td id="T_0b512_row3_col1" class="data row3 col1" >HALLMARK_APICAL_SURFACE</td>
#       <td id="T_0b512_row3_col2" class="data row3 col2" >9/27</td>
#       <td id="T_0b512_row3_col3" class="data row3 col3" >0.000018</td>
#       <td id="T_0b512_row3_col4" class="data row3 col4" >0.000186</td>
#       <td id="T_0b512_row3_col5" class="data row3 col5" >8.030370</td>
#       <td id="T_0b512_row3_col6" class="data row3 col6" >87.567233</td>
#       <td id="T_0b512_row3_col7" class="data row3 col7" >MDGA1;AFAP1L2;PCSK9;AKAP7;CX3CL1;GATA3;PLAUR;SRPX;ATP8B1</td>
#     </tr>
#     <tr>
#       <th id="T_0b512_level0_row4" class="row_heading level0 row4" >24</th>
#       <td id="T_0b512_row4_col0" class="data row4 col0" >gs_ind_0</td>
#       <td id="T_0b512_row4_col1" class="data row4 col1" >HALLMARK_INFLAMMATORY_RESPONSE</td>
#       <td id="T_0b512_row4_col2" class="data row4 col2" >22/135</td>
#       <td id="T_0b512_row4_col3" class="data row4 col3" >0.000019</td>
#       <td id="T_0b512_row4_col4" class="data row4 col4" >0.000186</td>
#       <td id="T_0b512_row4_col5" class="data row4 col5" >3.126780</td>
#       <td id="T_0b512_row4_col6" class="data row4 col6" >33.928454</td>
#       <td id="T_0b512_row4_col7" class="data row4 col7" >LAMP3;IL18;RNF144B;BST2;PLAUR;TNFSF15;HAS2;TNFSF10;TNFRSF1B;ICAM1;ITGB3;NAMPT;ICOSLG;ADM;SLC4A4;ACVR2A;F3;CX3CL1;INHBA;CMKLR1;EDN1;CD14</td>
#     </tr>
#     <tr>
#       <th id="T_0b512_level0_row5" class="row_heading level0 row5" >26</th>
#       <td id="T_0b512_row5_col0" class="data row5 col0" >gs_ind_0</td>
#       <td id="T_0b512_row5_col1" class="data row5 col1" >HALLMARK_INTERFERON_GAMMA_RESPONSE</td>
#       <td id="T_0b512_row5_col2" class="data row5 col2" >24/166</td>
#       <td id="T_0b512_row5_col3" class="data row5 col3" >0.000062</td>
#       <td id="T_0b512_row5_col4" class="data row5 col4" >0.000428</td>
#       <td id="T_0b512_row5_col5" class="data row5 col5" >2.712373</td>
#       <td id="T_0b512_row5_col6" class="data row5 col6" >26.260184</td>
#       <td id="T_0b512_row5_col7" class="data row5 col7" >CFH;BST2;IFIH1;IFIT2;IFI27;TNFSF10;HERC6;ICAM1;NAMPT;OAS2;ISG15;OASL;RSAD2;ST8SIA4;IFI44;IFIT3;CMKLR1;IFIT1;HLA-A;TNFAIP2;SLAMF7;DDX60;GBP4;VCAM1</td>
#     </tr>
#     <tr>
#       <th id="T_0b512_level0_row6" class="row_heading level0 row6" >15</th>
#       <td id="T_0b512_row6_col0" class="data row6 col0" >gs_ind_0</td>
#       <td id="T_0b512_row6_col1" class="data row6 col1" >HALLMARK_ESTROGEN_RESPONSE_LATE</td>
#       <td id="T_0b512_row6_col2" class="data row6 col2" >23/155</td>
#       <td id="T_0b512_row6_col3" class="data row6 col3" >0.000059</td>
#       <td id="T_0b512_row6_col4" class="data row6 col4" >0.000428</td>
#       <td id="T_0b512_row6_col5" class="data row6 col5" >2.796739</td>
#       <td id="T_0b512_row6_col6" class="data row6 col6" >27.255656</td>
#       <td id="T_0b512_row6_col7" class="data row6 col7" >CALCR;SCNN1A;GPER1;PERP;TIAM1;MEST;PTGES;DHCR7;CLIC3;RPS6KA2;LLGL2;CKB;PAPSS2;KRT19;TPD52L1;CDH1;MAPT;CDC20;TSPAN13;SERPINA3;TRIM29;AGR2;SERPINA1</td>
#     </tr>
#     <tr>
#       <th id="T_0b512_level0_row7" class="row_heading level0 row7" >19</th>
#       <td id="T_0b512_row7_col0" class="data row7 col0" >gs_ind_0</td>
#       <td id="T_0b512_row7_col1" class="data row7 col1" >HALLMARK_HEDGEHOG_SIGNALING</td>
#       <td id="T_0b512_row7_col2" class="data row7 col2" >8/27</td>
#       <td id="T_0b512_row7_col3" class="data row7 col3" >0.000139</td>
#       <td id="T_0b512_row7_col4" class="data row7 col4" >0.000834</td>
#       <td id="T_0b512_row7_col5" class="data row7 col5" >6.807732</td>
#       <td id="T_0b512_row7_col6" class="data row7 col6" >60.458321</td>
#       <td id="T_0b512_row7_col7" class="data row7 col7" >NRP2;AMOT;ETS2;SHH;CELSR1;VLDLR;NRCAM;ADGRG1</td>
#     </tr>
#     <tr>
#       <th id="T_0b512_level0_row8" class="row_heading level0 row8" >42</th>
#       <td id="T_0b512_row8_col0" class="data row8 col0" >gs_ind_0</td>
#       <td id="T_0b512_row8_col1" class="data row8 col1" >HALLMARK_TNFA_SIGNALING_VIA_NFKB</td>
#       <td id="T_0b512_row8_col2" class="data row8 col2" >23/180</td>
#       <td id="T_0b512_row8_col3" class="data row8 col3" >0.000556</td>
#       <td id="T_0b512_row8_col4" class="data row8 col4" >0.002966</td>
#       <td id="T_0b512_row8_col5" class="data row8 col5" >2.348164</td>
#       <td id="T_0b512_row8_col6" class="data row8 col6" >17.598221</td>
#       <td id="T_0b512_row8_col7" class="data row8 col7" >IL18;PLPP3;PLAUR;IFIH1;IFIT2;PLK2;KYNU;ICAM1;NAMPT;PMEPA1;ICOSLG;CXCL1;TNC;

# %% [markdown]
# We can also sort by the significance when looking at our output results table.

# %%
#Refer to above code cell since we did it simultaneously

# %% [markdown]
# We can also update the values in the <code>Gene_set</code> column.

# %%
ora.res2d.replace(to_replace={'gs_ind_0' : 'MSigDB Hallmark'},
                  inplace=True
                 )

# %% [markdown]
# Let's check how it updated:

# %%
ora.res2d.style

#There is a detailed explanation of each column in the Markdown cell below
#Pay particular attention to the confusing columns: Odds Ratio and the Combined Score
#These are less self-explanatory, but the Enrichr webpage also provides an explanation that I elaborate on below with a figure to help visualize
# Out:
# <style type="text/css">
# </style>
# <table id="T_dbb79">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dbb79_level0_col0" class="col_heading level0 col0" >Gene_set</th>
#       <th id="T_dbb79_level0_col1" class="col_heading level0 col1" >Term</th>
#       <th id="T_dbb79_level0_col2" class="col_heading level0 col2" >Overlap</th>
#       <th id="T_dbb79_level0_col3" class="col_heading level0 col3" >P-value</th>
#       <th id="T_dbb79_level0_col4" class="col_heading level0 col4" >Adjusted P-value</th>
#       <th id="T_dbb79_level0_col5" class="col_heading level0 col5" >Odds Ratio</th>
#       <th id="T_dbb79_level0_col6" class="col_heading level0 col6" >Combined Score</th>
#       <th id="T_dbb79_level0_col7" class="col_heading level0 col7" >Genes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbb79_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dbb79_row0_col0" class="data row0 col0" >MSigDB Hallmark</td>
#       <td id="T_dbb79_row0_col1" class="data row0 col1" >HALLMARK_ADIPOGENESIS</td>
#       <td id="T_dbb79_row0_col2" class="data row0 col2" >9/180</td>
#       <td id="T_dbb79_row0_col3" class="data row0 col3" >0.769974</td>
#       <td id="T_dbb79_row0_col4" class="data row0 col4" >0.972599</td>
#       <td id="T_dbb79_row0_col5" class="data row0 col5" >0.855870</td>
#       <td id="T_dbb79_row0_col6" class="data row0 col6" >0.223723</td>
#       <td id="T_dbb79_row0_col7" class="data row0 col7" >IDH3G;ANGPTL4;UCP2;FZD4;MYLK;PHYH;LAMA4;DHCR7;MGLL</td>
#     </tr>
#     <tr>
#       <th id="T_dbb79_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dbb79_row1_col0" class="data row1 col0" >MSigDB Hallmark</td>
#       <td id="T_dbb79_row1_col1" class="data row1 col1" >HALLMARK_ALLOGRAFT_REJECTION</td>
#       <td id="T_dbb79_row1_col2" class="data row1 col2" >16/109</td>
#       <td id="T_dbb79_row1_col3" class="data row1 col3" >0.000850</td>
#       <td id="T_dbb79_row1_col4" class="data row1 col4" >0.004079</td>
#       <td id="T_dbb79_row1_col5" class="data row1 col5" >2.767177</td>
#       <td id="T_dbb79_row1_col6" class="data row1 col6" >19.565548</td>
#       <td id="T_dbb79_row1_col7" class="data row1 col7" >ELF4;FLNA;TLR6;ITGB2;ACVR2A;IL18;SRGN;IL11;RPL39;INHBA;ST8SIA4;ICOSLG;INHBB;TGFB2;HLA-A;ICAM1</td>
#     </tr>
#     <tr>
#       <th id="T_dbb79_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dbb79_row2_col0" class="data row2 col0" >MSigDB Hallmark</td>
#       <td id="T_dbb79_row2_col1" class="data row2 col1" >HALLMARK_ANDROGEN_RESPONSE</td>
#       <td id="T_dbb79_row2_col2" class="data row2 col2" >11/90</td>
#       <td id="T_dbb79_row2_col3" class="data row2 col3" >0.019859</td>
#       <td id="T_dbb79_row2_col4" class="data row2 col4" >0.050171</td>
#       <td id="T_dbb79_row2_col5" class="data row2 col5" >2.256835</td>
#       <td id="T_dbb79_row2_col6" class="data row2 col6" >8.844727</td>
#       <td id="T_dbb79_row2_col7" class="data row2 col7" >SAT1;DHCR24;PMEPA1;NDRG1;SCD;KRT19;KRT8;ADAMTS1;TSC22D1;SPDEF;INSIG1</td>
#     </tr>
#     <tr>
#       <th id="T_dbb79_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dbb79_row3_col0" class="data row3 col0" >MSigDB Hallmark</td>
#       <td id="T_dbb79_row3_col1" class="data row3 col1" >HALLMARK_ANGIOGENESIS</td>
#       <td id="T_dbb79_row3_col2" class="data row3 col2" >4/26</td>
#       <td id="T_dbb79_row3_col3" class="data row3 col3" >0.069259</td>
#       <td id="T_dbb79_row3_col4" class="data row3 col4" >0.127863</td>
#       <td id="T_dbb79_row3_col5" class="data row3 col5" >3.107608</td>
#       <td id="T_dbb79_row3_col6" class="data row3 col6" >8.296997</td>
#       <td id="T_dbb79_row3_col7" class="data row3 col7" >FSTL1;VTN;SLCO2A1;THBD</td>
#     </tr>
#     <tr>
#       <th id="T_dbb79_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dbb79_row4_col0" class="data row4 col0" >MSigDB Hallmark</td>
#       <td id="T_dbb79_row4_col1" class="data row4 col1" >HALLMARK_APICAL_JUNCTION</td>
#       <td id="T_dbb79_row4_col2" class="data row4 col2" >19/152</td>
#       <td id="T_dbb79_row4_col3" class="data row4 col3" >0.002105</td>
#       <td id="T_dbb79_row4_col4" class="data row4 col4" >0.006735</td>
#       <td id="T_dbb79_row4_col5" class="data row4 col5" >2.291710</td>
#       <td id="T_dbb79_row4_col6" class="data row4 col6" >14.125159</td>
#       <td id="T_dbb79_row4_col7" class="data row4 col7" >ICAM5;IKBKG;ARHGEF6;CDH4;ICAM1;ITGA2;INSIG1;CDH11;PPP2R2C;MYH10;CX3CL1;FSCN1;CDH1;COL17A1;VCAM1;CLDN7;LIMA1;GRB7;CALB2</td>
#     </tr>
#     <tr>
#       <th id="T_dbb79_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dbb79_row5_col0" class="data row5 col0" >MSigDB Hallmark</td>
#       <td id="T_dbb79_row5_col1" class="data row5 col1" >HALLMARK_APICAL_SURFACE</td>
#       <td id="T_dbb79_row5_col2" class="data row5 col2" >9/27</td>
#       <td id="T_dbb79_row5_col3" class="data row5 col3" >0.000018</td>
#       <td id="T_dbb79_row5_col4" class="data row5 col4" >0.000186</td>
#       <td id="T_dbb79_row5_col5" class="data row5 col5" >8.030370</td>
#       <td id="T_dbb79_row5_col6" class="data row5 col6" >87.567233</td>
#       <td id="T_dbb79_row5_col7" class="data row5 col7" >MDGA1;AFAP1L2;PCSK9;AKAP7;CX3CL1;GATA3;PLAUR;SRPX;ATP8B1</td>
#     </tr>
#     <tr>
#       <th id="T_dbb79_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dbb79_row6_col0" class="data row6 col0" >MSigDB Hallmark</td>
#       <td id="T_dbb79_row6_col1" class="data row6 col1" >HALLMARK_APOPTOSIS</td>
#       <td id="T_dbb79_row6_col2" class="data row6 col2" >15/139</td>
#       <td id="T_dbb79_row6_col3" class="data row6 col3" >0.021250</td>
#       <td id="T_dbb79_row6_col4" class="data row6 col4" >0.051001</td>
#       <td id="T_dbb79_row6_col5" class="data row6 col5" >1.945041</td>
#       <td id="T_dbb79_row6_col6" class="data row6 col6" >7.491099</td>
#       <td id="T_dbb79_row6_col7" class="data row6 col7" >SAT1;KRT18;PDGFRB;GSN;CD14;IL18;ERBB3;TIMP3;BIK;BCAP31;SATB1;EMP1;TNFSF10;TGFB2;LEF1</td>
#     </tr>
#     <tr>
#       <th id="T_dbb79_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dbb79_row7_col0" class="data row7 col0" >MSigDB Hallmark</td>
#       <td id="T_dbb79_row7_col1" class="data row7 col1" >HALLMARK_BILE_ACID_METABOLISM</td>
#       <td id="T_dbb79_row7_col2" class="data row7 col2" >7/71</td>
#       <td id="T_dbb79_row7_col3" class="data row7 col3" >0.137655</td>
#       <td id="T_dbb79_row7_col4" class="data row7 col4" >0.227843</td>
#       <td id="T_dbb79_row7_col5" class="data row7 col5" >1.807404</td>
#       <td id="T_dbb79_row7_col6" class="data row7 col6" >3.584088</td>
#       <td id="T_dbb79_row7_col7" class="data row7 col7" >PXMP2;DHCR24;HSD3B1;FADS2;CH25H;PHYH;DIO2</td>
#     </tr>
#     <tr>
#       <th id="T_dbb79_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dbb79_row8_col0" class="data row8 col0" >MSigDB Hallmark</td>
#       <td id="T_dbb79_row8_col1" class="data row8 col1" >HALLMARK_CHOLESTEROL_HOMEOSTASIS</td>
#       <td id="T_dbb79_row8_col2" class="data row8 col2" >11/69</td>
#       <td id="T_dbb79_row8_col3" class="data row8 col3" >0.002738</td>
#       <td id="T_dbb79_row8_col4" class="data row8 col4" >0.008214</td>
#       <td id="T_dbb79_row8_col5" class="data row8 col5" >3.072049</td>
#       <td id="T_dbb79_row8_col6" class="data row8 col6" >18.126713</td>
#       <td id="T_dbb79_row8_col7" class="data row8 col7" >ALDOC;FADS2;PLAUR;LSS;GSTM2;MAL2;SCD;ANTXR2;TRIB3;DHCR7;NSDHL</td>
#     </tr>
#     <tr>
#       <th id="T_dbb79_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dbb79_row9_col0" class="data row9 col0" >MSigDB Hallmark</td>
#       <td id="T_dbb79_row9_col1" class="data row9 col1" >HALLMARK_COAGULATION</td>
#       <td id="T_dbb79_row9_col2" class="data row9 col2" >13/84</td>
#       <td id="T_dbb79_row9_col3" class="data row9 col3" >0.001550</td>
#       <td id="T_dbb79_row9_col4" class="data row9 col4" >0.005315</td>
#       <td id="T_dbb79_row9_col5" class="data row9 col5" >2.954866

# %% [markdown]
# So what we have in our Enrichr object results table are the following:
#
# <ul>
#     <li><code>Gene_set</code> - this is the database that we're using for our analysis. If we provided more than one database for our analysis, we would have additional gene set values corresponding to the other databases.</li>
#     <li><code>Term</code> - this is the functional groupings of the different genes.</li>
#     <li><code>Overlap</code> - this is the quantification of the number of genes contained in our significant hits (or other specified threshold) that overlap with the genes contained within the different terms</li>
#     <li><code>P-value</code> - this is the p-value resulting from the hypergeometric test</li>
#     <li><code>Adjusted P-value</code> - this is the q-value resulting from the Benjamini-Hochberg correction, which is one way to correct for multiple hypothesis testing</li>
#     <li><code>Odds Ratio</code> - the odds ratio can be thought of as a quantification of the enrichment of your significant hits, so a greater Odds Ratio value indicates a greater enrichment of genes contained in that gene set among your hits. The odds ratio is calculated as follows:</li>
# </ul>
#
# ```
# Odds Ratio = (1 * a * d) / (whichever is greater of the two: (1 * b * c) or 1)
# ```
#
# <ul>
#     <p>Where the variables are the numbers of genes broken down in the figure below:</p>
# </ul>
#
# <img src="./images/15_1_fig_1.jpg" style="height: 250px; margin: auto;"/>
#
# <ul>
#     <p>So then if we see a reduced enrichment for example, we would expect to see a smaller odds ratio.</p>
# </ul>
#
# <img src="./images/15_1_fig_2.jpg" style="height: 250px; margin: auto;"/>
#
# <ul>
#     <li><code>Combined Score</code> - a calculation that takes into account the <code>P-value</code> (not the <code>Adjusted P-value</code>) and the <code>Odds Ratio</code></li>
# </ul>
#
# <ul>
#     <p>The combined score is calculated as:</p>
# </ul>
#
# ```
# Combined Score = -log(P-value) * (Odds Ratio)
# ```
#
# <ul>
#     <p>The combined score is a compromise between the p-value and the odds ratio, which has been shown by the Ma'ayan lab to be better for ranking the results of an over-representation analysis.</p>
# </ul>

# %% [markdown]
# <h2>Save the results of your over-representation analysis</h2>

# %% [markdown]
# Let's go ahead and save the results table that we got from our analysis:

# %%
#We can save the results of our functional analysis in a separate folder but continue to dump everything into Week 10
try:
    os.mkdir('../Week_10/functional-analysis')
except FileExistsError:
    pass

ora.res2d.sort_values(by='Adjusted P-value').to_csv('../Week_10/functional-analysis/over-representation-analysis.csv',\
                                                    index=False)

# %% [markdown]
# <h2>Visualize results of over-representation analysis</h2>

# %% [markdown]
# We can then take our results and plot them a few different ways to visualize the results of our functional analysis. If you ran your over-representation analysis using multiple databases, you also have the option to plot the results from the databases together.

# %% [markdown]
# <h3>Plot a dot plot</h3>

# %% [markdown]
# We can plot our results on a dot plot (categorical scatter plot) that allow us to visualize the different categories (<code>Term</code>) together on a single plot and arrange them based on the output result scores, such as combined score, adjusted p-value, etc. The dot plot allows us to visualize multiple result scores on a single plot depending on what parameters we provide it.
#
# To do this, we'll make use of GSEApy's <code>gp.dotplot()</code> function. <a href="https://gseapy.readthedocs.io/en/latest/run.html#gseapy.plot.dotplot" rel="noopener noreferrer"><u>Documentation for <code>gp.dotplot()</code> can be found here.</u></a> We'll provide it with the results of our analysis and specify how we want it to generate the plot:

# %%
#Call up the dotplot function to then visualize the results of our over-rep analysis
#The column, x, and y parameters pull from the values from the indicated column from ora.res2d
#So in this setup, the Combined Score column values will be used to plot dots' x-axis position
#Y-axis will be the Term column values that meet our cutoff criteria top 25 terms with cutoff Adjust P-value <0.05
gp.dotplot(df=ora.res2d,
           column='Adjusted P-value',
           x='Combined Score',
           y='Term',
           top_term=25,
           cutoff=0.05,
           size=15,
           figsize=(3,10),
           title='MSigDB Hallmark',
           xticklabels_rot=0,
           show_ring=True,
           marker='o',
           # ofname='../Week_10/functional-analysis/over-rep-dot-plot.pdf',
          );

#More detailed breakdown of the code is in the code breakdown below

# %% [markdown]
# <h2>Let's break down the code:</h2>

# %% [markdown]
# <code>gp.dotplot()</code>
#
# We're calling up the function to generate dot plots from the GSEApy package. The dot plot will visualize the data contained in three columns of your DataFrame: % Genes in set (derived from <code>Overlap</code>), and two others that you can select through the <code>column</code> and <code>x</code> parameters.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>df=ora.res2d</code>
#
# We provide it with a DataFrame containing our results. In this case, we're providing it with the DataFrame containing the results of our most recent query.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>column='Adjusted P-value'</code>
#
# We are specifying how we want to fill the color for each dot. The default viridis color map will be used to color in the dots according to their adjusted p-value.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>x='Combined Score'</code>
#
# This is another set of data that we want to visualize in the same dot plot. This parameter affects where along the X-axis the dots are plotted with the location determined by the results column you specify. In this case, we will plot the dots along the X-axis based on their <code>Combined Score</code>.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>y='Term'</code>
#
# This sets our Y-axis, and here we're specifying that we want to set our Y-axis as a categorical Y axis corresponding to each group of genes.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>top_term=20</code>
#
# This argument sets the number of enriched terms that we will plot, and it will pull the top terms according to the values specified by your <code>column</code> parameter. So in our case, this will pull the top 10 most significant terms to generate a dot plot.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>cutoff=0.05</code>
#
# This argument sets what the cutoff significance threshold is for plotting. By setting this to parameter to <code>0.05</code>, we specify that our significantly enriched terms will be those that have an <code>Adjusted P-value</code> less than 0.05.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>size=15</code>
#
# This sets the size of our dots, and we can adjust this to better display our dots on our plots.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>figsize=(3,10)</code>
#
# This parameter sets the size of our output figure, and we can supply it with a tuple corresponding to the width and the height of our figure.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>title = 'MSigDB Hallmark'</code>
#
# We can also add a title to our plots through this parameter.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>xticklabels_rot=0</code>
#
# Here, we can adjust the rotation of our X-axis tick labels. This is helpful to adjust when plotting categorical values along the X-axis (such as comparing multiple databases at the same time) to prevent the labels from overlapping one another.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>show_ring=False</code>
#
# If we want, we can also plot a ring around our dots corresponding to the largest percent value in our plot to better compare size changes between dots. By setting this to <code>False</code>, we'll hide the rings and just plot the dots.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>marker='o'</code>
#
# This parameter is the same as what we've seen with matplotlib, and <code>gp.dotplot()</code> follows the same syntax, where we can specify that we want to plot dots by passing the argument <code>'o'</code>.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>ofname=None</code>
#
# If we want to instead save our output image generated by this function to a file, we can provide the name of the file as a string. This functions similarly to some of the visualization functions we've encountered in R, where we provided the file name as an argument to get an output file.
#
# To save the output visualization, we can then provide it with the file path and name.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>

# %% [markdown]
# <h2>Plot a bar plot</h2>

# %% [markdown]
# Another way of visualizing our results is to generate a bar plot, which is a more focused graph, where we simply plot one of the result scores. We'll make use of GSEApy's <code>gp.barplot()</code> function. <a href="https://gseapy.readthedocs.io/en/latest/run.html#gseapy.plot.barplot" rel="noopener noreferrer"><u>Documentation for <code>gp.barplot()</code> can be found here.</u></a>

# %%
#Another way to visualize results of over-rep analysis is via a barplot
#The dot plot shows more dimensions of information, while barplot looks at one dimension
#In this case, we set it up to plot just the combined score
gp.barplot(df=ora.res2d,
           column='Combined Score',
           top_term=25,
           cutoff=0.05,
           figsize=(3,10),
           title='MSigDB Hallmark',
           color='#E64B35',
           ofname=None,
          );

# %% [markdown]
# The setup is very similar to the dot plot and in some ways a little simpler. The only difference here is that we can provide the function with a <code>color</code> string or dictionary that sets the fill color of the bars. If we have multiple databases being compared, we can provide it with a dictionary containing key:value pairs corresponding to the database name and the color, respectively.

# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Gene Set Enrichment Analysis (GSEA)</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# Another common functional analysis approach is to perform a <a href="https://www.gsea-msigdb.org/gsea/doc/GSEAUserGuideFrame.html" rel="noopener noreferrer"><u>Gene Set Enrichment Analysis (GSEA)</u></a>. A key difference between the over-representation analysis that we performed above and GSEA is that we will take our counts matrix to perform this analysis. So we are not setting any arbitrary cutoffs for significance or log2 fold change. We provide the analysis with our expression matrix, the database that we want it to use for analysis, and metadata contained within a .cls file.
#
# Our dataset will get ordered based on the normalized count matrix. Then the function will perform a walk down the list of genes to determine if there is an enrichment of genes within a gene set above what it would normally expect to encounter based on random chance, where random chance is determined by reshuffling (permutation) the order of the genes and repeating the walk up to a specified number of permutations. The result is that we identify which gene sets are enriched in either our control samples or our TAZ KO samples.

# %% [markdown]
# <h2>Prepare for GSEA</h2>

# %% [markdown]
# To perform our analysis, we'll first generate the "metadata" that will be parsed from a .cls file. The <code>gp.parser.gsea_cls_parser()</code> function will pull out the conditions and how they should be assigned to each column of your normalized counts matrix. We can generate this ourselves directly in this notebook.
#
# First, we can create variables that specify what our two sample groups are:

# %%
#We assign our strings corresponding to how we want to specify our two conditions
ctrl = 'CONTROL'
tazko = 'TAZ KO'

# %% [markdown]
# Then we can put them together into a list that will be used to assign the groups to each column of our normalized count matrix:

# %%
#We can place the strings into their own list and then have it repeated according to how many groups we have
class_vector = ([ctrl] + [tazko])*9

# %%
class_vector
#What we end up with is a repeating list of 'CONTROL' and 'TAZKO'
#This is how we will specify to GSEA what condition each column in our norm_counts matrix corresponds to
#Not too different from what we had to do for DESeq2
# Out:
# ['CONTROL',
#  'TAZ KO',
#  'CONTROL',
#  'TAZ KO',
#  'CONTROL',
#  'TAZ KO',
#  'CONTROL',
#  'TAZ KO',
#  'CONTROL',
#  'TAZ KO',
#  'CONTROL',
#  'TAZ KO',
#  'CONTROL',
#  'TAZ KO',
#  'CONTROL',
#  'TAZ KO',
#  'CONTROL',
#  'TAZ KO']

# %%
norm_counts.head().style
# Out:
# <style type="text/css">
# </style>
# <table id="T_6de86">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6de86_level0_col0" class="col_heading level0 col0" >gene</th>
#       <th id="T_6de86_level0_col1" class="col_heading level0 col1" >ctrl_g1</th>
#       <th id="T_6de86_level0_col2" class="col_heading level0 col2" >tazko_g1</th>
#       <th id="T_6de86_level0_col3" class="col_heading level0 col3" >ctrl_g2</th>
#       <th id="T_6de86_level0_col4" class="col_heading level0 col4" >tazko_g2</th>
#       <th id="T_6de86_level0_col5" class="col_heading level0 col5" >ctrl_g3</th>
#       <th id="T_6de86_level0_col6" class="col_heading level0 col6" >tazko_g3</th>
#       <th id="T_6de86_level0_col7" class="col_heading level0 col7" >ctrl_g4</th>
#       <th id="T_6de86_level0_col8" class="col_heading level0 col8" >tazko_g4</th>
#       <th id="T_6de86_level0_col9" class="col_heading level0 col9" >ctrl_g5</th>
#       <th id="T_6de86_level0_col10" class="col_heading level0 col10" >tazko_g5</th>
#       <th id="T_6de86_level0_col11" class="col_heading level0 col11" >ctrl_g6</th>
#       <th id="T_6de86_level0_col12" class="col_heading level0 col12" >tazko_g6</th>
#       <th id="T_6de86_level0_col13" class="col_heading level0 col13" >ctrl_g7</th>
#       <th id="T_6de86_level0_col14" class="col_heading level0 col14" >tazko_g7</th>
#       <th id="T_6de86_level0_col15" class="col_heading level0 col15" >ctrl_g8</th>
#       <th id="T_6de86_level0_col16" class="col_heading level0 col16" >tazko_g8</th>
#       <th id="T_6de86_level0_col17" class="col_heading level0 col17" >ctrl_g9</th>
#       <th id="T_6de86_level0_col18" class="col_heading level0 col18" >tazko_g9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6de86_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6de86_row0_col0" class="data row0 col0" >A1BG-AS1</td>
#       <td id="T_6de86_row0_col1" class="data row0 col1" >0.993195</td>
#       <td id="T_6de86_row0_col2" class="data row0 col2" >3.094105</td>
#       <td id="T_6de86_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_6de86_row0_col4" class="data row0 col4" >1.143745</td>
#       <td id="T_6de86_row0_col5" class="data row0 col5" >2.841466</td>
#       <td id="T_6de86_row0_col6" class="data row0 col6" >4.465449</td>
#       <td id="T_6de86_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_6de86_row0_col8" class="data row0 col8" >7.408773</td>
#       <td id="T_6de86_row0_col9" class="data row0 col9" >0.959141</td>
#       <td id="T_6de86_row0_col10" class="data row0 col10" >1.882807</td>
#       <td id="T_6de86_row0_col11" class="data row0 col11" >1.918798</td>
#       <td id="T_6de86_row0_col12" class="data row0 col12" >2.490844</td>
#       <td id="T_6de86_row0_col13" class="data row0 col13" >0.000000</td>
#       <td id="T_6de86_row0_col14" class="data row0 col14" >0.913544</td>
#       <td id="T_6de86_row0_col15" class="data row0 col15" >0.968493</td>
#       <td id="T_6de86_row0_col16" class="data row0 col16" >1.832776</td>
#       <td id="T_6de86_row0_col17" class="data row0 col17" >0.000000</td>
#       <td id="T_6de86_row0_col18" class="data row0 col18" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6de86_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6de86_row1_col0" class="data row1 col0" >A4GALT</td>
#       <td id="T_6de86_row1_col1" class="data row1 col1" >7.945557</td>
#       <td id="T_6de86_row1_col2" class="data row1 col2" >8.250946</td>
#       <td id="T_6de86_row1_col3" class="data row1 col3" >14.523575</td>
#       <td id="T_6de86_row1_col4" class="data row1 col4" >10.293703</td>
#       <td id="T_6de86_row1_col5" class="data row1 col5" >16.101640</td>
#       <td id="T_6de86_row1_col6" class="data row1 col6" >7.144719</td>
#       <td id="T_6de86_row1_col7" class="data row1 col7" >12.238351</td>
#       <td id="T_6de86_row1_col8" class="data row1 col8" >9.260966</td>
#       <td id="T_6de86_row1_col9" class="data row1 col9" >4.795706</td>
#       <td id="T_6de86_row1_col10" class="data row1 col10" >17.886670</td>
#       <td id="T_6de86_row1_col11" class="data row1 col11" >8.634592</td>
#       <td id="T_6de86_row1_col12" class="data row1 col12" >9.963376</td>
#       <td id="T_6de86_row1_col13" class="data row1 col13" >7.729285</td>
#       <td id="T_6de86_row1_col14" class="data row1 col14" >8.221895</td>
#       <td id="T_6de86_row1_col15" class="data row1 col15" >19.369854</td>
#       <td id="T_6de86_row1_col16" class="data row1 col16" >11.913046</td>
#       <td id="T_6de86_row1_col17" class="data row1 col17" >6.457018</td>
#       <td id="T_6de86_row1_col18" class="data row1 col18" >10.786287</td>
#     </tr>
#     <tr>
#       <th id="T_6de86_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6de86_row2_col0" class="data row2 col0" >AAAS</td>
#       <td id="T_6de86_row2_col1" class="data row2 col1" >17.877503</td>
#       <td id="T_6de86_row2_col2" class="data row2 col2" >28.878310</td>
#       <td id="T_6de86_row2_col3" class="data row2 col3" >24.205958</td>
#       <td id="T_6de86_row2_col4" class="data row2 col4" >27.449875</td>
#       <td id="T_6de86_row2_col5" class="data row2 col5" >37.886211</td>
#       <td id="T_6de86_row2_col6" class="data row2 col6" >29.471964</td>
#       <td id="T_6de86_row2_col7" class="data row2 col7" >29.576015</td>
#       <td id="T_6de86_row2_col8" class="data row2 col8" >25.004609</td>
#       <td id="T_6de86_row2_col9" class="data row2 col9" >26.855952</td>
#       <td id="T_6de86_row2_col10" class="data row2 col10" >25.417899</td>
#       <td id="T_6de86_row2_col11" class="data row2 col11" >24.944376</td>
#       <td id="T_6de86_row2_col12" class="data row2 col12" >19.926752</td>
#       <td id="T_6de86_row2_col13" class="data row2 col13" >38.646424</td>
#       <td id="T_6de86_row2_col14" class="data row2 col14" >27.406318</td>
#       <td id="T_6de86_row2_col15" class="data row2 col15" >25.180810</td>
#       <td id="T_6de86_row2_col16" class="data row2 col16" >44.903018</td>
#       <td id="T_6de86_row2_col17" class="data row2 col17" >31.208920</td>
#       <td id="T_6de86_row2_col18" class="data row2 col18" >21.572573</td>
#     </tr>
#     <tr>
#       <th id="T_6de86_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6de86_row3_col0" class="data row3 col0" >AACS</td>
#       <td id="T_6de86_row3_col1" class="data row3 col1" >23.836671</td>
#       <td id="T_6de86_row3_col2" class="data row3 col2" >29.909678</td>
#       <td id="T_6de86_row3_col3" class="data row3 col3" >30.983626</td>
#       <td id="T_6de86_row3_col4" class="data row3 col4" >28.593619</td>
#       <td id="T_6de86_row3_col5" class="data row3 col5" >33.150435</td>
#       <td id="T_6de86_row3_col6" class="data row3 col6" >24.113425</td>
#       <td id="T_6de86_row3_col7" class="data row3 col7" >28.556153</td>
#       <td id="T_6de86_row3_col8" class="data row3 col8" >26.856802</td>
#       <td id="T_6de86_row3_col9" class="data row3 col9" >35.488223</td>
#       <td id="T_6de86_row3_col10" class="data row3 col10" >25.417899</td>
#       <td id="T_6de86_row3_col11" class="data row3 col11" >31.660170</td>
#       <td id="T_6de86_row3_col12" class="data row3 col12" >26.153863</td>
#       <td id="T_6de86_row3_col13" class="data row3 col13" >33.815621</td>
#       <td id="T_6de86_row3_col14" class="data row3 col14" >18.270879</td>
#       <td id="T_6de86_row3_col15" class="data row3 col15" >19.369854</td>
#       <td id="T_6de86_row3_col16" class="data row3 col16" >28.408032</td>
#       <td id="T_6de86_row3_col17" class="data row3 col17" >27.980411</td>
#       <td id="T_6de86_row3_col18" class="data row3 col18" >33.257717</td>
#     </tr>
#     <tr>
#       <th id="T_6de86_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6de86_row4_col0" class="data row4 col0" >AADAT</td>
#       <td id="T_6de86_row4_col1" class="data row4 col1" >0.993195</td>
#       <td id="T_6de86_row4_col2" class="data row4 col2" >4.125473</td>
#       <td id="T_6de86_row4_col3" class="data row4 col3" >3.872953</td>
#       <td id="T_6de86_row4_col4" class="data r

# %% [markdown]
# Let's take a look at the variables:

# %%
#See above code cells

# %% [markdown]
# So this is much the same as what we did when we provided DESeq2 with a conditions matrix.

# %% [markdown]
# <h2>Perform GSEA</h2>

# %% [markdown]
# Now, we can set up and then run GSEA:

# %%
#We first set up our GSEA parameters
#This does not run the GSEA but specifies how we want it to run
gs_res = gp.GSEA(data=norm_counts,                  #Instead of filtering or using our DESeq2 results, we pass along our normalized counts matrix
                 gene_sets=hallmark_db,             #We specify what gene sets we want to use
                 classes=class_vector,              #Then we provide it with what each column's condition is (the "metadata")
                 method='signal_to_noise',          #We specify how we want it to rank each gene
                 permutation_type='phenotype',      #Then we specify how "random chance" is determined to determine the degree of enrichment in our sample conditions
                 permutation_num=1000,              #Every permutation results in a ranked list of genes and a "walk" down that ranked list to determine background enrichment
                 outdir=None,                       #No need to output to a file
                 seed=135,                          #This sets the seed for the random assignment, so its consistent between each run
                )

#We then need to specify what a positive and negative enrichment score corresponds to
gs_res.pheno_pos = tazko       #We note that positive corresponds to enrichment in our TAZ KO samples
gs_res.pheno_neg = ctrl        #While a negative enrichment corresponds to our CONTROL samples

#Then with everything set up, we can run our GSEA
gs_res.run()

#Review the below code breakdown for more detailed information, esp. on permutation and how "more than random chance" is determined
#Keep in mind that in our case, our 'phenotype' is either CONTROL or TAZ KO
#So when the 'phenotype' is shuffled, then it is shuffling how CONTROL and TAZ KO labels are being assigned
#In other words, it's randomly assigning conditions to samples before ranking genes
#so we then get an idea of the level of enrichment when there is no differential expression (no difference between CONTROL and TAZ KO regardless of assignment)
#and we can compare it to when we do have differential expression (our properly assigned samples)

# %% [markdown]
# <h2>Let's break down the code:</h2>

# %% [markdown]
# <code>gs_res</code>
#
# This will be the variable to hold our GSEA results.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>&equals;</code>
#
# Our assignment variable.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>gp.GSEA()</code>
#
# This is the function to set up our GSEA run. This set up allows us to first provide the information for our analysis before running the analysis. If we wanted to just run the analysis directly, we can instead use the <code>gp.gsea()</code> function. This will become more apparent when we specify how we want our groups to be arranged.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>data=norm_counts</code>
#
# This is our normalized counts matrix that we'll pass to <code>gp.GSEA()</code>. We don't need to provide it with an ordered list of genes since it will perform the ranking according to the argument we set for the <code>method</code> parameter.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>gene_sets=hallmark_db</code>
#
# Like with before, we indicate which database we want it to use for functional analysis. Here, we provide it with the <code>dict</code> object containing the gene sets for the MSigDB Hallmark database that we pulled in earlier.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>classes=class_vector</code>
#
# This argument assigns the sample conditions (phenotypes) to our normalized counts matrix based on the information contained in our .cls file. So by making sure that the order of our class vector matches our normalized counts matrix columns, our samples will be assigned to their correct "class" or "phenotype".
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>method='signal_to_noise'</code>
#
# This parameter sets the ranking algorithm that will be used. This method calculates the difference of means scaled by the standard deviation, so that a large difference in gene expression classifies that gene as a stronger "class marker" for the condition. So if something is highly upregulated in our TAZ KO samples compared to control, then it will be highly ranked in our ranked list. As we then progress towards the end of the ranked list, the genes will be highly downregulatd in TAZ KO samples compared to control, so those genes will be a stronger "class marker" for our control condition.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>permutation_type='phenotype'</code>
#
# Recall from Dr. Ingolia's lecture that GSEA compares the enrichment relative to what would be expected by random chance. In order to determine "what would be expected by random chance", GSEA will randomly shuffle the data and repeat the analysis many times. The repeated reshuffling and "walk" down the list creates a reference for the level of enrichment that would be expected based on random chance. There are two methods to "shuffle" the data prior to analysis.
#
# The one discussed in lecture is a reshuffling of the sample condition prior to ranking and then repeating the walk down the list of genes. With the setup that we have indicated here with the <code>'phenotype'</code> argument, we randomly assign a condition (phenotype) to each sample, then the genes are ranked according to our specified method. Then the walk down the list is performed. This type of permutation ensures that the gene sets are constant between permutations, and by shuffling the assigned phenotypes for each of our samples, it creates a reference point for the level of enrichment when there is no differential expression in our data (a random ranking of genes). This permutation method requires that we have at least 7 samples for each condition, which we do. The stringency of this method allows us to use a cutoff FDR (q-value) of 0.25 rather than 0.05.
#
# Another permutation method, which is less stringent, is to hold the gene rankings constant (assume the differential expression is true) and then instead reshuffle what genes are contained in the gene sets. This method can be used by passing the <code>'gene_set'</code> argument. So the reference point in this case is not a random ranking of genes but rather comparing the enrichment level to a hypothetical randomly generated gene set. This can be used if the sample numbers are too small for the 'phenotype' permutation, and it requires a FDR (q-value) cutoff of 0.05.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>permutation_num=1000</code>
#
# This is the number of times we want to reshuffle and repeat the analysis to determine a reference enrichment level for "random chance".
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>outdir=None</code>
#
# If we wanted to save the output into a file, we can specify the file name here or separately save using <code>pd.DataFrame.to_csv()</code>.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>seed=135</code>
#
# This seed is for the random permutations, and by setting a "seed" value, we fix the randomization, allowing our results to be reproducible between runs. So if you provided someone else with the same settings, they'll be able to get the same results if they use the same "seed" value. However, if they run with a different seed value, their randomization will be different, so their reference enrichment level will be different as well. So they may have slightly different results.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>gs_res.pheno_pos = tazko</code>
#
# This sets which condition (phenotype) positive enrichment values are correlated with. Our setup will set positive values to be indicative of enrichment in TAZ KO samples.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>gs_res.pheno_neg = ctrl</code>
#
# This sets which condition (phenotpe) negative enrichment values are correlated with. Based on our setup, negative values would indicate enrichment in our control samples.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>
#
# <code>gs_res.run()</code>
#
# After we've set up how we want to run our GSEA, we can then run the analysis with this line.
#
# <hr style="border: 1px solid; border-color: #AAAAAA;"></hr>

# %% [markdown]
# Let's take a look at the results table:

# %%
gs_res.res2d
# Out:
#     Name                                        Term        ES       NES  \
# 0   gsea                            HALLMARK_HYPOXIA -0.541378 -2.437251
# 1   gsea                   HALLMARK_MTORC1_SIGNALING -0.568454 -2.394979
# 2   gsea              HALLMARK_XENOBIOTIC_METABOLISM -0.478665 -2.392068
# 3   gsea                    HALLMARK_APICAL_JUNCTION -0.445569  -2.26099
# 4   gsea            HALLMARK_ESTROGEN_RESPONSE_EARLY -0.480687 -2.239042
# 5   gsea  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION -0.465643  -2.22044
# 6   gsea          HALLMARK_UNFOLDED_PROTEIN_RESPONSE -0.503866 -2.196935
# 7   gsea            HALLMARK_CHOLESTEROL_HOMEOSTASIS  -0.56626 -2.159681
# 8   gsea                         HALLMARK_GLYCOLYSIS -0.437329 -2.123528
# 9   gsea          HALLMARK_INTERFERON_ALPHA_RESPONSE  0.553577  2.113095
# 10  gsea                        HALLMARK_E2F_TARGETS -0.579016 -2.071134
# 11  gsea                     HALLMARK_UV_RESPONSE_DN -0.450964 -2.067952
# 12  gsea                     HALLMARK_G2M_CHECKPOINT -0.524794 -2.042348
# 13  gsea             HALLMARK_ESTROGEN_RESPONSE_LATE -0.442408 -2.040362
# 14  gsea                     HALLMARK_MYC_TARGETS_V1  -0.61392 -1.992562
# 15  gsea                HALLMARK_ALLOGRAFT_REJECTION  -0.38901 -1.984094
# 16  gsea            HALLMARK_PI3K_AKT_MTOR_SIGNALING  -0.41823 -1.964983
# 17  gsea          HALLMARK_INTERFERON_GAMMA_RESPONSE  0.401863  1.939322
# 18  gsea                         HALLMARK_MYOGENESIS -0.379444 -1.933435
# 19  gsea                  HALLMARK_ANDROGEN_RESPONSE -0.465108 -1.926777
# 20  gsea                HALLMARK_IL2_STAT5_SIGNALING  0.412261  1.905653
# 21  gsea              HALLMARK_INFLAMMATORY_RESPONSE -0.382299 -1.886326
# 22  gsea                          HALLMARK_APOPTOSIS -0.339715 -1.884988
# 23  gsea                       HALLMARK_ADIPOGENESIS -0.365979 -1.860194
# 24  gsea                         HALLMARK_PEROXISOME -0.386682  -1.82986
# 25  gsea                  HALLMARK_KRAS_SIGNALING_UP  0.423498  1.818937
# 26  gsea                     HALLMARK_MYC_TARGETS_V2 -0.514232 -1.809506
# 27  gsea                    HALLMARK_MITOTIC_SPINDLE -0.401173 -1.712999
# 28  gsea                    HALLMARK_HEME_METABOLISM -0.306495 -1.652698
# 29  gsea                 HALLMARK_HEDGEHOG_SIGNALING -0.439619 -1.636869
# 30  gsea                     HALLMARK_APICAL_SURFACE  0.424429  1.601526
# 31  gsea              HALLMARK_FATTY_ACID_METABOLISM  -0.34684  -1.59589
# 32  gsea            HALLMARK_TNFA_SIGNALING_VIA_NFKB  0.335274  1.561547
# 33  gsea                         HALLMARK_COMPLEMENT -0.298437 -1.552569
# 34  gsea                        HALLMARK_COAGULATION  0.338584  1.521259
# 35  gsea                     HALLMARK_UV_RESPONSE_UP  -0.30291 -1.514061
# 36  gsea                        HALLMARK_P53_PATHWAY -0.288734 -1.495035
# 37  gsea                 HALLMARK_TGF_BETA_SIGNALING  0.379876  1.489886
# 38  gsea                         HALLMARK_DNA_REPAIR -0.331978 -1.470496
# 39  gsea               HALLMARK_BILE_ACID_METABOLISM -0.311241 -1.424891
# 40  gsea                  HALLMARK_PROTEIN_SECRETION -0.310881 -1.423843
# 41  gsea         HALLMARK_WNT_BETA_CATENIN_SIGNALING -0.331435 -1.393421
# 42  gsea                       HALLMARK_ANGIOGENESIS  0.387734  1.380714
# 43  gsea    HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY  0.363394  1.371411
# 44  gsea                HALLMARK_PANCREAS_BETA_CELLS -0.443163 -1.365129
# 45  gsea                    HALLMARK_NOTCH_SIGNALING -0.322226 -1.274948
# 46  gsea          HALLMARK_OXIDATIVE_PHOSPHORYLATION -0.310957 -1.120973
# 47  gsea            HALLMARK_IL6_JAK_STAT3_SIGNALING  0.268949   1.10491
# 48  gsea                    HALLMARK_SPERMATOGENESIS  0.208671  0.907714
# 49  gsea                  HALLMARK_KRAS_SIGNALING_DN  0.195857  0.901821
#
#    NOM p-val FDR q-val FWER p-val   Tag %  Gene %  \
# 0        0.0       0.0        0.0  58/177   8.36%
# 1        0.0       0.0        0.0  71/196  11.98%
# 2        0.0       0.0        0.0  36/158   7.52%
# 3        0.0       0.0        0.0  43/163   8.82%
# 4        0.0       0.0        0.0  53/181  11.41%
# 5        0.0       0.0        0.0  48/173   8.98%
# 6        0.0       0.0        0.0  44/110  15.65%
# 7        0.0       0.0        0.0   29/70  12.52%
# 8        0.0  0.000165      0.001  48/184   9.16%
# 9        0.0   0.00052      0.001   32/96   9.31%
# 10       0.0  0.000296      0.002  97/199  18.01%
# 11       0.0  0.000269      0.002  35/138  11.39%
# 12       0.0  0.000247      0.002  79/197  15.25%
# 13       0.0  0.000342      0.003  55/179  12.78%
# 14  0.002062  0.000529      0.004  95/198  16.45%
# 15       0.0  0.000592      0.004  27/132  10.41%
# 16       0.0  0.000925      0.007   30/93  15.03%
# 17       0.0  0.005978      0.014  46/176   9.31%
# 18       0.0  0.001219      0.011  35/141  10.84%
# 19       0.0  0.001152      0.011   23/98   8.56%
# 20       0.0  0.005198       0.02  47/166  12.01%
# 21       0.0  0.002338      0.023  33/151  10.75%
# 22       0.0  0.002295      0.024  37/144  12.65%
# 23       0.0  0.003384      0.038  42/187  11.41%
# 24       0.0  0.004913      0.053   24/88  16.58%
# 25       0.0  0.009876      0.043  51/157  14.56%
# 26  0.002053  0.005858      0.064   23/57  22.33%
# 27  0.013514  0.013942      0.127  59/198  14.21%
# 28       0.0  0.022327      0.203  32/173  11.49%
# 29  0.021696  0.024145      0.221    9/33   5.06%
# 30  0.023605  0.057905      0.267    9/32   5.10%
# 31  0.005894  0.033012      0.297  32/138  13.37%
# 32  0.045635  0.064627      0.346  26/188   3.86%
# 33  0.001957   0.04373      0.354  26/160   9.97%
# 34  0.016194  0.073662      0.434   16/99   3.17%
# 35  0.023305  0.054782      0.418  34/140  15.46%
# 36   0.00789  0.059421      0.446  44/188  14.61%
# 37  0.055336  0.078943      0.496   18/52  13.01%
# 38  0.058947  0.066006      0.492  46/148  23.21%
# 39  0.031683  0.082867      0.586   13/84   9.75%
# 40  0.081633  0.081029      0.591   17/95   9.63%
# 41  0.041667  0.092581      0.654    6/39  10.41%
# 42  0.095918  0.130352      0.689    8/29   4.74%
# 43  0.117878  0.122879      0.708   10/47   6.77%
# 44  0.106996  0.103599       0.71    2/16   2.51%
# 45  0.126706  0.156532      0.857    3/30   1.75%
# 46   0.35625  0.296078      0.966  62/200  23.38%
# 47  0.302905  0.372407      0.974   11/68   8.36%
# 48  0.606119  0.642246        1.0   24/78  22.19%
# 49  0.702041  0.602639        1.0  17/104  12.22%
#
#                                            Lead_genes
# 0   F3;CAV1;SLC2A1;ENO1;PLAC8;EXT1;VLDLR;ERRFI1;AN...
# 1   SLC2A1;HSPD1;ENO1;CALR;FADS2;DHCR24;SCD;G6PD;D...
# 2   SPINT2;TGFB2;CDA;PAPSS2;PC;PYCR1;AOX1;PINK1;SL...
# 3   ICAM1;MYH10;CDH11;ACTG1;LIMA1;CDH4;INSIG1;CAP1...
# 4   SLC2A1;UGCG;KRT8;KRT19;PAPSS2;WWC1;KRT18;INHBB...
# 5   FSTL1;DKK1;MATN2;TIMP3;CDH11;COL6A2;MEST;THBS1...
# 6   CALR;SLC7A5;EEF2;DKC1;KHSRP;PSAT1;SRPRB;FUS;BA...
# 7   FADS2;ACTG1;SCD;DHCR7;ERRFI1;LSS;ALDOC;MAL2;GS...
# 8   ENO1;EXT1;PRPS1;PC;PKM;G6PD;VLDLR;PGK1;ARTN;AK...
# 9   IFIT3;IFI44;IFIT2;HERC6;SAMD9;RSAD2;IFIH1;B2M;...
# 10  HMGB3;MYBL2;PRPS1;CDCA8;KIF2C;CDC20;HMGB2;STMN...
# 11  F3;CAV1;EFEMP1;VLDLR;INSIG1;ANXA2;COL1A2;FHL2;...
# 12  HMGN2;HMGB3;MYBL2;KIF2C;SLC7A5;CDC20;CCND1;STM...
# 13  CAV1;TRIM29;MEST;CKB;KRT19;PAPSS2;DHCR7;SLC7A5...
# 14  HSPD1;PABPC4;PGK1;VBP1;PRDX3;EIF3B;CDC20;PABPC...
# 15  ICAM1;IL11;TGFB2;FLNA;INHBB;SRGN;INHBA;ELF4;RP...
# 16  SLC2A1;CALR;RPS6KA1;AKT1;SFN;PPP1CA;NGF;MKNK2;...
# 17  IFIT3;IFI44;IFIT2;HERC6;NAMPT;CDKN1A;ST8SIA4;I...
# 18  FST;COL6A2;CKB;PC;WWTR1;SCD;APP;MYLK;SPDEF;ATP...
# 19  KRT8;SMS;KRT19;H1-0;DHCR24;SCD;INSIG1;UAP1;NDR...
# 20  PRNP;NT5E;TGM2;TNFRSF1B;EMP1;SPRY4;ITGA6;CD44;...
# 21  F3;ICAM1;BST2;TNFSF10;INHBA;SLC4A4;AXL;CD55;PV...
# 22  CAV1;TIMP3;TGFB2;H1-0;TNFSF10;KRT18;APP;HMGB2;...
# 23  UCP2;DHCR7;MYLK;SLC1A5;PRDX3;IDH3G;RTN3;SCP2;P...
# 24  DHCR24;PABPC1;ACSL4;SCP2;CTPS1;YWHAH;PRDX1;SOD...
# 25  PLAU;GFPT2;ITGA2;TNFRSF1B;KCNN4;PLAT;EMP1;PLAU...
# 26  HSPD1;HK2;PLK1;MAP3K6;NOP2;SRM;PA2G4;NOLC1;SLC...
# 27  MYH10;FLNA;KIF2C;CAPZB;PCNT;NEDD9;TPX2;PALLD;C...
# 28  SLC2A1;UCP2;PC;H1-0;MPP1;SELENBP1;PDZK1IP1;SEC...
# 29   VLDLR;L1CAM;ETS2;AMOT;NRP2;CELSR1;MYH9;SHH;PTCH1
# 30  CX3CL1;PLAUR;SRPX;DCBLD2;MDGA1;GSTM3;BRCA1;AKA...
# 31  SMS;DHCR24;TP53INP2;ACSL4;IDH3G;GLUL;MGLL;CBR1...
# 32  PLAU;KYNU;PMEPA1;GFPT2;SQSTM1;IFIT2;NAMPT;LAMB...
# 33  F3;CDA;CALM3;C4BPB;PCSK9;CD55;CXCL1;FYN;C3;F8;...
# 34  PLAU;ITGA2;SERPINA1;PLAT;GSN;THBD;CAPN2;SERPIN...
# 35  ICAM1;C4BPB;STIP1;PPT1;CREG1;PPIF;CDK2;SLC25A4...
# 36  PRMT2;INHBB;IRAK1;PLK2;APP;NDRG1;ITGB4;SFN;EPH...
# 37  SLC20A1;PMEPA1;SERPINE1;LTBP2;FURIN;BCAR3;APC;...
# 38  CDA;SF3A3;BCAP31;RALA;ARL6IP1;TYMS;IMPDH2;NME4...
# 39  FADS2;DHCR24;HSD3B1;SCP2;DIO2;SOD1;ACSL1;FADS1...
# 40  BNIP3;KRT18;CAV2;OCRL;PPT1;SOD1;AP2M1;RER1;LAM...
# 41                    DKK1;FZD8;PTCH1;JAG2;NCOR2;LEF1
# 42     THBD;VEGFA;TNFRSF21;STC1;NRP1;ITGAV;TIMP1;VCAN
# 43  PRNP;GPX3;SOD2;CAT;NQO1;TXNRD2;PTPA;MBP;GLRX;GCLC
# 44                                        FOXA2;SRPRB
# 45                                   FZD7;CCND1;SAP30
# 46  ATP1B1;PRDX3;SLC25A5;ATP6AP1;GPI;IDH3G;ATP5F1A...
# 47  TNFRSF1B;CD44;TNFRSF21;IFNGR1;IL17RA;STAM2;TGF...
# 48  HSPA4L;GSTM3;TALDO1;IDE;STAM2;BUB1;CCNA1;MAP7;...
# 49  RSAD2;NR4A2;CAMK1D;SPTBN2;C5;SLC25A23;TENT5C;T...

# %% [markdown]
# Depending on what seed you chose, your results might differ slightly, but we can see enrichment for a number of pathways in our TAZ KO samples.
#
# Now let's save the results of our GSEA.

# %%
gs_res.res2d.sort_values(by='NES').to_csv('../Week_10/functional-analysis/GSEA-result.csv',
                                          index=False,
                                         )

# %% [markdown]
# <h2>Generate a GSEA plot</h2>

# %% [markdown]
# We can then visualize our results with a GSEA plot using the function <code>gp_obj.plot()</code>.
#
# This function will generate a GSEA plot for our indicated gene set term/category, and the object is a <code>matplotlib.Figure</code> object, which we can modify using the same methods we have been using for our other figures.

# %%
gs_res.res2d.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_0d7de">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d7de_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_0d7de_level0_col1" class="col_heading level0 col1" >Term</th>
#       <th id="T_0d7de_level0_col2" class="col_heading level0 col2" >ES</th>
#       <th id="T_0d7de_level0_col3" class="col_heading level0 col3" >NES</th>
#       <th id="T_0d7de_level0_col4" class="col_heading level0 col4" >NOM p-val</th>
#       <th id="T_0d7de_level0_col5" class="col_heading level0 col5" >FDR q-val</th>
#       <th id="T_0d7de_level0_col6" class="col_heading level0 col6" >FWER p-val</th>
#       <th id="T_0d7de_level0_col7" class="col_heading level0 col7" >Tag %</th>
#       <th id="T_0d7de_level0_col8" class="col_heading level0 col8" >Gene %</th>
#       <th id="T_0d7de_level0_col9" class="col_heading level0 col9" >Lead_genes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d7de_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0d7de_row0_col0" class="data row0 col0" >gsea</td>
#       <td id="T_0d7de_row0_col1" class="data row0 col1" >HALLMARK_HYPOXIA</td>
#       <td id="T_0d7de_row0_col2" class="data row0 col2" >-0.541378</td>
#       <td id="T_0d7de_row0_col3" class="data row0 col3" >-2.437251</td>
#       <td id="T_0d7de_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_0d7de_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_0d7de_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_0d7de_row0_col7" class="data row0 col7" >58/177</td>
#       <td id="T_0d7de_row0_col8" class="data row0 col8" >8.36%</td>
#       <td id="T_0d7de_row0_col9" class="data row0 col9" >F3;CAV1;SLC2A1;ENO1;PLAC8;EXT1;VLDLR;ERRFI1;ANXA2;PGK1;NDRG1;AK4;PFKP;ALDOC;SELENBP1;GPI;SAP30;SDC2;COL5A1;PGF;PGM1;HK2;MT1E;ADM;IDS;XPNPEP1;GAPDH;ACKR3;NEDD4L;FBP1;PDGFB;PFKL;CAVIN1;CITED2;HK1;MYH9;TPI1;MXI1;CCN1;GPC1;NFIL3;TMEM45A;GCNT2;HSPA5;LDHA;EDN2;PPFIA4;TPD52;TPST2;ERO1A;DDIT4;NDST1;EGFR;PDK1;HDLBP;SLC25A1;PFKFB3;TGFBI</td>
#     </tr>
#     <tr>
#       <th id="T_0d7de_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0d7de_row1_col0" class="data row1 col0" >gsea</td>
#       <td id="T_0d7de_row1_col1" class="data row1 col1" >HALLMARK_MTORC1_SIGNALING</td>
#       <td id="T_0d7de_row1_col2" class="data row1 col2" >-0.568454</td>
#       <td id="T_0d7de_row1_col3" class="data row1 col3" >-2.394979</td>
#       <td id="T_0d7de_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_0d7de_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_0d7de_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_0d7de_row1_col7" class="data row1 col7" >71/196</td>
#       <td id="T_0d7de_row1_col8" class="data row1 col8" >11.98%</td>
#       <td id="T_0d7de_row1_col9" class="data row1 col9" >SLC2A1;HSPD1;ENO1;CALR;FADS2;DHCR24;SCD;G6PD;DHCR7;VLDLR;TXNRD1;INSIG1;PGK1;SLC7A5;SLC1A5;AK4;GPI;EGLN3;PGM1;PSAT1;ADD3;HK2;AURKA;EIF2S2;SERPINH1;LDLR;GAPDH;STIP1;RRM2;PRDX1;PFKL;PPA1;PLK1;PLOD2;TRIB3;TPI1;FADS1;STARD4;NFIL3;SERP1;NFYC;IFI30;EPRS1;HSPA5;HPRT1;LDHA;PSMG1;BCAT1;DHFR;ITGB2;DDX39A;ERO1A;DDIT4;CYB5B;RPA1;RDH11;PDK1;CTH;ADIPOR2;SHMT2;MTHFD2;GLA;LTA4H;ACACA;EBP;CCNG1;CCNF;HSP90B1;ELOVL6;PHGDH;PSMB5</td>
#     </tr>
#     <tr>
#       <th id="T_0d7de_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0d7de_row2_col0" class="data row2 col0" >gsea</td>
#       <td id="T_0d7de_row2_col1" class="data row2 col1" >HALLMARK_XENOBIOTIC_METABOLISM</td>
#       <td id="T_0d7de_row2_col2" class="data row2 col2" >-0.478665</td>
#       <td id="T_0d7de_row2_col3" class="data row2 col3" >-2.392068</td>
#       <td id="T_0d7de_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_0d7de_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_0d7de_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_0d7de_row2_col7" class="data row2 col7" >36/158</td>
#       <td id="T_0d7de_row2_col8" class="data row2 col8" >7.52%</td>
#       <td id="T_0d7de_row2_col9" class="data row2 col9" >SPINT2;TGFB2;CDA;PAPSS2;PC;PYCR1;AOX1;PINK1;SLC1A5;ETS2;AHCY;PGD;PGRMC1;PTGES;JUP;PTGR1;CBR1;GART;VTN;EPHA2;LONP1;CYB5A;FBP1;KARS1;RAP1GAP;SMOX;GCNT2;HPRT1;MAN1A1;BCAT1;ITIH4;UPP1;DHPS;COMT;DCXR;NPC1</td>
#     </tr>
#     <tr>
#       <th id="T_0d7de_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0d7de_row3_col0" class="data row3 col0" >gsea</td>
#       <td id="T_0d7de_row3_col1" class="data row3 col1" >HALLMARK_APICAL_JUNCTION</td>
#       <td id="T_0d7de_row3_col2" class="data row3 col2" >-0.445569</td>
#       <td id="T_0d7de_row3_col3" class="data row3 col3" >-2.260990</td>
#       <td id="T_0d7de_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_0d7de_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_0d7de_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_0d7de_row3_col7" class="data row3 col7" >43/163</td>
#       <td id="T_0d7de_row3_col8" class="data row3 col8" >8.82%</td>
#       <td id="T_0d7de_row3_col9" class="data row3 col9" >ICAM1;MYH10;CDH11;ACTG1;LIMA1;CDH4;INSIG1;CAP1;TIAL1;JUP;ACTB;LAYN;ITGB4;PPP2R2C;CNN2;ADAM9;CLDN7;FLNC;YWHAH;FSCN1;DLG1;VCAM1;MYH9;ACTN4;ACTN1;SORBS3;CDH1;IKBKG;EXOC4;CLDN11;PFN1;GRB7;MSN;ICAM5;EGFR;NEGR1;ZYX;LDLRAP1;TGFBI;NECTIN2;NEXN;ADAM23;AKT2</td>
#     </tr>
#     <tr>
#       <th id="T_0d7de_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0d7de_row4_col0" class="data row4 col0" >gsea</td>
#       <td id="T_0d7de_row4_col1" class="data row4 col1" >HALLMARK_ESTROGEN_RESPONSE_EARLY</td>
#       <td id="T_0d7de_row4_col2" class="data row4 col2" >-0.480687</td>
#       <td id="T_0d7de_row4_col3" class="data row4 col3" >-2.239042</td>
#       <td id="T_0d7de_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_0d7de_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_0d7de_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_0d7de_row4_col7" class="data row4 col7" >53/181</td>
#       <td id="T_0d7de_row4_col8" class="data row4 col8" >11.41%</td>
#       <td id="T_0d7de_row4_col9" class="data row4 col9" >SLC2A1;UGCG;KRT8;KRT19;PAPSS2;WWC1;KRT18;INHBB;DHCR7;SLC7A5;FHL2;CCND1;ZNF185;PTGES;ELF3;ITPK1;RAB17;KAZN;CELSR1;CLDN7;ADD3;SFN;FASN;RPS6KA2;MUC1;CLIC3;PLAAT3;DHRS3;PPIF;CYP26B1;SYT12;SCNN1A;ESRP2;MYBL1;GJA1;INPP5F;TIAM1;FDFT1;RHOD;TPD52L1;SLC37A1;AQP3;FLNB;CALCR;MYBBP1A;ADCY9;NCOR2;GLA;TMPRSS3;SEMA3B;NADSYN1;TTC39A;SCARB1</td>
#     </tr>
#     <tr>
#       <th id="T_0d7de_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0d7de_row5_col0" class="data row5 col0" >gsea</td>
#       <td id="T_0d7de_row5_col1" class="data row5 col1" >HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION</td>
#       <td id="T_0d7de_row5_col2" class="data row5 col2" >-0.465643</td>
#       <td id="T_0d7de_row5_col3" class="data row5 col3" >-2.220440</td>
#       <td id="T_0d7de_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_0d7de_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_0d7de_row5_col6" class="data row5 col6" >0.000000</td>
#       <td id="T_0d7de_row5_col7" class="data row5 col7" >48/173</td>
#       <td id="T_0d7de_row5_col8" class="data row5 col8" >8.98%</td>
#       <td id="T_0d7de_row5_col9" class="data row5 col9" >FSTL1;DKK1;MATN2;TIMP3;CDH11;COL6A2;MEST;THBS1;FLNA;NNMT;MYLK;COL1A2;LOXL2;INHBA;TPM1;COL12A1;PVR;CXCL8;CXCL1;P3H1;COL5A1;BASP1;CALD1;COL4A1;SERPINH1;PDGFRB;SNAI2;SAT1;CALU;OXTR;PTX3;FZD8;ABI3BP;PLOD2;VCAM1;CCN1;GPC1;QSOX1;GJA1;SDC1;MMP1;ITGB3;COL4A2;VIM;TGFBI;FSTL3;ENO2;EDIL3</td>
#     </tr>
#     <tr>
#       <th id="T_0d7de_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0d7de_row6_col0" class="data row6 col0" >gsea</td>
#       <td id="T_0d7de_row6_col1" class="data row6 col1" >HALLMARK_UNFOLDED_PROTEIN_RESPONSE</td>
#       <td id="T_0d7de_row6_col2" class="data row6 col2" >-0.503866</td>
#       <td id="T_0d7de_row6_col3" class="data row6 col3" >-2.196935</td>
#       <td id="T

# %% [markdown]
# If we want to plot multiple GSEA plots (say of our top 5 most significant hits), we can make use of a for loop:

# %%
#Plotting just one GSEA plot
fig = gs_res.plot(gs_res.res2d.Term[20])

fig.set_size_inches(4, 5)

fig.savefig('../Week_10/functional-analysis/GSEA_HALLMARK_IL2_STAT5_SIGNALING_plot.pdf',
            bbox_inches='tight',
           )

# %% [markdown]
# Another way of looking at multiple GSEA terms is to plot them all together onto a single GSEA plot. We'll use the same function as before but instead of providing it with a single term, we can provide a list of terms:

# %%
gs_res.res2d.sort_values(by='FDR q-val', inplace=True)

# %%
gs_res.res2d.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_51f67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51f67_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_51f67_level0_col1" class="col_heading level0 col1" >Term</th>
#       <th id="T_51f67_level0_col2" class="col_heading level0 col2" >ES</th>
#       <th id="T_51f67_level0_col3" class="col_heading level0 col3" >NES</th>
#       <th id="T_51f67_level0_col4" class="col_heading level0 col4" >NOM p-val</th>
#       <th id="T_51f67_level0_col5" class="col_heading level0 col5" >FDR q-val</th>
#       <th id="T_51f67_level0_col6" class="col_heading level0 col6" >FWER p-val</th>
#       <th id="T_51f67_level0_col7" class="col_heading level0 col7" >Tag %</th>
#       <th id="T_51f67_level0_col8" class="col_heading level0 col8" >Gene %</th>
#       <th id="T_51f67_level0_col9" class="col_heading level0 col9" >Lead_genes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51f67_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_51f67_row0_col0" class="data row0 col0" >gsea</td>
#       <td id="T_51f67_row0_col1" class="data row0 col1" >HALLMARK_HYPOXIA</td>
#       <td id="T_51f67_row0_col2" class="data row0 col2" >-0.541378</td>
#       <td id="T_51f67_row0_col3" class="data row0 col3" >-2.437251</td>
#       <td id="T_51f67_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_51f67_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_51f67_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_51f67_row0_col7" class="data row0 col7" >58/177</td>
#       <td id="T_51f67_row0_col8" class="data row0 col8" >8.36%</td>
#       <td id="T_51f67_row0_col9" class="data row0 col9" >F3;CAV1;SLC2A1;ENO1;PLAC8;EXT1;VLDLR;ERRFI1;ANXA2;PGK1;NDRG1;AK4;PFKP;ALDOC;SELENBP1;GPI;SAP30;SDC2;COL5A1;PGF;PGM1;HK2;MT1E;ADM;IDS;XPNPEP1;GAPDH;ACKR3;NEDD4L;FBP1;PDGFB;PFKL;CAVIN1;CITED2;HK1;MYH9;TPI1;MXI1;CCN1;GPC1;NFIL3;TMEM45A;GCNT2;HSPA5;LDHA;EDN2;PPFIA4;TPD52;TPST2;ERO1A;DDIT4;NDST1;EGFR;PDK1;HDLBP;SLC25A1;PFKFB3;TGFBI</td>
#     </tr>
#     <tr>
#       <th id="T_51f67_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_51f67_row1_col0" class="data row1 col0" >gsea</td>
#       <td id="T_51f67_row1_col1" class="data row1 col1" >HALLMARK_MTORC1_SIGNALING</td>
#       <td id="T_51f67_row1_col2" class="data row1 col2" >-0.568454</td>
#       <td id="T_51f67_row1_col3" class="data row1 col3" >-2.394979</td>
#       <td id="T_51f67_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_51f67_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_51f67_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_51f67_row1_col7" class="data row1 col7" >71/196</td>
#       <td id="T_51f67_row1_col8" class="data row1 col8" >11.98%</td>
#       <td id="T_51f67_row1_col9" class="data row1 col9" >SLC2A1;HSPD1;ENO1;CALR;FADS2;DHCR24;SCD;G6PD;DHCR7;VLDLR;TXNRD1;INSIG1;PGK1;SLC7A5;SLC1A5;AK4;GPI;EGLN3;PGM1;PSAT1;ADD3;HK2;AURKA;EIF2S2;SERPINH1;LDLR;GAPDH;STIP1;RRM2;PRDX1;PFKL;PPA1;PLK1;PLOD2;TRIB3;TPI1;FADS1;STARD4;NFIL3;SERP1;NFYC;IFI30;EPRS1;HSPA5;HPRT1;LDHA;PSMG1;BCAT1;DHFR;ITGB2;DDX39A;ERO1A;DDIT4;CYB5B;RPA1;RDH11;PDK1;CTH;ADIPOR2;SHMT2;MTHFD2;GLA;LTA4H;ACACA;EBP;CCNG1;CCNF;HSP90B1;ELOVL6;PHGDH;PSMB5</td>
#     </tr>
#     <tr>
#       <th id="T_51f67_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_51f67_row2_col0" class="data row2 col0" >gsea</td>
#       <td id="T_51f67_row2_col1" class="data row2 col1" >HALLMARK_XENOBIOTIC_METABOLISM</td>
#       <td id="T_51f67_row2_col2" class="data row2 col2" >-0.478665</td>
#       <td id="T_51f67_row2_col3" class="data row2 col3" >-2.392068</td>
#       <td id="T_51f67_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_51f67_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_51f67_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_51f67_row2_col7" class="data row2 col7" >36/158</td>
#       <td id="T_51f67_row2_col8" class="data row2 col8" >7.52%</td>
#       <td id="T_51f67_row2_col9" class="data row2 col9" >SPINT2;TGFB2;CDA;PAPSS2;PC;PYCR1;AOX1;PINK1;SLC1A5;ETS2;AHCY;PGD;PGRMC1;PTGES;JUP;PTGR1;CBR1;GART;VTN;EPHA2;LONP1;CYB5A;FBP1;KARS1;RAP1GAP;SMOX;GCNT2;HPRT1;MAN1A1;BCAT1;ITIH4;UPP1;DHPS;COMT;DCXR;NPC1</td>
#     </tr>
#     <tr>
#       <th id="T_51f67_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_51f67_row3_col0" class="data row3 col0" >gsea</td>
#       <td id="T_51f67_row3_col1" class="data row3 col1" >HALLMARK_APICAL_JUNCTION</td>
#       <td id="T_51f67_row3_col2" class="data row3 col2" >-0.445569</td>
#       <td id="T_51f67_row3_col3" class="data row3 col3" >-2.260990</td>
#       <td id="T_51f67_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_51f67_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_51f67_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_51f67_row3_col7" class="data row3 col7" >43/163</td>
#       <td id="T_51f67_row3_col8" class="data row3 col8" >8.82%</td>
#       <td id="T_51f67_row3_col9" class="data row3 col9" >ICAM1;MYH10;CDH11;ACTG1;LIMA1;CDH4;INSIG1;CAP1;TIAL1;JUP;ACTB;LAYN;ITGB4;PPP2R2C;CNN2;ADAM9;CLDN7;FLNC;YWHAH;FSCN1;DLG1;VCAM1;MYH9;ACTN4;ACTN1;SORBS3;CDH1;IKBKG;EXOC4;CLDN11;PFN1;GRB7;MSN;ICAM5;EGFR;NEGR1;ZYX;LDLRAP1;TGFBI;NECTIN2;NEXN;ADAM23;AKT2</td>
#     </tr>
#     <tr>
#       <th id="T_51f67_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_51f67_row4_col0" class="data row4 col0" >gsea</td>
#       <td id="T_51f67_row4_col1" class="data row4 col1" >HALLMARK_ESTROGEN_RESPONSE_EARLY</td>
#       <td id="T_51f67_row4_col2" class="data row4 col2" >-0.480687</td>
#       <td id="T_51f67_row4_col3" class="data row4 col3" >-2.239042</td>
#       <td id="T_51f67_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_51f67_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_51f67_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_51f67_row4_col7" class="data row4 col7" >53/181</td>
#       <td id="T_51f67_row4_col8" class="data row4 col8" >11.41%</td>
#       <td id="T_51f67_row4_col9" class="data row4 col9" >SLC2A1;UGCG;KRT8;KRT19;PAPSS2;WWC1;KRT18;INHBB;DHCR7;SLC7A5;FHL2;CCND1;ZNF185;PTGES;ELF3;ITPK1;RAB17;KAZN;CELSR1;CLDN7;ADD3;SFN;FASN;RPS6KA2;MUC1;CLIC3;PLAAT3;DHRS3;PPIF;CYP26B1;SYT12;SCNN1A;ESRP2;MYBL1;GJA1;INPP5F;TIAM1;FDFT1;RHOD;TPD52L1;SLC37A1;AQP3;FLNB;CALCR;MYBBP1A;ADCY9;NCOR2;GLA;TMPRSS3;SEMA3B;NADSYN1;TTC39A;SCARB1</td>
#     </tr>
#     <tr>
#       <th id="T_51f67_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_51f67_row5_col0" class="data row5 col0" >gsea</td>
#       <td id="T_51f67_row5_col1" class="data row5 col1" >HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION</td>
#       <td id="T_51f67_row5_col2" class="data row5 col2" >-0.465643</td>
#       <td id="T_51f67_row5_col3" class="data row5 col3" >-2.220440</td>
#       <td id="T_51f67_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_51f67_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_51f67_row5_col6" class="data row5 col6" >0.000000</td>
#       <td id="T_51f67_row5_col7" class="data row5 col7" >48/173</td>
#       <td id="T_51f67_row5_col8" class="data row5 col8" >8.98%</td>
#       <td id="T_51f67_row5_col9" class="data row5 col9" >FSTL1;DKK1;MATN2;TIMP3;CDH11;COL6A2;MEST;THBS1;FLNA;NNMT;MYLK;COL1A2;LOXL2;INHBA;TPM1;COL12A1;PVR;CXCL8;CXCL1;P3H1;COL5A1;BASP1;CALD1;COL4A1;SERPINH1;PDGFRB;SNAI2;SAT1;CALU;OXTR;PTX3;FZD8;ABI3BP;PLOD2;VCAM1;CCN1;GPC1;QSOX1;GJA1;SDC1;MMP1;ITGB3;COL4A2;VIM;TGFBI;FSTL3;ENO2;EDIL3</td>
#     </tr>
#     <tr>
#       <th id="T_51f67_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_51f67_row6_col0" class="data row6 col0" >gsea</td>
#       <td id="T_51f67_row6_col1" class="data row6 col1" >HALLMARK_UNFOLDED_PROTEIN_RESPONSE</td>
#       <td id="T_51f67_row6_col2" class="data row6 col2" >-0.503866</td>
#       <td id="T_51f67_row6_col3" class="data row6 col3" >-2.196935</td>
#       <td id="T

# %%
#For loop to plot multiple GSEA plots
for i in range(0, 5, 1):
    fig = gs_res.plot(gs_res.res2d.Term[i])
    fig.set_size_inches(4, 6)

# %%
#We can also pass along a list of Terms to then plot multiple terms on a single GSEA plot overlaid
fig = gs_res.plot(gs_res.res2d.Term[:5])

fig.set_size_inches(6,6)

# %% [markdown]
# <h2>Generate heatmap of leading edge genes</h2>

# %% [markdown]
# The leading edge of a GSEA plot are the genes that have contributed to the "peak" enrichment score of a term, and we can pull them out of our results matrix to generate a heatmap of their relative expression levels between our two conditions. To do this, we'll first need to pull out each of the genes identified as a leading edge gene for a term of interest:

# %%
gs_res.res2d
# Out:
#     Name                                        Term        ES       NES  \
# 0   gsea                            HALLMARK_HYPOXIA -0.541378 -2.437251
# 1   gsea                   HALLMARK_MTORC1_SIGNALING -0.568454 -2.394979
# 2   gsea              HALLMARK_XENOBIOTIC_METABOLISM -0.478665 -2.392068
# 3   gsea                    HALLMARK_APICAL_JUNCTION -0.445569  -2.26099
# 4   gsea            HALLMARK_ESTROGEN_RESPONSE_EARLY -0.480687 -2.239042
# 5   gsea  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION -0.465643  -2.22044
# 6   gsea          HALLMARK_UNFOLDED_PROTEIN_RESPONSE -0.503866 -2.196935
# 7   gsea            HALLMARK_CHOLESTEROL_HOMEOSTASIS  -0.56626 -2.159681
# 8   gsea                         HALLMARK_GLYCOLYSIS -0.437329 -2.123528
# 12  gsea                     HALLMARK_G2M_CHECKPOINT -0.524794 -2.042348
# 11  gsea                     HALLMARK_UV_RESPONSE_DN -0.450964 -2.067952
# 10  gsea                        HALLMARK_E2F_TARGETS -0.579016 -2.071134
# 13  gsea             HALLMARK_ESTROGEN_RESPONSE_LATE -0.442408 -2.040362
# 9   gsea          HALLMARK_INTERFERON_ALPHA_RESPONSE  0.553577  2.113095
# 14  gsea                     HALLMARK_MYC_TARGETS_V1  -0.61392 -1.992562
# 15  gsea                HALLMARK_ALLOGRAFT_REJECTION  -0.38901 -1.984094
# 16  gsea            HALLMARK_PI3K_AKT_MTOR_SIGNALING  -0.41823 -1.964983
# 19  gsea                  HALLMARK_ANDROGEN_RESPONSE -0.465108 -1.926777
# 18  gsea                         HALLMARK_MYOGENESIS -0.379444 -1.933435
# 22  gsea                          HALLMARK_APOPTOSIS -0.339715 -1.884988
# 21  gsea              HALLMARK_INFLAMMATORY_RESPONSE -0.382299 -1.886326
# 23  gsea                       HALLMARK_ADIPOGENESIS -0.365979 -1.860194
# 24  gsea                         HALLMARK_PEROXISOME -0.386682  -1.82986
# 20  gsea                HALLMARK_IL2_STAT5_SIGNALING  0.412261  1.905653
# 26  gsea                     HALLMARK_MYC_TARGETS_V2 -0.514232 -1.809506
# 17  gsea          HALLMARK_INTERFERON_GAMMA_RESPONSE  0.401863  1.939322
# 25  gsea                  HALLMARK_KRAS_SIGNALING_UP  0.423498  1.818937
# 27  gsea                    HALLMARK_MITOTIC_SPINDLE -0.401173 -1.712999
# 28  gsea                    HALLMARK_HEME_METABOLISM -0.306495 -1.652698
# 29  gsea                 HALLMARK_HEDGEHOG_SIGNALING -0.439619 -1.636869
# 31  gsea              HALLMARK_FATTY_ACID_METABOLISM  -0.34684  -1.59589
# 33  gsea                         HALLMARK_COMPLEMENT -0.298437 -1.552569
# 35  gsea                     HALLMARK_UV_RESPONSE_UP  -0.30291 -1.514061
# 30  gsea                     HALLMARK_APICAL_SURFACE  0.424429  1.601526
# 36  gsea                        HALLMARK_P53_PATHWAY -0.288734 -1.495035
# 32  gsea            HALLMARK_TNFA_SIGNALING_VIA_NFKB  0.335274  1.561547
# 38  gsea                         HALLMARK_DNA_REPAIR -0.331978 -1.470496
# 34  gsea                        HALLMARK_COAGULATION  0.338584  1.521259
# 37  gsea                 HALLMARK_TGF_BETA_SIGNALING  0.379876  1.489886
# 40  gsea                  HALLMARK_PROTEIN_SECRETION -0.310881 -1.423843
# 39  gsea               HALLMARK_BILE_ACID_METABOLISM -0.311241 -1.424891
# 41  gsea         HALLMARK_WNT_BETA_CATENIN_SIGNALING -0.331435 -1.393421
# 44  gsea                HALLMARK_PANCREAS_BETA_CELLS -0.443163 -1.365129
# 43  gsea    HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY  0.363394  1.371411
# 42  gsea                       HALLMARK_ANGIOGENESIS  0.387734  1.380714
# 45  gsea                    HALLMARK_NOTCH_SIGNALING -0.322226 -1.274948
# 46  gsea          HALLMARK_OXIDATIVE_PHOSPHORYLATION -0.310957 -1.120973
# 47  gsea            HALLMARK_IL6_JAK_STAT3_SIGNALING  0.268949   1.10491
# 49  gsea                  HALLMARK_KRAS_SIGNALING_DN  0.195857  0.901821
# 48  gsea                    HALLMARK_SPERMATOGENESIS  0.208671  0.907714
#
#    NOM p-val FDR q-val FWER p-val   Tag %  Gene %  \
# 0        0.0       0.0        0.0  58/177   8.36%
# 1        0.0       0.0        0.0  71/196  11.98%
# 2        0.0       0.0        0.0  36/158   7.52%
# 3        0.0       0.0        0.0  43/163   8.82%
# 4        0.0       0.0        0.0  53/181  11.41%
# 5        0.0       0.0        0.0  48/173   8.98%
# 6        0.0       0.0        0.0  44/110  15.65%
# 7        0.0       0.0        0.0   29/70  12.52%
# 8        0.0  0.000165      0.001  48/184   9.16%
# 12       0.0  0.000247      0.002  79/197  15.25%
# 11       0.0  0.000269      0.002  35/138  11.39%
# 10       0.0  0.000296      0.002  97/199  18.01%
# 13       0.0  0.000342      0.003  55/179  12.78%
# 9        0.0   0.00052      0.001   32/96   9.31%
# 14  0.002062  0.000529      0.004  95/198  16.45%
# 15       0.0  0.000592      0.004  27/132  10.41%
# 16       0.0  0.000925      0.007   30/93  15.03%
# 19       0.0  0.001152      0.011   23/98   8.56%
# 18       0.0  0.001219      0.011  35/141  10.84%
# 22       0.0  0.002295      0.024  37/144  12.65%
# 21       0.0  0.002338      0.023  33/151  10.75%
# 23       0.0  0.003384      0.038  42/187  11.41%
# 24       0.0  0.004913      0.053   24/88  16.58%
# 20       0.0  0.005198       0.02  47/166  12.01%
# 26  0.002053  0.005858      0.064   23/57  22.33%
# 17       0.0  0.005978      0.014  46/176   9.31%
# 25       0.0  0.009876      0.043  51/157  14.56%
# 27  0.013514  0.013942      0.127  59/198  14.21%
# 28       0.0  0.022327      0.203  32/173  11.49%
# 29  0.021696  0.024145      0.221    9/33   5.06%
# 31  0.005894  0.033012      0.297  32/138  13.37%
# 33  0.001957   0.04373      0.354  26/160   9.97%
# 35  0.023305  0.054782      0.418  34/140  15.46%
# 30  0.023605  0.057905      0.267    9/32   5.10%
# 36   0.00789  0.059421      0.446  44/188  14.61%
# 32  0.045635  0.064627      0.346  26/188   3.86%
# 38  0.058947  0.066006      0.492  46/148  23.21%
# 34  0.016194  0.073662      0.434   16/99   3.17%
# 37  0.055336  0.078943      0.496   18/52  13.01%
# 40  0.081633  0.081029      0.591   17/95   9.63%
# 39  0.031683  0.082867      0.586   13/84   9.75%
# 41  0.041667  0.092581      0.654    6/39  10.41%
# 44  0.106996  0.103599       0.71    2/16   2.51%
# 43  0.117878  0.122879      0.708   10/47   6.77%
# 42  0.095918  0.130352      0.689    8/29   4.74%
# 45  0.126706  0.156532      0.857    3/30   1.75%
# 46   0.35625  0.296078      0.966  62/200  23.38%
# 47  0.302905  0.372407      0.974   11/68   8.36%
# 49  0.702041  0.602639        1.0  17/104  12.22%
# 48  0.606119  0.642246        1.0   24/78  22.19%
#
#                                            Lead_genes
# 0   F3;CAV1;SLC2A1;ENO1;PLAC8;EXT1;VLDLR;ERRFI1;AN...
# 1   SLC2A1;HSPD1;ENO1;CALR;FADS2;DHCR24;SCD;G6PD;D...
# 2   SPINT2;TGFB2;CDA;PAPSS2;PC;PYCR1;AOX1;PINK1;SL...
# 3   ICAM1;MYH10;CDH11;ACTG1;LIMA1;CDH4;INSIG1;CAP1...
# 4   SLC2A1;UGCG;KRT8;KRT19;PAPSS2;WWC1;KRT18;INHBB...
# 5   FSTL1;DKK1;MATN2;TIMP3;CDH11;COL6A2;MEST;THBS1...
# 6   CALR;SLC7A5;EEF2;DKC1;KHSRP;PSAT1;SRPRB;FUS;BA...
# 7   FADS2;ACTG1;SCD;DHCR7;ERRFI1;LSS;ALDOC;MAL2;GS...
# 8   ENO1;EXT1;PRPS1;PC;PKM;G6PD;VLDLR;PGK1;ARTN;AK...
# 12  HMGN2;HMGB3;MYBL2;KIF2C;SLC7A5;CDC20;CCND1;STM...
# 11  F3;CAV1;EFEMP1;VLDLR;INSIG1;ANXA2;COL1A2;FHL2;...
# 10  HMGB3;MYBL2;PRPS1;CDCA8;KIF2C;CDC20;HMGB2;STMN...
# 13  CAV1;TRIM29;MEST;CKB;KRT19;PAPSS2;DHCR7;SLC7A5...
# 9   IFIT3;IFI44;IFIT2;HERC6;SAMD9;RSAD2;IFIH1;B2M;...
# 14  HSPD1;PABPC4;PGK1;VBP1;PRDX3;EIF3B;CDC20;PABPC...
# 15  ICAM1;IL11;TGFB2;FLNA;INHBB;SRGN;INHBA;ELF4;RP...
# 16  SLC2A1;CALR;RPS6KA1;AKT1;SFN;PPP1CA;NGF;MKNK2;...
# 19  KRT8;SMS;KRT19;H1-0;DHCR24;SCD;INSIG1;UAP1;NDR...
# 18  FST;COL6A2;CKB;PC;WWTR1;SCD;APP;MYLK;SPDEF;ATP...
# 22  CAV1;TIMP3;TGFB2;H1-0;TNFSF10;KRT18;APP;HMGB2;...
# 21  F3;ICAM1;BST2;TNFSF10;INHBA;SLC4A4;AXL;CD55;PV...
# 23  UCP2;DHCR7;MYLK;SLC1A5;PRDX3;IDH3G;RTN3;SCP2;P...
# 24  DHCR24;PABPC1;ACSL4;SCP2;CTPS1;YWHAH;PRDX1;SOD...
# 20  PRNP;NT5E;TGM2;TNFRSF1B;EMP1;SPRY4;ITGA6;CD44;...
# 26  HSPD1;HK2;PLK1;MAP3K6;NOP2;SRM;PA2G4;NOLC1;SLC...
# 17  IFIT3;IFI44;IFIT2;HERC6;NAMPT;CDKN1A;ST8SIA4;I...
# 25  PLAU;GFPT2;ITGA2;TNFRSF1B;KCNN4;PLAT;EMP1;PLAU...
# 27  MYH10;FLNA;KIF2C;CAPZB;PCNT;NEDD9;TPX2;PALLD;C...
# 28  SLC2A1;UCP2;PC;H1-0;MPP1;SELENBP1;PDZK1IP1;SEC...
# 29   VLDLR;L1CAM;ETS2;AMOT;NRP2;CELSR1;MYH9;SHH;PTCH1
# 31  SMS;DHCR24;TP53INP2;ACSL4;IDH3G;GLUL;MGLL;CBR1...
# 33  F3;CDA;CALM3;C4BPB;PCSK9;CD55;CXCL1;FYN;C3;F8;...
# 35  ICAM1;C4BPB;STIP1;PPT1;CREG1;PPIF;CDK2;SLC25A4...
# 30  CX3CL1;PLAUR;SRPX;DCBLD2;MDGA1;GSTM3;BRCA1;AKA...
# 36  PRMT2;INHBB;IRAK1;PLK2;APP;NDRG1;ITGB4;SFN;EPH...
# 32  PLAU;KYNU;PMEPA1;GFPT2;SQSTM1;IFIT2;NAMPT;LAMB...
# 38  CDA;SF3A3;BCAP31;RALA;ARL6IP1;TYMS;IMPDH2;NME4...
# 34  PLAU;ITGA2;SERPINA1;PLAT;GSN;THBD;CAPN2;SERPIN...
# 37  SLC20A1;PMEPA1;SERPINE1;LTBP2;FURIN;BCAR3;APC;...
# 40  BNIP3;KRT18;CAV2;OCRL;PPT1;SOD1;AP2M1;RER1;LAM...
# 39  FADS2;DHCR24;HSD3B1;SCP2;DIO2;SOD1;ACSL1;FADS1...
# 41                    DKK1;FZD8;PTCH1;JAG2;NCOR2;LEF1
# 44                                        FOXA2;SRPRB
# 43  PRNP;GPX3;SOD2;CAT;NQO1;TXNRD2;PTPA;MBP;GLRX;GCLC
# 42     THBD;VEGFA;TNFRSF21;STC1;NRP1;ITGAV;TIMP1;VCAN
# 45                                   FZD7;CCND1;SAP30
# 46  ATP1B1;PRDX3;SLC25A5;ATP6AP1;GPI;IDH3G;ATP5F1A...
# 47  TNFRSF1B;CD44;TNFRSF21;IFNGR1;IL17RA;STAM2;TGF...
# 49  RSAD2;NR4A2;CAMK1D;SPTBN2;C5;SLC25A23;TENT5C;T...
# 48  HSPA4L;GSTM3;TALDO1;IDE;STAM2;BUB1;CCNA1;MAP7;...

# %% [markdown]
# This line of code pulls out the string containing the gene names of the leading edge genes for our top GSEA result, and since the gene names are all a single value in the data matrix separated by a semicolon, we can split them apart from each other with the <code>str.split()</code> function, where <code>str</code> is replaced with the string we want to split up into a list.
#
# Let's take a look at our leading edge gene names:

# %%
genes = gs_res.res2d.Lead_genes[20].split(';')

# %%
genes[0:5]
# Out:
# ['PRNP', 'NT5E', 'TGM2', 'TNFRSF1B', 'EMP1']

# %% [markdown]
# We can pass this list to an organized counts matrix generated by <code>gp.GSEA()</code> and contained within the output <code>gs_res</code> object. So we use this list to pull out just the normalized count data for the genes contributing to the leading edge while passing it to <code>gp.heatmap()</code> for visualization.

# %%
gs_res.heatmat.loc[genes].head().style
# Out:
# <style type="text/css">
# </style>
# <table id="T_ac7bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac7bc_level0_col0" class="col_heading level0 col0" >tazko_g1</th>
#       <th id="T_ac7bc_level0_col1" class="col_heading level0 col1" >tazko_g2</th>
#       <th id="T_ac7bc_level0_col2" class="col_heading level0 col2" >tazko_g3</th>
#       <th id="T_ac7bc_level0_col3" class="col_heading level0 col3" >tazko_g4</th>
#       <th id="T_ac7bc_level0_col4" class="col_heading level0 col4" >tazko_g5</th>
#       <th id="T_ac7bc_level0_col5" class="col_heading level0 col5" >tazko_g6</th>
#       <th id="T_ac7bc_level0_col6" class="col_heading level0 col6" >tazko_g7</th>
#       <th id="T_ac7bc_level0_col7" class="col_heading level0 col7" >tazko_g8</th>
#       <th id="T_ac7bc_level0_col8" class="col_heading level0 col8" >tazko_g9</th>
#       <th id="T_ac7bc_level0_col9" class="col_heading level0 col9" >ctrl_g1</th>
#       <th id="T_ac7bc_level0_col10" class="col_heading level0 col10" >ctrl_g2</th>
#       <th id="T_ac7bc_level0_col11" class="col_heading level0 col11" >ctrl_g3</th>
#       <th id="T_ac7bc_level0_col12" class="col_heading level0 col12" >ctrl_g4</th>
#       <th id="T_ac7bc_level0_col13" class="col_heading level0 col13" >ctrl_g5</th>
#       <th id="T_ac7bc_level0_col14" class="col_heading level0 col14" >ctrl_g6</th>
#       <th id="T_ac7bc_level0_col15" class="col_heading level0 col15" >ctrl_g7</th>
#       <th id="T_ac7bc_level0_col16" class="col_heading level0 col16" >ctrl_g8</th>
#       <th id="T_ac7bc_level0_col17" class="col_heading level0 col17" >ctrl_g9</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >gene</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac7bc_level0_row0" class="row_heading level0 row0" >PRNP</th>
#       <td id="T_ac7bc_row0_col0" class="data row0 col0" >809.624047</td>
#       <td id="T_ac7bc_row0_col1" class="data row0 col1" >889.833434</td>
#       <td id="T_ac7bc_row0_col2" class="data row0 col2" >943.995934</td>
#       <td id="T_ac7bc_row0_col3" class="data row0 col3" >918.687858</td>
#       <td id="T_ac7bc_row0_col4" class="data row0 col4" >814.314169</td>
#       <td id="T_ac7bc_row0_col5" class="data row0 col5" >865.568308</td>
#       <td id="T_ac7bc_row0_col6" class="data row0 col6" >892.532415</td>
#       <td id="T_ac7bc_row0_col7" class="data row0 col7" >934.715887</td>
#       <td id="T_ac7bc_row0_col8" class="data row0 col8" >1035.483505</td>
#       <td id="T_ac7bc_row0_col9" class="data row0 col9" >319.808666</td>
#       <td id="T_ac7bc_row0_col10" class="data row0 col10" >329.201026</td>
#       <td id="T_ac7bc_row0_col11" class="data row0 col11" >318.244173</td>
#       <td id="T_ac7bc_row0_col12" class="data row0 col12" >297.799879</td>
#       <td id="T_ac7bc_row0_col13" class="data row0 col13" >318.434863</td>
#       <td id="T_ac7bc_row0_col14" class="data row0 col14" >291.657322</td>
#       <td id="T_ac7bc_row0_col15" class="data row0 col15" >340.088530</td>
#       <td id="T_ac7bc_row0_col16" class="data row0 col16" >298.295749</td>
#       <td id="T_ac7bc_row0_col17" class="data row0 col17" >318.546219</td>
#     </tr>
#     <tr>
#       <th id="T_ac7bc_level0_row1" class="row_heading level0 row1" >NT5E</th>
#       <td id="T_ac7bc_row1_col0" class="data row1 col0" >695.142175</td>
#       <td id="T_ac7bc_row1_col1" class="data row1 col1" >631.347115</td>
#       <td id="T_ac7bc_row1_col2" class="data row1 col2" >665.351912</td>
#       <td id="T_ac7bc_row1_col3" class="data row1 col3" >666.789574</td>
#       <td id="T_ac7bc_row1_col4" class="data row1 col4" >632.623262</td>
#       <td id="T_ac7bc_row1_col5" class="data row1 col5" >582.857508</td>
#       <td id="T_ac7bc_row1_col6" class="data row1 col6" >733.575772</td>
#       <td id="T_ac7bc_row1_col7" class="data row1 col7" >681.792764</td>
#       <td id="T_ac7bc_row1_col8" class="data row1 col8" >769.421771</td>
#       <td id="T_ac7bc_row1_col9" class="data row1 col9" >423.100906</td>
#       <td id="T_ac7bc_row1_col10" class="data row1 col10" >349.534030</td>
#       <td id="T_ac7bc_row1_col11" class="data row1 col11" >394.963750</td>
#       <td id="T_ac7bc_row1_col12" class="data row1 col12" >348.793009</td>
#       <td id="T_ac7bc_row1_col13" class="data row1 col13" >398.043579</td>
#       <td id="T_ac7bc_row1_col14" class="data row1 col14" >415.419804</td>
#       <td id="T_ac7bc_row1_col15" class="data row1 col15" >370.039509</td>
#       <td id="T_ac7bc_row1_col16" class="data row1 col16" >417.420350</td>
#       <td id="T_ac7bc_row1_col17" class="data row1 col17" >399.258944</td>
#     </tr>
#     <tr>
#       <th id="T_ac7bc_level0_row2" class="row_heading level0 row2" >TGM2</th>
#       <td id="T_ac7bc_row2_col0" class="data row2 col0" >1090.156201</td>
#       <td id="T_ac7bc_row2_col1" class="data row2 col1" >1061.395150</td>
#       <td id="T_ac7bc_row2_col2" class="data row2 col2" >1020.801658</td>
#       <td id="T_ac7bc_row2_col3" class="data row2 col3" >1017.780197</td>
#       <td id="T_ac7bc_row2_col4" class="data row2 col4" >980.001213</td>
#       <td id="T_ac7bc_row2_col5" class="data row2 col5" >1122.125245</td>
#       <td id="T_ac7bc_row2_col6" class="data row2 col6" >1035.045267</td>
#       <td id="T_ac7bc_row2_col7" class="data row2 col7" >1023.605535</td>
#       <td id="T_ac7bc_row2_col8" class="data row2 col8" >1071.437794</td>
#       <td id="T_ac7bc_row2_col9" class="data row2 col9" >656.501641</td>
#       <td id="T_ac7bc_row2_col10" class="data row2 col10" >726.178733</td>
#       <td id="T_ac7bc_row2_col11" class="data row2 col11" >829.708022</td>
#       <td id="T_ac7bc_row2_col12" class="data row2 col12" >623.136049</td>
#       <td id="T_ac7bc_row2_col13" class="data row2 col13" >724.151571</td>
#       <td id="T_ac7bc_row2_col14" class="data row2 col14" >749.290687</td>
#       <td id="T_ac7bc_row2_col15" class="data row2 col15" >693.703309</td>
#       <td id="T_ac7bc_row2_col16" class="data row2 col16" >718.621576</td>
#       <td id="T_ac7bc_row2_col17" class="data row2 col17" >746.861743</td>
#     </tr>
#     <tr>
#       <th id="T_ac7bc_level0_row3" class="row_heading level0 row3" >TNFRSF1B</th>
#       <td id="T_ac7bc_row3_col0" class="data row3 col0" >20.627364</td>
#       <td id="T_ac7bc_row3_col1" class="data row3 col1" >21.731151</td>
#       <td id="T_ac7bc_row3_col2" class="data row3 col2" >26.792694</td>
#       <td id="T_ac7bc_row3_col3" class="data row3 col3" >19.448029</td>
#       <td id="T_ac7bc_row3_col4" class="data row3 col4" >20.710881</td>
#       <td id="T_ac7bc_row3_col5" class="data row3 col5" >21.172174</td>
#       <td id="T_ac7bc_row3_col6" class="data row3 col6" >28.319862</td>
#       <td id="T_ac7bc_row3_col7" class="data row3 col7" >23.826091</td>
#       <td id="T_ac7bc_row3_col8" class="data row3 col8" >19.774859</td>
#       <td id="T_ac7bc_row3_col9" class="data row3 col9" >3.972778</td>
#       <td id="T_ac7bc_row3_col10" class="data row3 col10" >5.809430</td>
#       <td id="T_ac7bc_row3_col11" class="data row3 col11" >9.471553</td>
#       <td id="T_ac7bc_row3_col12" class="data row3 col12" >9.178763</td>
#       <td id="T_ac7bc_row3_col13" class="data row3 col13" >3.836565</td>
#       <td id="T_ac7bc_row3_col14" class="data row3 col14" >6.715794</td>
#       <td id="T_ac7bc_row3_col15" class="data row3 col15" >4.830803</td>

# %%
gp.heatmap(df=gs_res.heatmat.loc[genes],
           z_score=0,
           title=gs_res.res2d.Term[20],
           figsize=(16,8),
           cmap='viridis',
          );

# %% [markdown]
# Like with our GSEA plots, if we want to plot our top 5 terms, we can make use of a for loop:

# %%
gs_res.res2d.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_db721">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db721_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_db721_level0_col1" class="col_heading level0 col1" >Term</th>
#       <th id="T_db721_level0_col2" class="col_heading level0 col2" >ES</th>
#       <th id="T_db721_level0_col3" class="col_heading level0 col3" >NES</th>
#       <th id="T_db721_level0_col4" class="col_heading level0 col4" >NOM p-val</th>
#       <th id="T_db721_level0_col5" class="col_heading level0 col5" >FDR q-val</th>
#       <th id="T_db721_level0_col6" class="col_heading level0 col6" >FWER p-val</th>
#       <th id="T_db721_level0_col7" class="col_heading level0 col7" >Tag %</th>
#       <th id="T_db721_level0_col8" class="col_heading level0 col8" >Gene %</th>
#       <th id="T_db721_level0_col9" class="col_heading level0 col9" >Lead_genes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db721_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_db721_row0_col0" class="data row0 col0" >gsea</td>
#       <td id="T_db721_row0_col1" class="data row0 col1" >HALLMARK_HYPOXIA</td>
#       <td id="T_db721_row0_col2" class="data row0 col2" >-0.541378</td>
#       <td id="T_db721_row0_col3" class="data row0 col3" >-2.437251</td>
#       <td id="T_db721_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_db721_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_db721_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_db721_row0_col7" class="data row0 col7" >58/177</td>
#       <td id="T_db721_row0_col8" class="data row0 col8" >8.36%</td>
#       <td id="T_db721_row0_col9" class="data row0 col9" >F3;CAV1;SLC2A1;ENO1;PLAC8;EXT1;VLDLR;ERRFI1;ANXA2;PGK1;NDRG1;AK4;PFKP;ALDOC;SELENBP1;GPI;SAP30;SDC2;COL5A1;PGF;PGM1;HK2;MT1E;ADM;IDS;XPNPEP1;GAPDH;ACKR3;NEDD4L;FBP1;PDGFB;PFKL;CAVIN1;CITED2;HK1;MYH9;TPI1;MXI1;CCN1;GPC1;NFIL3;TMEM45A;GCNT2;HSPA5;LDHA;EDN2;PPFIA4;TPD52;TPST2;ERO1A;DDIT4;NDST1;EGFR;PDK1;HDLBP;SLC25A1;PFKFB3;TGFBI</td>
#     </tr>
#     <tr>
#       <th id="T_db721_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_db721_row1_col0" class="data row1 col0" >gsea</td>
#       <td id="T_db721_row1_col1" class="data row1 col1" >HALLMARK_MTORC1_SIGNALING</td>
#       <td id="T_db721_row1_col2" class="data row1 col2" >-0.568454</td>
#       <td id="T_db721_row1_col3" class="data row1 col3" >-2.394979</td>
#       <td id="T_db721_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_db721_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_db721_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_db721_row1_col7" class="data row1 col7" >71/196</td>
#       <td id="T_db721_row1_col8" class="data row1 col8" >11.98%</td>
#       <td id="T_db721_row1_col9" class="data row1 col9" >SLC2A1;HSPD1;ENO1;CALR;FADS2;DHCR24;SCD;G6PD;DHCR7;VLDLR;TXNRD1;INSIG1;PGK1;SLC7A5;SLC1A5;AK4;GPI;EGLN3;PGM1;PSAT1;ADD3;HK2;AURKA;EIF2S2;SERPINH1;LDLR;GAPDH;STIP1;RRM2;PRDX1;PFKL;PPA1;PLK1;PLOD2;TRIB3;TPI1;FADS1;STARD4;NFIL3;SERP1;NFYC;IFI30;EPRS1;HSPA5;HPRT1;LDHA;PSMG1;BCAT1;DHFR;ITGB2;DDX39A;ERO1A;DDIT4;CYB5B;RPA1;RDH11;PDK1;CTH;ADIPOR2;SHMT2;MTHFD2;GLA;LTA4H;ACACA;EBP;CCNG1;CCNF;HSP90B1;ELOVL6;PHGDH;PSMB5</td>
#     </tr>
#     <tr>
#       <th id="T_db721_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_db721_row2_col0" class="data row2 col0" >gsea</td>
#       <td id="T_db721_row2_col1" class="data row2 col1" >HALLMARK_XENOBIOTIC_METABOLISM</td>
#       <td id="T_db721_row2_col2" class="data row2 col2" >-0.478665</td>
#       <td id="T_db721_row2_col3" class="data row2 col3" >-2.392068</td>
#       <td id="T_db721_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_db721_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_db721_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_db721_row2_col7" class="data row2 col7" >36/158</td>
#       <td id="T_db721_row2_col8" class="data row2 col8" >7.52%</td>
#       <td id="T_db721_row2_col9" class="data row2 col9" >SPINT2;TGFB2;CDA;PAPSS2;PC;PYCR1;AOX1;PINK1;SLC1A5;ETS2;AHCY;PGD;PGRMC1;PTGES;JUP;PTGR1;CBR1;GART;VTN;EPHA2;LONP1;CYB5A;FBP1;KARS1;RAP1GAP;SMOX;GCNT2;HPRT1;MAN1A1;BCAT1;ITIH4;UPP1;DHPS;COMT;DCXR;NPC1</td>
#     </tr>
#     <tr>
#       <th id="T_db721_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_db721_row3_col0" class="data row3 col0" >gsea</td>
#       <td id="T_db721_row3_col1" class="data row3 col1" >HALLMARK_APICAL_JUNCTION</td>
#       <td id="T_db721_row3_col2" class="data row3 col2" >-0.445569</td>
#       <td id="T_db721_row3_col3" class="data row3 col3" >-2.260990</td>
#       <td id="T_db721_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_db721_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_db721_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_db721_row3_col7" class="data row3 col7" >43/163</td>
#       <td id="T_db721_row3_col8" class="data row3 col8" >8.82%</td>
#       <td id="T_db721_row3_col9" class="data row3 col9" >ICAM1;MYH10;CDH11;ACTG1;LIMA1;CDH4;INSIG1;CAP1;TIAL1;JUP;ACTB;LAYN;ITGB4;PPP2R2C;CNN2;ADAM9;CLDN7;FLNC;YWHAH;FSCN1;DLG1;VCAM1;MYH9;ACTN4;ACTN1;SORBS3;CDH1;IKBKG;EXOC4;CLDN11;PFN1;GRB7;MSN;ICAM5;EGFR;NEGR1;ZYX;LDLRAP1;TGFBI;NECTIN2;NEXN;ADAM23;AKT2</td>
#     </tr>
#     <tr>
#       <th id="T_db721_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_db721_row4_col0" class="data row4 col0" >gsea</td>
#       <td id="T_db721_row4_col1" class="data row4 col1" >HALLMARK_ESTROGEN_RESPONSE_EARLY</td>
#       <td id="T_db721_row4_col2" class="data row4 col2" >-0.480687</td>
#       <td id="T_db721_row4_col3" class="data row4 col3" >-2.239042</td>
#       <td id="T_db721_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_db721_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_db721_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_db721_row4_col7" class="data row4 col7" >53/181</td>
#       <td id="T_db721_row4_col8" class="data row4 col8" >11.41%</td>
#       <td id="T_db721_row4_col9" class="data row4 col9" >SLC2A1;UGCG;KRT8;KRT19;PAPSS2;WWC1;KRT18;INHBB;DHCR7;SLC7A5;FHL2;CCND1;ZNF185;PTGES;ELF3;ITPK1;RAB17;KAZN;CELSR1;CLDN7;ADD3;SFN;FASN;RPS6KA2;MUC1;CLIC3;PLAAT3;DHRS3;PPIF;CYP26B1;SYT12;SCNN1A;ESRP2;MYBL1;GJA1;INPP5F;TIAM1;FDFT1;RHOD;TPD52L1;SLC37A1;AQP3;FLNB;CALCR;MYBBP1A;ADCY9;NCOR2;GLA;TMPRSS3;SEMA3B;NADSYN1;TTC39A;SCARB1</td>
#     </tr>
#     <tr>
#       <th id="T_db721_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_db721_row5_col0" class="data row5 col0" >gsea</td>
#       <td id="T_db721_row5_col1" class="data row5 col1" >HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION</td>
#       <td id="T_db721_row5_col2" class="data row5 col2" >-0.465643</td>
#       <td id="T_db721_row5_col3" class="data row5 col3" >-2.220440</td>
#       <td id="T_db721_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_db721_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_db721_row5_col6" class="data row5 col6" >0.000000</td>
#       <td id="T_db721_row5_col7" class="data row5 col7" >48/173</td>
#       <td id="T_db721_row5_col8" class="data row5 col8" >8.98%</td>
#       <td id="T_db721_row5_col9" class="data row5 col9" >FSTL1;DKK1;MATN2;TIMP3;CDH11;COL6A2;MEST;THBS1;FLNA;NNMT;MYLK;COL1A2;LOXL2;INHBA;TPM1;COL12A1;PVR;CXCL8;CXCL1;P3H1;COL5A1;BASP1;CALD1;COL4A1;SERPINH1;PDGFRB;SNAI2;SAT1;CALU;OXTR;PTX3;FZD8;ABI3BP;PLOD2;VCAM1;CCN1;GPC1;QSOX1;GJA1;SDC1;MMP1;ITGB3;COL4A2;VIM;TGFBI;FSTL3;ENO2;EDIL3</td>
#     </tr>
#     <tr>
#       <th id="T_db721_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_db721_row6_col0" class="data row6 col0" >gsea</td>
#       <td id="T_db721_row6_col1" class="data row6 col1" >HALLMARK_UNFOLDED_PROTEIN_RESPONSE</td>
#       <td id="T_db721_row6_col2" class="data row6 col2" >-0.503866</td>
#       <td id="T_db721_row6_col3" class="data row6 col3" >-2.196935</td>
#       <td id="T

# %%
for i in range(0, 5, 1):
    genes = gs_res.res2d.Lead_genes[i].split(';')
    
    gp.heatmap(df = gs_res.heatmat.loc[genes],
               z_score=0,
               title=gs_res.res2d.Term[i],
               figsize=(16,8),
               cmap='viridis',
              );

# %% [markdown]
# <h2>Generate a dot plot from GSEA results</h2>

# %% [markdown]
# Similar to our over-representation analysis, we can also generate a dot plot from the results of our GSEA run. We'll again make use of the <code>gp.dotplot</code> function.

# %%
gp.dotplot(df=gs_res.res2d,
           column='FDR q-val',
           x='NES',
           y='Term',
           top_term=50,
           cutoff=0.25,
           size=8,
           figsize=(3, 15),
           title='MSigDB Hallmark',
          );

# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Determine functional group enrichment in TAZ direct targets</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# With our subsetted data, we can perform an over-representation analysis or GSEA to determine which functional groups TAZ may be directly or indirectly regulating. We can continue to use our gene sets from MSigDB Hallmark collection for this functional analysis as well.
#
# We can define what our "interesting" genes are that we want to determine what gene sets or functional groups are enriched:

# %%
overlap
# Out:
#          gene     baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# 84     ABI3BP     2.217591       -3.911127  0.806348 -4.850422  1.231988e-06
# 97      ABTB2    24.241325        0.442388  0.171200  2.584034  9.765229e-03
# 115     ACAT2    58.251661       -0.310600  0.113016 -2.748280  5.990890e-03
# 173     ACTN1   527.742339       -0.292663  0.062124 -4.710941  2.465758e-06
# 175     ACTN4  1001.076407       -0.293635  0.055564 -5.284628  1.259608e-07
# ...       ...          ...             ...       ...       ...           ...
# 16742  ZNF114     5.791568       -1.579809  0.405935 -3.891775  9.951350e-05
# 16903  ZNF395   118.485818       -0.722475  0.100286 -7.204120  5.841998e-13
# 16988  ZNF521     0.886511       -3.284686  1.006299 -3.264124  1.098030e-03
# 17120  ZNF692    11.607842       -1.053824  0.270242 -3.899563  9.636650e-05
# 17254   ZNRF1    22.938717       -1.141504  0.201529 -5.664220  1.476952e-08
#
#                padj
# 84     1.525805e-05
# 97     3.947565e-02
# 115    2.646608e-02
# 173    2.908270e-05
# 175    1.896517e-06
# ...             ...
# 16742  8.009924e-04
# 16903  1.862188e-11
# 16988  6.389603e-03
# 17120  7.779623e-04
# 17254  2.614148e-07
#
# [319 rows x 7 columns]

# %%
interesting_genes = no_overlap.loc[:, 'gene']

# %% [markdown]
# Let's run the over-representation analysis using the GSEApy package's <code>gp.enrich()</code> function.

# %%
ora = gp.enrich(gene_list=interesting_genes,
                gene_sets=hallmark_db,
                background=bg_genes,
                outdir=None,
               )

# %% [markdown]
# We can sort our data by the adjusted p-value just to reorganize our data where the most significant over-representation is at the top of the DataFrame:

# %%
ora.res2d.sort_values(by='Adjusted P-value', inplace=True)

# %% [markdown]
# Now let's take a look at the output of our analysis:

# %%
ora.res2d.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_f9a94">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9a94_level0_col0" class="col_heading level0 col0" >Gene_set</th>
#       <th id="T_f9a94_level0_col1" class="col_heading level0 col1" >Term</th>
#       <th id="T_f9a94_level0_col2" class="col_heading level0 col2" >Overlap</th>
#       <th id="T_f9a94_level0_col3" class="col_heading level0 col3" >P-value</th>
#       <th id="T_f9a94_level0_col4" class="col_heading level0 col4" >Adjusted P-value</th>
#       <th id="T_f9a94_level0_col5" class="col_heading level0 col5" >Odds Ratio</th>
#       <th id="T_f9a94_level0_col6" class="col_heading level0 col6" >Combined Score</th>
#       <th id="T_f9a94_level0_col7" class="col_heading level0 col7" >Genes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9a94_level0_row0" class="row_heading level0 row0" >30</th>
#       <td id="T_f9a94_row0_col0" class="data row0 col0" >gs_ind_0</td>
#       <td id="T_f9a94_row0_col1" class="data row0 col1" >HALLMARK_MTORC1_SIGNALING</td>
#       <td id="T_f9a94_row0_col2" class="data row0 col2" >88/193</td>
#       <td id="T_f9a94_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_f9a94_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_f9a94_row0_col5" class="data row0 col5" >2.714949</td>
#       <td id="T_f9a94_row0_col6" class="data row0 col6" >66.044573</td>
#       <td id="T_f9a94_row0_col7" class="data row0 col7" >GLA;ENO1;PGM1;CYB5B;CALR;HPRT1;TRIB3;DHCR7;PHGDH;RRM2;SCD;PGK1;NFIL3;GPI;GTF2H1;HSP90B1;BCAT1;CANX;HK2;CTH;GAPDH;PLK1;SERP1;CTSC;HSPA5;ARPC5L;ADIPOR2;LTA4H;ADD3;ELOVL6;PSAT1;EBP;PFKL;TXNRD1;PLOD2;PPIA;ERO1A;SHMT2;TPI1;PSMC6;PSMD13;AK4;NIBAN1;PRDX1;FADS2;EIF2S2;NAMPT;AURKA;EPRS1;NFYC;FADS1;HSPA4;PSMB5;DDX39A;CCNF;LDHA;RDH11;STC1;GLRX;PDK1;EGLN3;STARD4;SLC7A11;CCNG1;PPA1;SLC1A5;PSMG1;G6PD;ACACA;SQSTM1;DDIT4;IFI30;INSIG1;NUP205;SERPINH1;STIP1;CDKN1A;VLDLR;DHFR;HSPD1;GCLC;RPA1;SLC6A6;DHCR24;BUB1;MTHFD2;EDEM1;SLC7A5</td>
#     </tr>
#     <tr>
#       <th id="T_f9a94_level0_row1" class="row_heading level0 row1" >13</th>
#       <td id="T_f9a94_row1_col0" class="data row1 col0" >gs_ind_0</td>
#       <td id="T_f9a94_row1_col1" class="data row1 col1" >HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION</td>
#       <td id="T_f9a94_row1_col2" class="data row1 col2" >73/157</td>
#       <td id="T_f9a94_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_f9a94_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_f9a94_row1_col5" class="data row1 col5" >2.807620</td>
#       <td id="T_f9a94_row1_col6" class="data row1 col6" >60.460792</td>
#       <td id="T_f9a94_row1_col7" class="data row1 col7" >JUN;TFPI2;SLIT2;ITGB5;CALD1;ITGB1;TPM1;SERPINE2;FSTL1;RGS4;QSOX1;PLAUR;FN1;OXTR;CALU;MATN2;ACTA2;RHOB;THBS2;ENO2;CD44;NT5E;ITGA2;NNMT;TIMP1;MEST;COL12A1;PMEPA1;COL1A2;FZD8;CXCL1;LRRC15;TNC;LOXL1;MMP14;COL4A1;LOXL2;CDH11;ITGAV;SGCB;EMP3;TGFB1;SERPINH1;GJA1;THBS1;SNAI2;PLOD1;MMP1;TIMP3;GLIPR1;INHBA;HTRA1;VIM;COL4A2;P3H1;CAPG;SAT1;COL6A2;PDGFRB;FLNA;FSTL3;WNT5A;CXCL8;MCM7;PLOD2;MYLK;PVR;SDC1;VCAM1;PLOD3;VEGFA;ADAM12;IL6</td>
#     </tr>
#     <tr>
#       <th id="T_f9a94_level0_row2" class="row_heading level0 row2" >31</th>
#       <td id="T_f9a94_row2_col0" class="data row2 col0" >gs_ind_0</td>
#       <td id="T_f9a94_row2_col1" class="data row2 col1" >HALLMARK_MYC_TARGETS_V1</td>
#       <td id="T_f9a94_row2_col2" class="data row2 col2" >85/196</td>
#       <td id="T_f9a94_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_f9a94_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_f9a94_row2_col5" class="data row2 col5" >2.477973</td>
#       <td id="T_f9a94_row2_col6" class="data row2 col6" >50.704686</td>
#       <td id="T_f9a94_row2_col7" class="data row2 col7" >PCBP1;TCP1;RUVBL2;PRPS2;PHB2;MCM6;PCNA;HPRT1;CLNS1A;DDX21;PGK1;SF3A1;CDC20;CDK2;H2AZ1;IARS1;CANX;HSP90AB1;KARS1;TFDP1;RPL6;RSL1D1;CTPS1;RNPS1;CYC1;RANBP1;BUB3;MRPL23;SNRPD3;RAN;RPL22;RPS2;RPLP0;SRM;AP3S1;RPS3;RPS5;HNRNPA1;SRSF2;PPIA;EIF4G2;USP1;PSMC6;EIF2S2;HNRNPA3;HDGF;EPRS1;CCNA2;U2AF1;PSMA1;HNRNPD;YWHAE;EIF4H;NAP1L1;PRDX3;SSBP1;PA2G4;C1QBP;PABPC4;LDHA;SYNCRIP;PSMB2;SET;HNRNPC;VBP1;CUL1;FBL;XPO1;SLC25A3;IMPDH2;NOLC1;APEX1;EEF1B2;SSB;UBA2;GLO1;HSPD1;TYMS;RPL18;RPL14;EIF3B;HDDC2;PSMD1;MCM7;SERBP1</td>
#     </tr>
#     <tr>
#       <th id="T_f9a94_level0_row3" class="row_heading level0 row3" >21</th>
#       <td id="T_f9a94_row3_col0" class="data row3 col0" >gs_ind_0</td>
#       <td id="T_f9a94_row3_col1" class="data row3 col1" >HALLMARK_HYPOXIA</td>
#       <td id="T_f9a94_row3_col2" class="data row3 col2" >72/169</td>
#       <td id="T_f9a94_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_f9a94_row3_col4" class="data row3 col4" >0.000001</td>
#       <td id="T_f9a94_row3_col5" class="data row3 col5" >2.396375</td>
#       <td id="T_f9a94_row3_col6" class="data row3 col6" >39.996111</td>
#       <td id="T_f9a94_row3_col7" class="data row3 col7" >HK2;JUN;GLRX;TPI1;GAPDH;MAP3K1;PDK1;SLC25A1;ENO1;CAV1;PLAUR;TPST2;CITED2;SELENBP1;PGM1;ENO2;AK4;NEDD4L;AMPD3;TIPARP;HSPA5;ALDOC;CHST3;CAVIN1;GCNT2;NDRG1;KLF7;PFKFB3;PGF;ANKZF1;VHL;ADM;FBP1;PAM;DDIT4;HDLBP;HS3ST1;ANGPTL4;MXI1;CDKN1A;F3;VLDLR;KLHL24;PPFIA4;PFKP;SRPX;CAVIN3;PGK1;NFIL3;ACKR3;BTG1;NDST2;SLC6A6;GPI;SDC2;MT1E;HK1;PFKL;SAP30;LDHA;STC1;GYS1;NDST1;PLAC8;ERRFI1;TPD52;IER3;IL6;VEGFA;AKAP12;IDS;ERO1A</td>
#     </tr>
#     <tr>
#       <th id="T_f9a94_level0_row4" class="row_heading level0 row4" >18</th>
#       <td id="T_f9a94_row4_col0" class="data row4 col0" >gs_ind_0</td>
#       <td id="T_f9a94_row4_col1" class="data row4 col1" >HALLMARK_GLYCOLYSIS</td>
#       <td id="T_f9a94_row4_col2" class="data row4 col2" >74/176</td>
#       <td id="T_f9a94_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_f9a94_row4_col4" class="data row4 col4" >0.000001</td>
#       <td id="T_f9a94_row4_col5" class="data row4 col5" >2.342691</td>
#       <td id="T_f9a94_row4_col6" class="data row4 col6" >38.545464</td>
#       <td id="T_f9a94_row4_col7" class="data row4 col7" >HK2;CTH;HAX1;TPI1;B3GAT3;GLRX;PKM;ELF3;EGLN3;ENO1;QSOX1;CHST4;CITED2;CD44;NT5E;ENO2;RBCK1;AK4;GNPDA1;SLC16A3;RARS1;KIF20A;HSPA5;AKR1A1;SOD1;G6PD;TALDO1;AGL;AURKA;ERO1A;ANKZF1;PC;DDIT4;PAM;HDLBP;ANGPTL4;SOX9;MXI1;STMN1;PLOD1;ARTN;CHPF2;VLDLR;PPFIA4;EXT2;B4GALT7;PFKP;FUT8;PGK1;CDK1;HOMER1;GCLC;HS2ST1;CAPN5;SDC2;CYB5A;NDST3;SAP30;LDHA;BIK;MED24;STC1;PLOD2;IL13RA1;MPI;NASP;GYS1;PGAM1;VEGFA;SDC1;IER3;PRPS1;PPIA;NSDHL</td>
#     </tr>
#     <tr>
#       <th id="T_f9a94_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_f9a94_row5_col0" class="data row5 col0" >gs_ind_0</td>
#       <td id="T_f9a94_row5_col1" class="data row5 col1" >HALLMARK_APOPTOSIS</td>
#       <td id="T_f9a94_row5_col2" class="data row5 col2" >61/139</td>
#       <td id="T_f9a94_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_f9a94_row5_col4" class="data row5 col4" >0.000001</td>
#       <td id="T_f9a94_row5_col5" class="data row5 col5" >2.520765</td>
#       <td id="T_f9a94_row5_col6" class="data row5 col6" >39.416753</td>
#       <td id="T_f9a94_row5_col7" class="data row5 col7" >JUN;KRT18;CTH;GPX3;HSPB1;SPTAN1;IL18;PPT1;IL1A;SMAD7;SOD2;CASP4;CAV1;IGFBP6;TNFSF10;RHOB;CD44;CDC25B;ENO2;PSEN1;BCAP31;TIMP1;RELA;XIAP;SOD1;TIMP2;BRCA1;APP;EMP1;SQSTM1;HMGB2;LEF1;CD14;BTG3;H1-0;CDKN1A;ERBB3;TIMP3;PPP3R1;CCNA1;IGF2R;CFLAR;TOP2A;GSTM1;PAK1;TGFB2;RETSAT;SAT1;CLU;PDGFRB;GSN;SLC20A1;EBP;CDK2;BIK;PLAT;IL6;IER3;EREG;ANKH;GPX4</td>
#     </tr>
#     <tr>
#       <th id="T_f9a94_level0_row6" class="row_heading level0 row6" >17</th>
#       <td id="T_f9a94_row6_col0" class="data row6 col0" >gs_ind_0</td>
#       <td id="T_f9a94_row6_col1" class="data row6 col1" >HALLMARK_G2M_CHECKPOINT</td>
#       <td id="T_f9a94_row6_col2" class="data row6 col2" >78/196</td>
#       <td id="T_f9a94_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_f9a94_row6_col4" class="data row6 col4" >0.000004</td>
#       <td id="T_f9a94_row6_col5" class="data row6 col5" >2.134529</td>
#       <td id="T_f9a94_row6_col6" class="data row6 c

# %% [markdown]
# <h2>Generate a dot plot of over-represented gene sets</h2>

# %% [markdown]
# We can make use of the <code>gp.dotplot()</code> function to generate a dot plot of our over-representation analysis results.

# %%
gp.dotplot(df=ora.res2d,
           column='Adjusted P-value',
           x='Combined Score',
           y='Term',
           top_term=30,
           cutoff=0.05,
           size=10,
           figsize=(2,10),
           title='MSigDB Hallmark',
           show_ring=True,
           marker='o',
           ofname=None,
          );

# %% [markdown]
# What adjustments can we make to our code to instead look at the set of genes that are indirectly regulated by TAZ?

# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Perform GSEA on TAZ direct targets</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# Like with over-representation analysis, we can also perform GSEA on our overlapping genes to get an idea of what functional groups may be direct targets of TAZ by taking a look at the difference in enrichment between our TAZ KO and control samples.
#
# We can continue with our normalized counts matrix from earlier in the notebook to pass to <code>GSEApy</code>'s <code>gp.GSEA()</code> function.

# %%
norm_counts.head().style
# Out:
# <style type="text/css">
# </style>
# <table id="T_6915e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6915e_level0_col0" class="col_heading level0 col0" >gene</th>
#       <th id="T_6915e_level0_col1" class="col_heading level0 col1" >ctrl_g1</th>
#       <th id="T_6915e_level0_col2" class="col_heading level0 col2" >tazko_g1</th>
#       <th id="T_6915e_level0_col3" class="col_heading level0 col3" >ctrl_g2</th>
#       <th id="T_6915e_level0_col4" class="col_heading level0 col4" >tazko_g2</th>
#       <th id="T_6915e_level0_col5" class="col_heading level0 col5" >ctrl_g3</th>
#       <th id="T_6915e_level0_col6" class="col_heading level0 col6" >tazko_g3</th>
#       <th id="T_6915e_level0_col7" class="col_heading level0 col7" >ctrl_g4</th>
#       <th id="T_6915e_level0_col8" class="col_heading level0 col8" >tazko_g4</th>
#       <th id="T_6915e_level0_col9" class="col_heading level0 col9" >ctrl_g5</th>
#       <th id="T_6915e_level0_col10" class="col_heading level0 col10" >tazko_g5</th>
#       <th id="T_6915e_level0_col11" class="col_heading level0 col11" >ctrl_g6</th>
#       <th id="T_6915e_level0_col12" class="col_heading level0 col12" >tazko_g6</th>
#       <th id="T_6915e_level0_col13" class="col_heading level0 col13" >ctrl_g7</th>
#       <th id="T_6915e_level0_col14" class="col_heading level0 col14" >tazko_g7</th>
#       <th id="T_6915e_level0_col15" class="col_heading level0 col15" >ctrl_g8</th>
#       <th id="T_6915e_level0_col16" class="col_heading level0 col16" >tazko_g8</th>
#       <th id="T_6915e_level0_col17" class="col_heading level0 col17" >ctrl_g9</th>
#       <th id="T_6915e_level0_col18" class="col_heading level0 col18" >tazko_g9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6915e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6915e_row0_col0" class="data row0 col0" >A1BG-AS1</td>
#       <td id="T_6915e_row0_col1" class="data row0 col1" >0.993195</td>
#       <td id="T_6915e_row0_col2" class="data row0 col2" >3.094105</td>
#       <td id="T_6915e_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_6915e_row0_col4" class="data row0 col4" >1.143745</td>
#       <td id="T_6915e_row0_col5" class="data row0 col5" >2.841466</td>
#       <td id="T_6915e_row0_col6" class="data row0 col6" >4.465449</td>
#       <td id="T_6915e_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_6915e_row0_col8" class="data row0 col8" >7.408773</td>
#       <td id="T_6915e_row0_col9" class="data row0 col9" >0.959141</td>
#       <td id="T_6915e_row0_col10" class="data row0 col10" >1.882807</td>
#       <td id="T_6915e_row0_col11" class="data row0 col11" >1.918798</td>
#       <td id="T_6915e_row0_col12" class="data row0 col12" >2.490844</td>
#       <td id="T_6915e_row0_col13" class="data row0 col13" >0.000000</td>
#       <td id="T_6915e_row0_col14" class="data row0 col14" >0.913544</td>
#       <td id="T_6915e_row0_col15" class="data row0 col15" >0.968493</td>
#       <td id="T_6915e_row0_col16" class="data row0 col16" >1.832776</td>
#       <td id="T_6915e_row0_col17" class="data row0 col17" >0.000000</td>
#       <td id="T_6915e_row0_col18" class="data row0 col18" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6915e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6915e_row1_col0" class="data row1 col0" >A4GALT</td>
#       <td id="T_6915e_row1_col1" class="data row1 col1" >7.945557</td>
#       <td id="T_6915e_row1_col2" class="data row1 col2" >8.250946</td>
#       <td id="T_6915e_row1_col3" class="data row1 col3" >14.523575</td>
#       <td id="T_6915e_row1_col4" class="data row1 col4" >10.293703</td>
#       <td id="T_6915e_row1_col5" class="data row1 col5" >16.101640</td>
#       <td id="T_6915e_row1_col6" class="data row1 col6" >7.144719</td>
#       <td id="T_6915e_row1_col7" class="data row1 col7" >12.238351</td>
#       <td id="T_6915e_row1_col8" class="data row1 col8" >9.260966</td>
#       <td id="T_6915e_row1_col9" class="data row1 col9" >4.795706</td>
#       <td id="T_6915e_row1_col10" class="data row1 col10" >17.886670</td>
#       <td id="T_6915e_row1_col11" class="data row1 col11" >8.634592</td>
#       <td id="T_6915e_row1_col12" class="data row1 col12" >9.963376</td>
#       <td id="T_6915e_row1_col13" class="data row1 col13" >7.729285</td>
#       <td id="T_6915e_row1_col14" class="data row1 col14" >8.221895</td>
#       <td id="T_6915e_row1_col15" class="data row1 col15" >19.369854</td>
#       <td id="T_6915e_row1_col16" class="data row1 col16" >11.913046</td>
#       <td id="T_6915e_row1_col17" class="data row1 col17" >6.457018</td>
#       <td id="T_6915e_row1_col18" class="data row1 col18" >10.786287</td>
#     </tr>
#     <tr>
#       <th id="T_6915e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6915e_row2_col0" class="data row2 col0" >AAAS</td>
#       <td id="T_6915e_row2_col1" class="data row2 col1" >17.877503</td>
#       <td id="T_6915e_row2_col2" class="data row2 col2" >28.878310</td>
#       <td id="T_6915e_row2_col3" class="data row2 col3" >24.205958</td>
#       <td id="T_6915e_row2_col4" class="data row2 col4" >27.449875</td>
#       <td id="T_6915e_row2_col5" class="data row2 col5" >37.886211</td>
#       <td id="T_6915e_row2_col6" class="data row2 col6" >29.471964</td>
#       <td id="T_6915e_row2_col7" class="data row2 col7" >29.576015</td>
#       <td id="T_6915e_row2_col8" class="data row2 col8" >25.004609</td>
#       <td id="T_6915e_row2_col9" class="data row2 col9" >26.855952</td>
#       <td id="T_6915e_row2_col10" class="data row2 col10" >25.417899</td>
#       <td id="T_6915e_row2_col11" class="data row2 col11" >24.944376</td>
#       <td id="T_6915e_row2_col12" class="data row2 col12" >19.926752</td>
#       <td id="T_6915e_row2_col13" class="data row2 col13" >38.646424</td>
#       <td id="T_6915e_row2_col14" class="data row2 col14" >27.406318</td>
#       <td id="T_6915e_row2_col15" class="data row2 col15" >25.180810</td>
#       <td id="T_6915e_row2_col16" class="data row2 col16" >44.903018</td>
#       <td id="T_6915e_row2_col17" class="data row2 col17" >31.208920</td>
#       <td id="T_6915e_row2_col18" class="data row2 col18" >21.572573</td>
#     </tr>
#     <tr>
#       <th id="T_6915e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6915e_row3_col0" class="data row3 col0" >AACS</td>
#       <td id="T_6915e_row3_col1" class="data row3 col1" >23.836671</td>
#       <td id="T_6915e_row3_col2" class="data row3 col2" >29.909678</td>
#       <td id="T_6915e_row3_col3" class="data row3 col3" >30.983626</td>
#       <td id="T_6915e_row3_col4" class="data row3 col4" >28.593619</td>
#       <td id="T_6915e_row3_col5" class="data row3 col5" >33.150435</td>
#       <td id="T_6915e_row3_col6" class="data row3 col6" >24.113425</td>
#       <td id="T_6915e_row3_col7" class="data row3 col7" >28.556153</td>
#       <td id="T_6915e_row3_col8" class="data row3 col8" >26.856802</td>
#       <td id="T_6915e_row3_col9" class="data row3 col9" >35.488223</td>
#       <td id="T_6915e_row3_col10" class="data row3 col10" >25.417899</td>
#       <td id="T_6915e_row3_col11" class="data row3 col11" >31.660170</td>
#       <td id="T_6915e_row3_col12" class="data row3 col12" >26.153863</td>
#       <td id="T_6915e_row3_col13" class="data row3 col13" >33.815621</td>
#       <td id="T_6915e_row3_col14" class="data row3 col14" >18.270879</td>
#       <td id="T_6915e_row3_col15" class="data row3 col15" >19.369854</td>
#       <td id="T_6915e_row3_col16" class="data row3 col16" >28.408032</td>
#       <td id="T_6915e_row3_col17" class="data row3 col17" >27.980411</td>
#       <td id="T_6915e_row3_col18" class="data row3 col18" >33.257717</td>
#     </tr>
#     <tr>
#       <th id="T_6915e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6915e_row4_col0" class="data row4 col0" >AADAT</td>
#       <td id="T_6915e_row4_col1" class="data row4 col1" >0.993195</td>
#       <td id="T_6915e_row4_col2" class="data row4 col2" >4.125473</td>
#       <td id="T_6915e_row4_col3" class="data row4 col3" >3.872953</td>
#       <td id="T_6915e_row4_col4" class="data r

# %% [markdown]
# We can then find the full set of overlaps with our ChIP-seq dataset.

# %%
full_overlap = list(set(norm_counts.gene) & set(chip_genes))

# %%
full_overlap[:10]
# Out:
# ['SLC20A2',
#  'TMEM178A',
#  'HTR1B',
#  'STC2',
#  'RGS20',
#  'LEMD2',
#  'WWP2',
#  'FOXP1',
#  'TGFBI',
#  'INSYN2B']

# %%
overlap_counts = pd.DataFrame(norm_counts[norm_counts.gene.isin(full_overlap)])

# %%
overlap_counts.head().style
# Out:
# <style type="text/css">
# </style>
# <table id="T_f12ad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f12ad_level0_col0" class="col_heading level0 col0" >gene</th>
#       <th id="T_f12ad_level0_col1" class="col_heading level0 col1" >ctrl_g1</th>
#       <th id="T_f12ad_level0_col2" class="col_heading level0 col2" >tazko_g1</th>
#       <th id="T_f12ad_level0_col3" class="col_heading level0 col3" >ctrl_g2</th>
#       <th id="T_f12ad_level0_col4" class="col_heading level0 col4" >tazko_g2</th>
#       <th id="T_f12ad_level0_col5" class="col_heading level0 col5" >ctrl_g3</th>
#       <th id="T_f12ad_level0_col6" class="col_heading level0 col6" >tazko_g3</th>
#       <th id="T_f12ad_level0_col7" class="col_heading level0 col7" >ctrl_g4</th>
#       <th id="T_f12ad_level0_col8" class="col_heading level0 col8" >tazko_g4</th>
#       <th id="T_f12ad_level0_col9" class="col_heading level0 col9" >ctrl_g5</th>
#       <th id="T_f12ad_level0_col10" class="col_heading level0 col10" >tazko_g5</th>
#       <th id="T_f12ad_level0_col11" class="col_heading level0 col11" >ctrl_g6</th>
#       <th id="T_f12ad_level0_col12" class="col_heading level0 col12" >tazko_g6</th>
#       <th id="T_f12ad_level0_col13" class="col_heading level0 col13" >ctrl_g7</th>
#       <th id="T_f12ad_level0_col14" class="col_heading level0 col14" >tazko_g7</th>
#       <th id="T_f12ad_level0_col15" class="col_heading level0 col15" >ctrl_g8</th>
#       <th id="T_f12ad_level0_col16" class="col_heading level0 col16" >tazko_g8</th>
#       <th id="T_f12ad_level0_col17" class="col_heading level0 col17" >ctrl_g9</th>
#       <th id="T_f12ad_level0_col18" class="col_heading level0 col18" >tazko_g9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f12ad_level0_row0" class="row_heading level0 row0" >24</th>
#       <td id="T_f12ad_row0_col0" class="data row0 col0" >ABCA13</td>
#       <td id="T_f12ad_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_f12ad_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_f12ad_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_f12ad_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_f12ad_row0_col5" class="data row0 col5" >1.894311</td>
#       <td id="T_f12ad_row0_col6" class="data row0 col6" >0.893090</td>
#       <td id="T_f12ad_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_f12ad_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_f12ad_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_f12ad_row0_col10" class="data row0 col10" >0.000000</td>
#       <td id="T_f12ad_row0_col11" class="data row0 col11" >0.000000</td>
#       <td id="T_f12ad_row0_col12" class="data row0 col12" >0.000000</td>
#       <td id="T_f12ad_row0_col13" class="data row0 col13" >0.966161</td>
#       <td id="T_f12ad_row0_col14" class="data row0 col14" >0.000000</td>
#       <td id="T_f12ad_row0_col15" class="data row0 col15" >0.000000</td>
#       <td id="T_f12ad_row0_col16" class="data row0 col16" >0.000000</td>
#       <td id="T_f12ad_row0_col17" class="data row0 col17" >0.000000</td>
#       <td id="T_f12ad_row0_col18" class="data row0 col18" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f12ad_level0_row1" class="row_heading level0 row1" >28</th>
#       <td id="T_f12ad_row1_col0" class="data row1 col0" >ABCA4</td>
#       <td id="T_f12ad_row1_col1" class="data row1 col1" >0.993195</td>
#       <td id="T_f12ad_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_f12ad_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_f12ad_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_f12ad_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_f12ad_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_f12ad_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_f12ad_row1_col8" class="data row1 col8" >0.000000</td>
#       <td id="T_f12ad_row1_col9" class="data row1 col9" >0.000000</td>
#       <td id="T_f12ad_row1_col10" class="data row1 col10" >0.000000</td>
#       <td id="T_f12ad_row1_col11" class="data row1 col11" >0.000000</td>
#       <td id="T_f12ad_row1_col12" class="data row1 col12" >0.000000</td>
#       <td id="T_f12ad_row1_col13" class="data row1 col13" >0.966161</td>
#       <td id="T_f12ad_row1_col14" class="data row1 col14" >0.000000</td>
#       <td id="T_f12ad_row1_col15" class="data row1 col15" >0.000000</td>
#       <td id="T_f12ad_row1_col16" class="data row1 col16" >0.000000</td>
#       <td id="T_f12ad_row1_col17" class="data row1 col17" >0.000000</td>
#       <td id="T_f12ad_row1_col18" class="data row1 col18" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f12ad_level0_row2" class="row_heading level0 row2" >39</th>
#       <td id="T_f12ad_row2_col0" class="data row2 col0" >ABCC1</td>
#       <td id="T_f12ad_row2_col1" class="data row2 col1" >73.496402</td>
#       <td id="T_f12ad_row2_col2" class="data row2 col2" >79.415352</td>
#       <td id="T_f12ad_row2_col3" class="data row2 col3" >81.332018</td>
#       <td id="T_f12ad_row2_col4" class="data row2 col4" >73.199665</td>
#       <td id="T_f12ad_row2_col5" class="data row2 col5" >97.556993</td>
#       <td id="T_f12ad_row2_col6" class="data row2 col6" >73.233365</td>
#       <td id="T_f12ad_row2_col7" class="data row2 col7" >58.132168</td>
#       <td id="T_f12ad_row2_col8" class="data row2 col8" >56.491894</td>
#       <td id="T_f12ad_row2_col9" class="data row2 col9" >65.221598</td>
#       <td id="T_f12ad_row2_col10" class="data row2 col10" >56.484220</td>
#       <td id="T_f12ad_row2_col11" class="data row2 col11" >71.954931</td>
#       <td id="T_f12ad_row2_col12" class="data row2 col12" >93.406652</td>
#       <td id="T_f12ad_row2_col13" class="data row2 col13" >72.462045</td>
#       <td id="T_f12ad_row2_col14" class="data row2 col14" >67.602250</td>
#       <td id="T_f12ad_row2_col15" class="data row2 col15" >77.479415</td>
#       <td id="T_f12ad_row2_col16" class="data row2 col16" >63.230781</td>
#       <td id="T_f12ad_row2_col17" class="data row2 col17" >81.788894</td>
#       <td id="T_f12ad_row2_col18" class="data row2 col18" >51.234861</td>
#     </tr>
#     <tr>
#       <th id="T_f12ad_level0_row3" class="row_heading level0 row3" >43</th>
#       <td id="T_f12ad_row3_col0" class="data row3 col0" >ABCC4</td>
#       <td id="T_f12ad_row3_col1" class="data row3 col1" >36.748201</td>
#       <td id="T_f12ad_row3_col2" class="data row3 col2" >39.191992</td>
#       <td id="T_f12ad_row3_col3" class="data row3 col3" >41.634247</td>
#       <td id="T_f12ad_row3_col4" class="data row3 col4" >36.599833</td>
#       <td id="T_f12ad_row3_col5" class="data row3 col5" >30.308969</td>
#       <td id="T_f12ad_row3_col6" class="data row3 col6" >43.761401</td>
#       <td id="T_f12ad_row3_col7" class="data row3 col7" >31.615741</td>
#       <td id="T_f12ad_row3_col8" class="data row3 col8" >46.304832</td>
#       <td id="T_f12ad_row3_col9" class="data row3 col9" >35.488223</td>
#       <td id="T_f12ad_row3_col10" class="data row3 col10" >41.421761</td>
#       <td id="T_f12ad_row3_col11" class="data row3 col11" >32.619569</td>
#       <td id="T_f12ad_row3_col12" class="data row3 col12" >31.135551</td>
#       <td id="T_f12ad_row3_col13" class="data row3 col13" >29.950979</td>
#       <td id="T_f12ad_row3_col14" class="data row3 col14" >49.331372</td>
#       <td id="T_f12ad_row3_col15" class="data row3 col15" >40.676693</td>
#       <td id="T_f12ad_row3_col16" class="data row3 col16" >35.739137</td>
#       <td id="T_f12ad_row3_col17" class="data row3 col17" >38.742108</td>
#       <td id="T_f12ad_row3_col18" class="data row3 col18" >32.358860</td>
#     </tr>
#     <tr>
#       <th id="T_f12ad_level0_row4" class="row_heading level0 row4" >78</th>
#       <td id="T_f12ad_row4_col0" class="data row4 col0" >ABHD4</td>
#       <td id="T_f12ad_row4_col1" class="data row4 col1" >23.836671</td>
#       <td id="T_f12ad_row4_col2" class="data row4 col2" >40.223360</td>
#       <td id="T_f12ad_row4_col3" class="data row4 col3" >21.301243</td>
#       <td id="T_f12ad_row4_col4" class="data ro

# %%
gs_res = gp.GSEA(data=overlap_counts,
                 gene_sets=hallmark_db,
                 classes=class_vector,
                 method='signal_to_noise',
                 permutation_type='phenotype',
                 permutation_num=1000,
                 outdir=None,
                 seed=135,
                )

gs_res.pheno_pos = tazko
gs_res.pheno_neg = ctrl

gs_res.run()

# %%
gs_res.res2d.sort_values(by='NES').style
# Out:
# <style type="text/css">
# </style>
# <table id="T_a47d2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a47d2_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_a47d2_level0_col1" class="col_heading level0 col1" >Term</th>
#       <th id="T_a47d2_level0_col2" class="col_heading level0 col2" >ES</th>
#       <th id="T_a47d2_level0_col3" class="col_heading level0 col3" >NES</th>
#       <th id="T_a47d2_level0_col4" class="col_heading level0 col4" >NOM p-val</th>
#       <th id="T_a47d2_level0_col5" class="col_heading level0 col5" >FDR q-val</th>
#       <th id="T_a47d2_level0_col6" class="col_heading level0 col6" >FWER p-val</th>
#       <th id="T_a47d2_level0_col7" class="col_heading level0 col7" >Tag %</th>
#       <th id="T_a47d2_level0_col8" class="col_heading level0 col8" >Gene %</th>
#       <th id="T_a47d2_level0_col9" class="col_heading level0 col9" >Lead_genes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a47d2_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a47d2_row0_col0" class="data row0 col0" >gsea</td>
#       <td id="T_a47d2_row0_col1" class="data row0 col1" >HALLMARK_MITOTIC_SPINDLE</td>
#       <td id="T_a47d2_row0_col2" class="data row0 col2" >-0.598513</td>
#       <td id="T_a47d2_row0_col3" class="data row0 col3" >-1.715085</td>
#       <td id="T_a47d2_row0_col4" class="data row0 col4" >0.011881</td>
#       <td id="T_a47d2_row0_col5" class="data row0 col5" >0.104230</td>
#       <td id="T_a47d2_row0_col6" class="data row0 col6" >0.067005</td>
#       <td id="T_a47d2_row0_col7" class="data row0 col7" >14/27</td>
#       <td id="T_a47d2_row0_col8" class="data row0 col8" >22.21%</td>
#       <td id="T_a47d2_row0_col9" class="data row0 col9" >NEDD9;PALLD;SORBS2;WASF2;FSCN1;ARHGAP29;TRIO;DLG1;ALS2;MYH9;ACTN4;SYNPO;FLNB;SPTBN1</td>
#     </tr>
#     <tr>
#       <th id="T_a47d2_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_a47d2_row1_col0" class="data row1 col0" >gsea</td>
#       <td id="T_a47d2_row1_col1" class="data row1 col1" >HALLMARK_HYPOXIA</td>
#       <td id="T_a47d2_row1_col2" class="data row1 col2" >-0.442640</td>
#       <td id="T_a47d2_row1_col3" class="data row1 col3" >-1.540341</td>
#       <td id="T_a47d2_row1_col4" class="data row1 col4" >0.033613</td>
#       <td id="T_a47d2_row1_col5" class="data row1 col5" >0.178003</td>
#       <td id="T_a47d2_row1_col6" class="data row1 col6" >0.205076</td>
#       <td id="T_a47d2_row1_col7" class="data row1 col7" >10/27</td>
#       <td id="T_a47d2_row1_col8" class="data row1 col8" >16.69%</td>
#       <td id="T_a47d2_row1_col9" class="data row1 col9" >SLC2A1;EXT1;ANXA2;COL5A1;XPNPEP1;MYH9;CCN1;GPC1;TMEM45A;EDN2</td>
#     </tr>
#     <tr>
#       <th id="T_a47d2_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_a47d2_row2_col0" class="data row2 col0" >gsea</td>
#       <td id="T_a47d2_row2_col1" class="data row2 col1" >HALLMARK_ESTROGEN_RESPONSE_EARLY</td>
#       <td id="T_a47d2_row2_col2" class="data row2 col2" >-0.424925</td>
#       <td id="T_a47d2_row2_col3" class="data row2 col3" >-1.347276</td>
#       <td id="T_a47d2_row2_col4" class="data row2 col4" >0.137066</td>
#       <td id="T_a47d2_row2_col5" class="data row2 col5" >0.365933</td>
#       <td id="T_a47d2_row2_col6" class="data row2 col6" >0.450761</td>
#       <td id="T_a47d2_row2_col7" class="data row2 col7" >4/24</td>
#       <td id="T_a47d2_row2_col8" class="data row2 col8" >5.18%</td>
#       <td id="T_a47d2_row2_col9" class="data row2 col9" >SLC2A1;WWC1;CCND1;ITPK1</td>
#     </tr>
#     <tr>
#       <th id="T_a47d2_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_a47d2_row3_col0" class="data row3 col0" >gsea</td>
#       <td id="T_a47d2_row3_col1" class="data row3 col1" >HALLMARK_APICAL_JUNCTION</td>
#       <td id="T_a47d2_row3_col2" class="data row3 col2" >-0.429255</td>
#       <td id="T_a47d2_row3_col3" class="data row3 col3" >-1.339467</td>
#       <td id="T_a47d2_row3_col4" class="data row3 col4" >0.115854</td>
#       <td id="T_a47d2_row3_col5" class="data row3 col5" >0.284941</td>
#       <td id="T_a47d2_row3_col6" class="data row3 col6" >0.464975</td>
#       <td id="T_a47d2_row3_col7" class="data row3 col7" >11/25</td>
#       <td id="T_a47d2_row3_col8" class="data row3 col8" >22.32%</td>
#       <td id="T_a47d2_row3_col9" class="data row3 col9" >LIMA1;LAYN;FSCN1;DLG1;MYH9;ACTN4;ACTN1;CDH1;EGFR;NEGR1;TGFBI</td>
#     </tr>
#     <tr>
#       <th id="T_a47d2_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_a47d2_row4_col0" class="data row4 col0" >gsea</td>
#       <td id="T_a47d2_row4_col1" class="data row4 col1" >HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION</td>
#       <td id="T_a47d2_row4_col2" class="data row4 col2" >-0.417915</td>
#       <td id="T_a47d2_row4_col3" class="data row4 col3" >-1.289153</td>
#       <td id="T_a47d2_row4_col4" class="data row4 col4" >0.190083</td>
#       <td id="T_a47d2_row4_col5" class="data row4 col5" >0.288054</td>
#       <td id="T_a47d2_row4_col6" class="data row4 col6" >0.529949</td>
#       <td id="T_a47d2_row4_col7" class="data row4 col7" >10/24</td>
#       <td id="T_a47d2_row4_col8" class="data row4 col8" >23.25%</td>
#       <td id="T_a47d2_row4_col9" class="data row4 col9" >DKK1;COL5A1;BASP1;PTX3;ABI3BP;CCN1;GPC1;ITGB3;TGFBI;EDIL3</td>
#     </tr>
#     <tr>
#       <th id="T_a47d2_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_a47d2_row5_col0" class="data row5 col0" >gsea</td>
#       <td id="T_a47d2_row5_col1" class="data row5 col1" >HALLMARK_ESTROGEN_RESPONSE_LATE</td>
#       <td id="T_a47d2_row5_col2" class="data row5 col2" >-0.427071</td>
#       <td id="T_a47d2_row5_col3" class="data row5 col3" >-1.188546</td>
#       <td id="T_a47d2_row5_col4" class="data row5 col4" >0.260521</td>
#       <td id="T_a47d2_row5_col5" class="data row5 col5" >0.350592</td>
#       <td id="T_a47d2_row5_col6" class="data row5 col6" >0.655838</td>
#       <td id="T_a47d2_row5_col7" class="data row5 col7" >6/15</td>
#       <td id="T_a47d2_row5_col8" class="data row5 col8" >24.51%</td>
#       <td id="T_a47d2_row5_col9" class="data row5 col9" >CCND1;ITPK1;PPIF;CDH1;FLNB;NCOR2</td>
#     </tr>
#     <tr>
#       <th id="T_a47d2_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_a47d2_row6_col0" class="data row6 col0" >gsea</td>
#       <td id="T_a47d2_row6_col1" class="data row6 col1" >HALLMARK_GLYCOLYSIS</td>
#       <td id="T_a47d2_row6_col2" class="data row6 col2" >-0.383128</td>
#       <td id="T_a47d2_row6_col3" class="data row6 col3" >-1.082920</td>
#       <td id="T_a47d2_row6_col4" class="data row6 col4" >0.381857</td>
#       <td id="T_a47d2_row6_col5" class="data row6 col5" >0.419434</td>
#       <td id="T_a47d2_row6_col6" class="data row6 col6" >0.771574</td>
#       <td id="T_a47d2_row6_col7" class="data row6 col7" >6/15</td>
#       <td id="T_a47d2_row6_col8" class="data row6 col8" >22.32%</td>
#       <td id="T_a47d2_row6_col9" class="data row6 col9" >EXT1;COL5A1;GPC1;PKP2;EGFR;TGFBI</td>
#     </tr>
#     <tr>
#       <th id="T_a47d2_level0_row7" class="row_heading level0 row7" >11</th>
#       <td id="T_a47d2_row7_col0" class="data row7 col0" >gsea</td>
#       <td id="T_a47d2_row7_col1" class="data row7 col1" >HALLMARK_UV_RESPONSE_DN</td>
#       <td id="T_a47d2_row7_col2" class="data row7 col2" >-0.281612</td>
#       <td id="T_a47d2_row7_col3" class="data row7 col3" >-0.914116</td>
#       <td id="T_a47d2_row7_col4" class="data row7 col4" >0.561905</td>
#       <td id="T_a47d2_row7_col5" class="data row7 col5" >0.566328</td>
#       <td id="T_a47d2_row7_col6" class="data row7 col6" >0.890355</td>
#       <td id="T_a47d2_row7_col7" class="data row7 col7" >12/25</td>
#       <td id="T_a47d2_row7_col8" class="data row7 col8" >33.26%</td>
#       <td id="T_a47d2_row7_col9" class="data row7 col9" >ANXA2;DDAH1;LDLR;DLG1;CCN1;PRKCE;ITGB3;INPP4B;RND3;IRS1;AKT3;ADGRL2</td>
#     </tr>
#     <tr>
#       <th id="T_a47d2_level0_row8" class="row_heading level0 row8" >10</th>
#       <td id="T_a47d2_row8_col0" class="data row8 col0" >gsea</td>
#       <td id="T_a47d2_row8_c

# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Exercise: Pull out leading edge genes to visualize counts</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# For this exercise, select a significantly enriched functional group based on our GSEA analysis, and pull out the leading edge genes. Once you have the genes, then use that information to generate a violin plot to visualize the distribution of the normalized counts for the set of leading edge genes.

# %%
genes = gs_res.res2d.Lead_genes[2].split(';')
genes
# Out:
# ['TGM2',
#  'NRP1',
#  'IFNGR1',
#  'BCL2',
#  'NFKBIZ',
#  'ADAM19',
#  'SPRED2',
#  'ETV4',
#  'PHLDA1']

# %%
IL_genes = gs_res.heatmat.loc[genes]

# %%
gp.heatmap(df=gs_res.heatmat.loc[genes],
           z_score=0,
           cmap='viridis',
          );

# %%
#We can take our normalized counts for just our leading edge genes
#And process them like we did for our top 10 most upreg/downreg genes like in 13-1
#So we can visualize their normalized counts as a violin plot or box-whisker plot
IL_genes = IL_genes.T

# %%
IL_genes
#We have our wide-format table, so we can melt it to be long-format
# Out:
# gene             TGM2        NRP1     IFNGR1       BCL2     NFKBIZ     ADAM19  \
# tazko_g1  1090.156201  403.264971  55.693883  10.313682  58.787988  38.160624
# tazko_g2  1061.395150  394.591947  72.055921  12.581193  44.606046  35.456088
# tazko_g3  1020.801658  421.538393  74.126455   7.144719  54.478479  46.440670
# tazko_g4  1017.780197  377.847425  68.531151  10.187063  32.413382  60.196281
# tazko_g5   980.001213  345.495144  58.367027   6.589826  36.714743  43.304569
# tazko_g6  1122.125245  348.718167  59.780257  13.699642  33.626395  32.380973
# tazko_g7  1035.045267  391.910344  65.775163  11.876071  47.504284  45.677196
# tazko_g8  1023.605535  354.642204  65.063557   6.414717  34.822749  39.404689
# tazko_g9  1071.437794  388.306314  74.605148  13.482858  62.021147  51.234861
# ctrl_g1    656.501641  288.026439  51.646120   6.952362  32.775422  26.816255
# ctrl_g2    726.178733  293.376208  50.348392   3.872953  26.142434  36.793056
# ctrl_g3    829.708022  288.882359  48.304919   5.682932  40.727677  31.256124
# ctrl_g4    623.136049  244.767024  37.734916   6.119176  18.357527  20.397252
# ctrl_g5    724.151571  270.477805  42.202211   1.918282  37.406505  27.815093
# ctrl_g6    749.290687  307.007708  55.645147   9.593991  25.903775  23.984977
# ctrl_g7    693.703309  264.728004  38.646424   5.796964  29.950979  33.815621
# ctrl_g8    718.621576  313.791632  47.456142   3.873971  34.865737  42.613678
# ctrl_g9    746.861743  325.003237  48.427635   4.304679  19.371054  39.818277
#
# gene         SPRED2       ETV4      PHLDA1
# tazko_g1  49.505674  53.631147  475.460746
# tazko_g2  52.612260  65.193452  415.179353
# tazko_g3  66.088646  41.082131  481.375410
# tazko_g4  39.822155  69.457247  481.570248
# tazko_g5  43.304569  50.835798  493.295519
# tazko_g6  72.234477  59.780257  414.725535
# tazko_g7  49.331372  52.072004  510.671054
# tazko_g8  54.983287  54.983287  471.939884
# tazko_g9  37.752003  66.515434  467.405749
# ctrl_g1   33.768617  43.700563  428.066879
# ctrl_g2   32.920103  42.602486  439.580193
# ctrl_g3   52.093540  35.044745  448.004446
# ctrl_g4   22.436977  37.734916  489.534048
# ctrl_g5   37.406505  59.466752  443.123213
# ctrl_g6   36.457165  65.239138  360.734057
# ctrl_g7   35.747942  28.984818  461.824766
# ctrl_g8   51.330113  42.613678  414.514872
# ctrl_g9   45.199126  47.351465  403.563622

# %%
#Preparing the table to melt
IL_genes.index = ['tazko']*9 + ['control']*9

# %%
IL_genes.reset_index(names=['condition'],
                     inplace=True
                    )

# %%
IL_genes.sort_values(by='condition', 
                     ascending=True, 
                     inplace=True,
                    )

# %%
#Now we melt it so that it becomes a long-format table while preserving the information associated with each count
IL_genes_long = pd.melt(IL_genes,
                        id_vars='condition',
                        value_vars=IL_genes.columns[1:],
                        value_name='count',
                       )

# %%
#Then we can use our box-whisker plot code from 13-1 with slight modifications to visualize these leading edge genes' normalized counts
color_set = ['#777777', '#E64B35']
fig, ax = plt.subplots()

sns.boxplot(data=IL_genes_long,
            x='gene',
            y='count',
            hue='condition',
            palette=color_set,
            linewidth=0.5,
            linecolor='k',
            fliersize=False,
            log_scale=False,
           )

handles, labels = ax.get_legend_handles_labels()
labels = ['Control', '$TAZ$ KO']

plt.legend(handles,
           labels,
           bbox_to_anchor=(1.15, 0.25, 0, 0.4),
           edgecolor='None',
          )

ax.set_xlabel(None)
ax.set_ylabel('Normalized counts')
ax.set_title('HALLMARK IL2 STAT5 SIGNALING')
plt.xticks(rotation=30,
           ha='right',
          )
plt.yscale('log')

sns.despine()
fig.set_dpi(300)
fig.set_size_inches(10, 3)
plt.show()

# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Exercise: Run GSEA on TAZ indirect targets</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# For this last exercise, practice running GSEA on our RNA-seq genes that were found to not overlap with our ChIP-seq genes, and after, we can take a look at what the result might tell us about the indirect targets of TAZ.

# %%
full_no_overlap = list(set(norm_counts.gene) - set(chip_genes))
no_overlap_genes = pd.DataFrame(norm_counts[norm_counts.gene.isin(full_no_overlap)])

# %%
gs_res = gp.GSEA(data=no_overlap_genes,
                 gene_sets=hallmark_db,
                 classes=class_vector,
                 method='signal_to_noise',
                 permutation_type='phenotype',
                 permutation_num=1000,
                 outdir=None,
                 seed=135,
                )

gs_res.pheno_pos = tazko
gs_res.pheno_neg = ctrl
gs_res.run()

# %%
gs_res.res2d
# Out:
#     Name                                        Term        ES       NES  \
# 0   gsea              HALLMARK_XENOBIOTIC_METABOLISM -0.489679 -2.443916
# 1   gsea                            HALLMARK_HYPOXIA -0.542064 -2.427672
# 2   gsea                   HALLMARK_MTORC1_SIGNALING -0.564804 -2.367178
# 3   gsea  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION -0.459021 -2.279592
# 4   gsea            HALLMARK_ESTROGEN_RESPONSE_EARLY  -0.48283 -2.240732
# 5   gsea          HALLMARK_UNFOLDED_PROTEIN_RESPONSE -0.506221 -2.224402
# 6   gsea                    HALLMARK_APICAL_JUNCTION -0.432337 -2.213957
# 7   gsea                     HALLMARK_UV_RESPONSE_DN -0.471745 -2.201749
# 8   gsea            HALLMARK_CHOLESTEROL_HOMEOSTASIS -0.568337  -2.16243
# 9   gsea                        HALLMARK_E2F_TARGETS -0.588458 -2.129107
# 10  gsea                         HALLMARK_GLYCOLYSIS -0.436442 -2.097597
# 11  gsea                     HALLMARK_G2M_CHECKPOINT  -0.53411   -2.0751
# 12  gsea          HALLMARK_INTERFERON_ALPHA_RESPONSE  0.530615  2.065868
# 13  gsea                     HALLMARK_MYC_TARGETS_V1  -0.61788 -2.018679
# 14  gsea             HALLMARK_ESTROGEN_RESPONSE_LATE -0.442101 -2.009782
# 15  gsea                HALLMARK_ALLOGRAFT_REJECTION -0.390676  -2.00785
# 16  gsea          HALLMARK_INTERFERON_GAMMA_RESPONSE  0.413992  1.951225
# 17  gsea                       HALLMARK_ADIPOGENESIS -0.388094 -1.937902
# 18  gsea                          HALLMARK_APOPTOSIS  -0.34999 -1.876257
# 19  gsea              HALLMARK_INFLAMMATORY_RESPONSE -0.378324 -1.860501
# 20  gsea            HALLMARK_PI3K_AKT_MTOR_SIGNALING -0.411559  -1.85566
# 21  gsea                         HALLMARK_MYOGENESIS -0.354032 -1.845577
# 22  gsea                     HALLMARK_MYC_TARGETS_V2 -0.523786 -1.841516
# 23  gsea                HALLMARK_IL2_STAT5_SIGNALING  0.389213   1.79935
# 24  gsea                         HALLMARK_PEROXISOME -0.376627 -1.782198
# 25  gsea                  HALLMARK_ANDROGEN_RESPONSE -0.423314 -1.767171
# 26  gsea                     HALLMARK_APICAL_SURFACE  0.474812  1.748082
# 27  gsea                  HALLMARK_KRAS_SIGNALING_UP   0.39683  1.713772
# 28  gsea              HALLMARK_FATTY_ACID_METABOLISM  -0.34807 -1.608866
# 29  gsea                        HALLMARK_P53_PATHWAY -0.305567 -1.584981
# 30  gsea                    HALLMARK_MITOTIC_SPINDLE -0.354639 -1.574618
# 31  gsea                        HALLMARK_COAGULATION -0.349934 -1.572822
# 32  gsea                    HALLMARK_HEME_METABOLISM -0.279274 -1.503484
# 33  gsea                 HALLMARK_HEDGEHOG_SIGNALING -0.414831 -1.503427
# 34  gsea                HALLMARK_PANCREAS_BETA_CELLS -0.479977 -1.478063
# 35  gsea            HALLMARK_TNFA_SIGNALING_VIA_NFKB  0.317788  1.471048
# 36  gsea                         HALLMARK_COMPLEMENT -0.284447 -1.467878
# 37  gsea                         HALLMARK_DNA_REPAIR -0.332643 -1.467015
# 38  gsea    HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY  0.390368  1.444654
# 39  gsea               HALLMARK_BILE_ACID_METABOLISM    -0.317  -1.43878
# 40  gsea                  HALLMARK_PROTEIN_SECRETION -0.312173 -1.425561
# 41  gsea                     HALLMARK_UV_RESPONSE_UP -0.273926 -1.384326
# 42  gsea            HALLMARK_IL6_JAK_STAT3_SIGNALING  0.334015  1.374585
# 43  gsea                 HALLMARK_TGF_BETA_SIGNALING  0.357245  1.371401
# 44  gsea                       HALLMARK_ANGIOGENESIS  0.359177  1.283069
# 45  gsea         HALLMARK_WNT_BETA_CATENIN_SIGNALING  0.292505  1.158588
# 46  gsea          HALLMARK_OXIDATIVE_PHOSPHORYLATION -0.310442 -1.119895
# 47  gsea                  HALLMARK_KRAS_SIGNALING_DN  0.235662    1.0334
# 48  gsea                    HALLMARK_NOTCH_SIGNALING  0.265017  1.017887
# 49  gsea                    HALLMARK_SPERMATOGENESIS  0.236503  1.016607
#
#    NOM p-val FDR q-val FWER p-val   Tag %  Gene %  \
# 0        0.0       0.0        0.0  35/152   7.52%
# 1        0.0       0.0        0.0  46/150   7.51%
# 2        0.0       0.0        0.0  75/190  13.74%
# 3        0.0       0.0        0.0  41/149   9.53%
# 4        0.0       0.0        0.0  45/157  10.56%
# 5        0.0       0.0        0.0  42/107  14.71%
# 6        0.0       0.0        0.0  34/138   9.17%
# 7        0.0       0.0        0.0  22/113   7.07%
# 8        0.0       0.0        0.0   24/64   9.69%
# 9        0.0       0.0        0.0  90/187  17.07%
# 10       0.0  0.000131      0.001  42/169   8.39%
# 11       0.0   0.00036      0.003  75/185  14.35%
# 12       0.0  0.001679      0.002   30/90   9.30%
# 13  0.002062  0.000554      0.004  88/190  14.56%
# 14       0.0  0.000617      0.004  49/164  11.90%
# 15       0.0  0.000576      0.004  24/123   9.61%
# 16       0.0  0.005598      0.015  44/161   9.30%
# 17       0.0   0.00126      0.012  41/177  10.56%
# 18       0.0  0.002966      0.028  34/132  11.78%
# 19       0.0  0.003361      0.034  28/139   9.97%
# 20       0.0  0.003487      0.038   36/87  19.46%
# 21       0.0  0.003961      0.045  30/128   9.49%
# 22       0.0   0.00391      0.046   23/57  21.38%
# 23       0.0  0.017541      0.059  39/148  12.03%
# 24       0.0  0.007726      0.079   22/84  15.63%
# 25       0.0  0.008518      0.089   17/86   7.48%
# 26  0.004237  0.022113      0.097    9/28   5.06%
# 27       0.0  0.025416      0.129  44/139  14.60%
# 28  0.003953   0.03013      0.266  30/134  12.49%
# 29       0.0  0.035378      0.302  41/175  14.21%
# 30  0.041985  0.036843      0.319  45/171  13.35%
# 31   0.00789  0.035958      0.321   23/91  12.28%
# 32     0.014  0.057053      0.434  29/166  10.63%
# 33  0.052734  0.055085      0.434    7/29   4.59%
# 34  0.069388   0.06218      0.493    2/15   2.25%
# 35   0.05988  0.123814      0.514  32/160   9.27%
# 36  0.005906  0.063706      0.512  33/149  14.78%
# 37   0.06962   0.06194      0.512  44/145  22.29%
# 38  0.109827   0.12364      0.564   10/42   6.72%
# 39  0.032946  0.070452      0.566   12/79   8.96%
# 40  0.072314  0.073675      0.594   16/91   8.85%
# 41  0.061181  0.088485      0.672  31/136  14.54%
# 42  0.044715  0.161088      0.691   10/58   8.30%
# 43  0.120079  0.145118      0.696   15/44  13.03%
# 44  0.157258  0.205958      0.845    7/26   4.70%
# 45  0.210634  0.322406      0.957   12/35  22.10%
# 46  0.351129  0.296815      0.975  61/195  22.47%
# 47  0.395833  0.476221      0.991   26/92  21.84%
# 48  0.425101  0.463058      0.994   10/28  18.64%
# 49  0.431298  0.432062      0.994   24/73  22.31%
#
#                                            Lead_genes
# 0   SPINT2;TGFB2;CDA;PAPSS2;PC;PYCR1;AOX1;PINK1;SL...
# 1   F3;CAV1;ENO1;PLAC8;VLDLR;ERRFI1;PGK1;NDRG1;AK4...
# 2   HSPD1;ENO1;CALR;FADS2;DHCR24;SCD;G6PD;DHCR7;VL...
# 3   FSTL1;MATN2;TIMP3;CDH11;COL6A2;MEST;THBS1;FLNA...
# 4   UGCG;KRT8;KRT19;PAPSS2;KRT18;INHBB;DHCR7;SLC7A...
# 5   CALR;SLC7A5;EEF2;DKC1;KHSRP;PSAT1;SRPRB;FUS;BA...
# 6   ICAM1;MYH10;CDH11;ACTG1;CDH4;INSIG1;CAP1;TIAL1...
# 7   F3;CAV1;EFEMP1;VLDLR;INSIG1;COL1A2;FHL2;SDC2;F...
# 8   FADS2;ACTG1;SCD;DHCR7;ERRFI1;LSS;ALDOC;MAL2;GS...
# 9   HMGB3;MYBL2;PRPS1;CDCA8;KIF2C;CDC20;HMGB2;STMN...
# 10  ENO1;PRPS1;PC;PKM;G6PD;VLDLR;PGK1;ARTN;AK4;PFK...
# 11  HMGN2;HMGB3;MYBL2;KIF2C;SLC7A5;CDC20;STMN1;DKC...
# 12  IFIT3;IFI44;HERC6;SAMD9;RSAD2;IFIH1;B2M;SAMD9L...
# 13  HSPD1;PABPC4;PGK1;VBP1;PRDX3;EIF3B;CDC20;SERBP...
# 14  CAV1;TRIM29;MEST;CKB;KRT19;PAPSS2;DHCR7;SLC7A5...
# 15  ICAM1;IL11;TGFB2;FLNA;INHBB;INHBA;ELF4;RPS3A;A...
# 16  IFIT3;IFI44;HERC6;NAMPT;CDKN1A;ST8SIA4;IFIT1;O...
# 17  UCP2;DHCR7;MYLK;SLC1A5;PRDX3;IDH3G;RTN3;SCP2;P...
# 18  CAV1;TIMP3;TGFB2;H1-0;TNFSF10;KRT18;APP;HMGB2;...
# 19  F3;ICAM1;BST2;TNFSF10;INHBA;SLC4A4;CD55;PVR;CX...
# 20  CALR;RPS6KA1;AKT1;SFN;PPP1CA;NGF;MKNK2;TRIB3;A...
# 21  COL6A2;CKB;PC;WWTR1;SCD;APP;MYLK;ATP6AP1;ITGB4...
# 22  HSPD1;HK2;PLK1;MAP3K6;NOP2;SRM;PA2G4;NOLC1;SLC...
# 23  PRNP;NT5E;TNFRSF1B;EMP1;SPRY4;ITGA6;CD44;TNFRS...
# 24  DHCR24;ACSL4;SCP2;CTPS1;YWHAH;PRDX1;SOD1;DHRS3...
# 25  KRT8;SMS;KRT19;H1-0;DHCR24;SCD;INSIG1;NDRG1;AK...
# 26  CX3CL1;PLAUR;SRPX;DCBLD2;MDGA1;GSTM3;BRCA1;AKA...
# 27  GFPT2;ITGA2;TNFRSF1B;KCNN4;PLAT;EMP1;PLAUR;DNM...
# 28  SMS;DHCR24;TP53INP2;ACSL4;IDH3G;GLUL;MGLL;CBR1...
# 29  PRMT2;INHBB;IRAK1;PLK2;APP;NDRG1;ITGB4;SFN;EPH...
# 30  MYH10;FLNA;KIF2C;CAPZB;PCNT;TPX2;CDC42;KIF23;I...
# 31  F3;TIMP3;THBS1;CRIP2;FYN;WDR1;C3;F8;ADAM9;PDGF...
# 32  UCP2;PC;H1-0;MPP1;SELENBP1;PDZK1IP1;C3;MKRN1;S...
# 33             VLDLR;L1CAM;AMOT;NRP2;CELSR1;SHH;PTCH1
# 34                                        FOXA2;SRPRB
# 35  KYNU;PMEPA1;GFPT2;SQSTM1;NAMPT;CDKN1A;TSC22D1;...
# 36  F3;CDA;CALM3;PCSK9;CD55;CXCL1;FYN;C3;F8;ADAM9;...
# 37  CDA;SF3A3;BCAP31;RALA;ARL6IP1;TYMS;IMPDH2;NME4...
# 38  PRNP;GPX3;SOD2;CAT;NQO1;TXNRD2;PTPA;MBP;GLRX;GCLC
# 39  FADS2;DHCR24;HSD3B1;SCP2;SOD1;ACSL1;FADS1;PXMP...
# 40  BNIP3;KRT18;CAV2;OCRL;PPT1;SOD1;AP2M1;RER1;LAM...
# 41  ICAM1;STIP1;PPT1;CREG1;CDK2;SLC25A4;MARK2;EIF2...
# 42  TNFRSF1B;CD44;TNFRSF21;IL17RA;STAM2;TGFB1;CBL;...
# 43  SLC20A1;PMEPA1;FURIN;APC;CDK9;TGFB1;KLF10;PPM1...
# 44          THBD;VEGFA;TNFRSF21;STC1;ITGAV;TIMP1;VCAN
# 45  FZD1;MAML1;CUL1;NUMB;NOTCH1;NCSTN;PSEN2;KAT2A;...
# 46  PRDX3;SLC25A5;ATP6AP1;GPI;IDH3G;ATP5F1A;OAT;AT...
# 47  RSAD2;NR4A2;CAMK1D;SPTBN2;C5;SLC25A23;TENT5C;T...
# 48  FZD1;WNT5A;CUL1;ST3GAL6;NOTCH3;NOTCH1;PSENEN;P...
# 49  HSPA4L;GSTM3;TALDO1;IDE;STAM2;BUB1;CCNA1;MAP7;...
