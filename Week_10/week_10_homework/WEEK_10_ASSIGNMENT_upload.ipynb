# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Week 10 Assignment</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# <strong><u>Due: Saturday, November 8 at 11:59PM</u></strong>
#
# <strong><u>Total points: 5 pts</u></strong>
#
# <strong><u>To turn in your assignment:</u></strong>
# <ol>
#     <li>Complete assignment and make sure you have all the outputs requested for the notebook</li>
#     <li>Go to your server's file directory and locate the <code>week_10_homework</code> directory containing all your outputs from this assignment including this notebook</li>
#     <li>Right click and select <strong>Download as an Archive</strong> to download the <code>week_10_homework</code> directory as a ZIP folder. Do not mix up with <strong>Download Current Folder as an Archive</strong></li>
#     <li>Upload your ZIP folder to your individual feedback Google Drive folder under <code>MCB201B</code></li>
# </ol>
#
# <strong><u>How this assignment will be graded:</u></strong>
#
# You will be graded on whether or not you have <u>all requested outputs and files</u> and if your output is correct. You will also be graded on if your code is expected to be able to run without errors. For those of you running code in Terminal or on your own computer, you will need to write out your input(s) into the empty code cell for this notebook. You don't need to run them here. If you used line breaks, make sure not to transfer over the <code>&gt;</code> symbol at the start of each new line. There can be more than one correct way to answer a question. If you find that you prefer to separate your answer for a single question into multiple code cells, feel free to do so.
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%px;"></hr>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h2>Question 1</h2>

# %% [markdown]
# 1pt

# %% [markdown]
# From your previous <strong>full analysis</strong> of our ChIP-seq datasets for <code>taz_1</code> and <code>taz_2</code>, assign ranks to each peak that was called by <code>macs2</code> separately for each TAZ replicate using the <code>'-log10(qvalue)'</code> from <code>*_peaks.xls</code> output files. Output into this notebook the top 10 peaks for each replicate.

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%px;"></hr>

# %% [markdown]
# <h2>Question 2</h2>

# %% [markdown]
# 1pt

# %% [markdown]
# Use HOMER to identify peaks present in both <code>taz_1</code> and <code>taz_2</code>. Then create a scatter plot that visualizes the ranks of each replicate's peaks with their rank in <code>taz_1</code> along the x-axis and their rank in <code>taz_2</code> along the y-axis. Label axes accordingly. Output the scatter plot into this notebook, and you do not need to separately submit a PDF output.

# %%
# %%bash
#
# #Copy over your Terminal code here, but you do not need to run it.

# %%
#This code cell and additional code cells you make
#can be used for the rest of this question.

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%px;"></hr>

# %% [markdown]
# <h2>Question 3</h2>

# %% [markdown]
# 1pt

# %% [markdown]
# Identify peaks present in both <code>taz_1</code> and <code>taz_2</code>, and are ranked in the top 500 in both replicates. Use these peaks for motif analysis with HOMER. Plot the motif distribution around your top set of peaks for your top 3 motifs. Label axes and provide legend as appropriate.

# %%
# %%bash
#
# #Copy over your Terminal code here, but you do not need to run it.

# %%
#This code cell and additional code cells you make
#can be used for the rest of this question.

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%px;"></hr>

# %% [markdown]
# <h2>Question 4</h2>

# %% [markdown]
# 1pt

# %% [markdown]
# Use either your bash script from class or Jack's bash script (making adjustments as needed to analyze your group's dataset) to analyze your <strong>full</strong> RNA-seq dataset for your group. You will need to:
#
# <ol>
#     <li>Pull out 10 reads from each of your group's sequence files. <strong>Submit the outputs as part of your homework submission.</strong></li>
#     <li>Run FastQC on all four of your group's sequence files. <strong>Submit the outputs as part of your homework submission.</strong></li>
#     <li>Align your paired-end reads for both sample conditions to the hg19 reference genome. You do not need to submit any alignment output files.</li>
#     <li>Process your alignment outputs as we did in class for visualization in IGV and for read counting with <code>htseq-count</code>. You do not need to submit any output files from samtools, but make sure to delete your SAMs.</li>
#     <li>Quantify read abundance for each gene using <code>htseq-count</code> as we did in class. <strong>Submit your output <code>.txt</code> file from <code>htseq-count</code>.</li>
# </ol>
#
# No need to copy over any code or script for this question.

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%px;"></hr>

# %% [markdown]
# <h2>Question 5</h2>

# %% [markdown]
# 1pt

# %% [markdown]
# Load in your control sample's position-sorted <code>.bam</code> and <code>.bam.bai</code> and your TAZ KO sample's position-sorted <code>.bam</code> and <code>.bam.bai</code> files into IGV. Navigate to the following genomic range for TAZ (WWTR1):
#
# ```
# chr3:149,232,978-149,325,800
# ```
#
# Confirm that you can visualize the reads for TAZ, and save as a PNG to include with your homework submission.
# <strong>Once you've completed your homework assignment, go ahead and delete all your <code>.bam</code> and <code>.bam.bai</code> files (both name-sorted and position-sorted) to reduce storage usage on the Biology Hub.</strong> Jack will provide backups if you need, so feel free to delete your BAMs, BAM.BAIs, and SAMs.

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%px;"></hr>
