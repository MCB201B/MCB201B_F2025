# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Week 7 Assignment</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# <strong><u>Due: Saturday, October 18 at 11:59PM</u></strong>
#
# <strong><u>Total points: 5 pts</u></strong>
#
# <strong><u>To turn in your assignment:</u></strong>
# <ol>
#     <li>Complete assignment and make sure you have all the outputs requested for the notebook</li>
#     <li>Go to your server's file directory and locate the <code>week_7_homework</code> directory containing all your outputs from this assignment including this notebook</li>
#     <li>Right click and select <strong>Download as an Archive</strong> to download the <code>week_7_homework</code> directory as a ZIP folder. Do not mix up with <strong>Download Current Folder as an Archive</strong></li>
#     <li>Upload your ZIP folder to your individual feedback Google Drive folder under <code>MCB201B</code></li>
# </ol>
#
# <strong><u>How this assignment will be graded:</u></strong>
#
# You will be graded on whether or not you have <u>all requested outputs and files</u> and if your output is correct. You will also be graded on if your code is expected to be able to run without errors. For those of you running code in Terminal or on your own computer, you will need to write out your input(s) into the empty code cell for this notebook. You don't need to run them here. If you used line breaks, make sure not to transfer over the <code>&gt;</code> symbol at the start of each new line. There can be more than one correct way to answer a question. If you find that you prefer to separate your answer for a single question into multiple code cells, feel free to do so.
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%px;"></hr>

# %% [markdown]
# <h2>Question 1</h2>

# %% [markdown]
# 1pt

# %% [markdown]
# <ol>
#     <li>Create a new directory to hold your full alignments using the following file path: <code>~/MCB201B_F2025/Week_7/full-alignment</code>. Save your SAM/BAM/BAM.BAI files to this directory. <strong>Please do not submit your SAM/BAM/BAM.BAI files (they are huge...)</strong></li>
#     <li>Align the following <code>.fastq.gz</code> files to the hg19 reference genome using bowtie2. Use the <code>full-alignment</code> directory that you created to save the outputs from <code>bowtie2</code>.</li>
#
# <ul>
#     <li>ctrl_1.fastq.gz</li>
#     <li>ctrl_2.fastq.gz</li>
#     <li>taz_1.fastq.gz</li>
#     <li>taz_2.fastq.gz</li>
# </ul>
#     <li>Redirect the first 10 lines of each SAM file into its own <code>.txt</code> file (one for each SAM file). Save the <code>.txt</code> files into <code>week_7_homework</code> folder to be included with your submission.</li>
# </ol>

# %%
# %%bash
#
# #Copy over/write your Terminal inputs here if you did your homework in Terminal or on your own computer
# #You will be graded on whether or not you have the correct code to complete this question
# #If you ran the code in Terminal, you don't need to re-run it here

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%px;"></hr>

# %% [markdown]
# <h2>Question 2</h2>

# %% [markdown]
# 1pt

# %% [markdown]
# <ol>
#     <li>Create a new directory to hold your peak calling outputs using the following file path: <code>~/MCB201B_F2025/Week_7/full-alignment/macs2</code>. Save your <code>macs2</code> output files to this directory. <strong>Please do not submit all the <code>macs2</code> outputs (they are also huge...)</strong></li>
#     <li>Call peaks for your control files (pooling together only ctrl_1 and ctrl_2) using <code>macs2</code>. Run the resulting R script file (file has the extension <code>.r</code>) to obtain a PDF of the shift and cross-correlation plots. Save the PDF output into <code>week_7_homework</code> to be included as part of your homework submission. You do not need to turn in the other <code>macs2</code> outputs.</li>
# </ol>

# %%
# %%bash
#
# #Copy over/write your Terminal inputs here if you did your homework in Terminal or on your own computer
# #You will be graded on whether or not you have the correct code to complete this question
# #If you ran the code in Terminal, you don't need to re-run it here

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%px;"></hr>

# %% [markdown]
# <h2>Question 3</h2>

# %% [markdown]
# 1pt

# %% [markdown]
# Call peaks for taz_1 and taz_2 (not pooled) using macs2 and set the control as your control files (pooling together only ctrl_1 and ctrl_2). Run the resulting R script files for both taz_1 and taz_2 to obtain a PDF of the shift and cross-correlation plots. Save the two PDF outputs into <code>week_7_homework</code> to be included as part of your homework submission. You do not need to turn in the other <code>macs2</code> outputs.

# %%
# %%bash
#
# #Copy over/write your Terminal inputs here if you did your homework in Terminal or on your own computer
# #You will be graded on whether or not you have the correct code to complete this question
# #If you ran the code in Terminal, you don't need to re-run it here

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%px;"></hr>

# %% [markdown]
# <h2>Question 4</h2>

# %% [markdown]
# 1pt

# %% [markdown]
# Load your taz_1 and taz_2 <code>.xls</code> files into Python, like we did in class, and create a new <code>.csv</code> file containing just the top 100 most significant peaks for each replicate according to the <code>'-log10(qvalue)'</code>. Save the <code>.csv</code> outputs into <code>week_7_homework</code>. You do not need to submit the full <code>.xls</code> files.
#
# <strong>If you're worried about your command line code in other code cells running by accident, you can switch those code cells to Markdown cells or comment out your code.</code>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%px;"></hr>

# %% [markdown]
# <h2>Question 5</h2>

# %% [markdown]
# 1pt

# %% [markdown]
# <ol>
#     <li>Prepare your full alignment files for visualization in IGV as we did in class.</li>
#     <li>Using IGV, load in your <code>ctrl_treat_pileup.bdg</code>, your <code>taz_1_treat_pileup.bdg</code>, and your <code>taz_2_treat_pileup.bdg</code> for the full datasets. Find the most significant peak for taz_1. Adjust the data range for all .bdg tracks to be the same and as reasonable to visualize and compare the calculated pileups. Save your view as a PNG. Place the PNG file into your <code>week_7_homework</code> directory to be included with your submission.</li>
# </ol>

# %%
# %%bash
#
# #Copy over/write your Terminal inputs here if you did your homework in Terminal or on your own computer
# #You will be graded on whether or not you have the correct code to complete this question
# #If you ran the code in Terminal, you don't need to re-run it here

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%px;"></hr>
