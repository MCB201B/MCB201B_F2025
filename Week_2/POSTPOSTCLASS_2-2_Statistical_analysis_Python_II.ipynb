# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">2.2 Statistical Analysis in Python (II)</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 700px;"></hr>

# %% [markdown]
# We'll continue practicing some more statistical analysis using the data that we've collected from MCB201A. Like with notebook 2-1, this notebook will lean more towards independent exercises, and in the first exercise, you'll run a regression analysis using your group's BCA assay absorbance data and use the resulting standard curve to quantify the protein concentrations of your samples. You'll also run a linear regression on our class xenograft data to determine if there is a strong correlation between tumor volume and tumor weight and if that changes upon TAZ KO. Then you'll learn how to take what you've done so far and apply it to setting up a Python script to analyze some hypothetical results to learn one approach towards setting up a streamlined analysis workflow.
#
# <strong>Learning objectives:</strong>
# <ul>
#     <li>Practice linear regression in Python</li>
#     <li>Additional plotting practice</li>
#     <li>More operating system functionalities</li>
#     <li>Setting up a basic module</li>
#     <li>Creating a Python script for analysis</li>
#     <li>Execute a Python script</li>
# </ul>

# %% [markdown]
# <h2>Import Packages</h2>

# %%
#Import our packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import os

# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Exercise #1 - Linear regression for calibration</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 850px;"></hr>

# %% [markdown]
# For this first exercise, you'll run a regression analysis on your group's BCA data and then use that resulting information to calculate the concentrations of your unknown protein samples. This will also touch on some of the steps from your homework assignment as well and can hopefully help if you haven't started on it yet.
#
# First load in your BCA data - you can use the file that you uploaded for your Week 1 homework assignment and leave in the standards and unknowns.

# %%
bca = pd.read_csv('/home/jovyan/MCB201B_F2025/Week_1/week_1_homework/G5_BCA.csv',
                  skiprows=23,
                  nrows=2,
                  index_col='Unnamed: 1'
                 )

# %%
bca.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_e7363">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7363_level0_col0" class="col_heading level0 col0" >Unnamed: 0</th>
#       <th id="T_e7363_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_e7363_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_e7363_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_e7363_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_e7363_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_e7363_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_e7363_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_e7363_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_e7363_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_e7363_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_e7363_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_e7363_level0_col12" class="col_heading level0 col12" >12</th>
#       <th id="T_e7363_level0_col13" class="col_heading level0 col13" >Unnamed: 14</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7363_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_e7363_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_e7363_row0_col1" class="data row0 col1" >1.060000</td>
#       <td id="T_e7363_row0_col2" class="data row0 col2" >0.880000</td>
#       <td id="T_e7363_row0_col3" class="data row0 col3" >0.682000</td>
#       <td id="T_e7363_row0_col4" class="data row0 col4" >0.538000</td>
#       <td id="T_e7363_row0_col5" class="data row0 col5" >0.419000</td>
#       <td id="T_e7363_row0_col6" class="data row0 col6" >0.273000</td>
#       <td id="T_e7363_row0_col7" class="data row0 col7" >0.209000</td>
#       <td id="T_e7363_row0_col8" class="data row0 col8" >0.138000</td>
#       <td id="T_e7363_row0_col9" class="data row0 col9" >0.118000</td>
#       <td id="T_e7363_row0_col10" class="data row0 col10" >0.263000</td>
#       <td id="T_e7363_row0_col11" class="data row0 col11" >0.317000</td>
#       <td id="T_e7363_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_e7363_row0_col13" class="data row0 col13" >BCA read:562</td>
#     </tr>
#     <tr>
#       <th id="T_e7363_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_e7363_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_e7363_row1_col1" class="data row1 col1" >1.068000</td>
#       <td id="T_e7363_row1_col2" class="data row1 col2" >0.870000</td>
#       <td id="T_e7363_row1_col3" class="data row1 col3" >0.660000</td>
#       <td id="T_e7363_row1_col4" class="data row1 col4" >0.509000</td>
#       <td id="T_e7363_row1_col5" class="data row1 col5" >0.406000</td>
#       <td id="T_e7363_row1_col6" class="data row1 col6" >0.267000</td>
#       <td id="T_e7363_row1_col7" class="data row1 col7" >0.196000</td>
#       <td id="T_e7363_row1_col8" class="data row1 col8" >0.128000</td>
#       <td id="T_e7363_row1_col9" class="data row1 col9" >0.117000</td>
#       <td id="T_e7363_row1_col10" class="data row1 col10" >0.245000</td>
#       <td id="T_e7363_row1_col11" class="data row1 col11" >0.290000</td>
#       <td id="T_e7363_row1_col12" class="data row1 col12" >nan</td>
#       <td id="T_e7363_row1_col13" class="data row1 col13" >BCA read:562</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's do a quick sanity check to see how it imported.

# %% [markdown]
# If you need, make small adjustments to your DataFrame and update the column labels.

# %%
bca.drop(columns=['Unnamed: 0', '12', 'Unnamed: 14'], inplace=True)

# %%
bca.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_06118">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06118_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_06118_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_06118_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_06118_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_06118_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_06118_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_06118_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_06118_level0_col7" class="col_heading level0 col7" >8</th>
#       <th id="T_06118_level0_col8" class="col_heading level0 col8" >9</th>
#       <th id="T_06118_level0_col9" class="col_heading level0 col9" >10</th>
#       <th id="T_06118_level0_col10" class="col_heading level0 col10" >11</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06118_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_06118_row0_col0" class="data row0 col0" >1.060000</td>
#       <td id="T_06118_row0_col1" class="data row0 col1" >0.880000</td>
#       <td id="T_06118_row0_col2" class="data row0 col2" >0.682000</td>
#       <td id="T_06118_row0_col3" class="data row0 col3" >0.538000</td>
#       <td id="T_06118_row0_col4" class="data row0 col4" >0.419000</td>
#       <td id="T_06118_row0_col5" class="data row0 col5" >0.273000</td>
#       <td id="T_06118_row0_col6" class="data row0 col6" >0.209000</td>
#       <td id="T_06118_row0_col7" class="data row0 col7" >0.138000</td>
#       <td id="T_06118_row0_col8" class="data row0 col8" >0.118000</td>
#       <td id="T_06118_row0_col9" class="data row0 col9" >0.263000</td>
#       <td id="T_06118_row0_col10" class="data row0 col10" >0.317000</td>
#     </tr>
#     <tr>
#       <th id="T_06118_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_06118_row1_col0" class="data row1 col0" >1.068000</td>
#       <td id="T_06118_row1_col1" class="data row1 col1" >0.870000</td>
#       <td id="T_06118_row1_col2" class="data row1 col2" >0.660000</td>
#       <td id="T_06118_row1_col3" class="data row1 col3" >0.509000</td>
#       <td id="T_06118_row1_col4" class="data row1 col4" >0.406000</td>
#       <td id="T_06118_row1_col5" class="data row1 col5" >0.267000</td>
#       <td id="T_06118_row1_col6" class="data row1 col6" >0.196000</td>
#       <td id="T_06118_row1_col7" class="data row1 col7" >0.128000</td>
#       <td id="T_06118_row1_col8" class="data row1 col8" >0.117000</td>
#       <td id="T_06118_row1_col9" class="data row1 col9" >0.245000</td>
#       <td id="T_06118_row1_col10" class="data row1 col10" >0.290000</td>
#     </tr>
#   </tbody>
# </table>

# %%
new_names = [2.0, 1.5, 1.0, 0.75, 0.5, 0.25, 0.125, 0.025, 0, 'ko', 'ctrl']

for old, new in zip(bca.columns, new_names):
    bca.rename(columns={old:new}, inplace=True)

# %% [markdown]
# Let's take a look to see how it updated.

# %%
bca.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_d9cca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9cca_level0_col0" class="col_heading level0 col0" >2.000000</th>
#       <th id="T_d9cca_level0_col1" class="col_heading level0 col1" >1.500000</th>
#       <th id="T_d9cca_level0_col2" class="col_heading level0 col2" >1.000000</th>
#       <th id="T_d9cca_level0_col3" class="col_heading level0 col3" >0.750000</th>
#       <th id="T_d9cca_level0_col4" class="col_heading level0 col4" >0.500000</th>
#       <th id="T_d9cca_level0_col5" class="col_heading level0 col5" >0.250000</th>
#       <th id="T_d9cca_level0_col6" class="col_heading level0 col6" >0.125000</th>
#       <th id="T_d9cca_level0_col7" class="col_heading level0 col7" >0.025000</th>
#       <th id="T_d9cca_level0_col8" class="col_heading level0 col8" >0</th>
#       <th id="T_d9cca_level0_col9" class="col_heading level0 col9" >ko</th>
#       <th id="T_d9cca_level0_col10" class="col_heading level0 col10" >ctrl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9cca_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_d9cca_row0_col0" class="data row0 col0" >1.060000</td>
#       <td id="T_d9cca_row0_col1" class="data row0 col1" >0.880000</td>
#       <td id="T_d9cca_row0_col2" class="data row0 col2" >0.682000</td>
#       <td id="T_d9cca_row0_col3" class="data row0 col3" >0.538000</td>
#       <td id="T_d9cca_row0_col4" class="data row0 col4" >0.419000</td>
#       <td id="T_d9cca_row0_col5" class="data row0 col5" >0.273000</td>
#       <td id="T_d9cca_row0_col6" class="data row0 col6" >0.209000</td>
#       <td id="T_d9cca_row0_col7" class="data row0 col7" >0.138000</td>
#       <td id="T_d9cca_row0_col8" class="data row0 col8" >0.118000</td>
#       <td id="T_d9cca_row0_col9" class="data row0 col9" >0.263000</td>
#       <td id="T_d9cca_row0_col10" class="data row0 col10" >0.317000</td>
#     </tr>
#     <tr>
#       <th id="T_d9cca_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_d9cca_row1_col0" class="data row1 col0" >1.068000</td>
#       <td id="T_d9cca_row1_col1" class="data row1 col1" >0.870000</td>
#       <td id="T_d9cca_row1_col2" class="data row1 col2" >0.660000</td>
#       <td id="T_d9cca_row1_col3" class="data row1 col3" >0.509000</td>
#       <td id="T_d9cca_row1_col4" class="data row1 col4" >0.406000</td>
#       <td id="T_d9cca_row1_col5" class="data row1 col5" >0.267000</td>
#       <td id="T_d9cca_row1_col6" class="data row1 col6" >0.196000</td>
#       <td id="T_d9cca_row1_col7" class="data row1 col7" >0.128000</td>
#       <td id="T_d9cca_row1_col8" class="data row1 col8" >0.117000</td>
#       <td id="T_d9cca_row1_col9" class="data row1 col9" >0.245000</td>
#       <td id="T_d9cca_row1_col10" class="data row1 col10" >0.290000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Now, like with our homework assignment, let's split our unknowns from our standards. We can save each one to it's own variable.

# %%
bca_standard = bca.loc[:, 2:0]

# %%
bca_standard.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_5a673">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a673_level0_col0" class="col_heading level0 col0" >2.000000</th>
#       <th id="T_5a673_level0_col1" class="col_heading level0 col1" >1.500000</th>
#       <th id="T_5a673_level0_col2" class="col_heading level0 col2" >1.000000</th>
#       <th id="T_5a673_level0_col3" class="col_heading level0 col3" >0.750000</th>
#       <th id="T_5a673_level0_col4" class="col_heading level0 col4" >0.500000</th>
#       <th id="T_5a673_level0_col5" class="col_heading level0 col5" >0.250000</th>
#       <th id="T_5a673_level0_col6" class="col_heading level0 col6" >0.125000</th>
#       <th id="T_5a673_level0_col7" class="col_heading level0 col7" >0.025000</th>
#       <th id="T_5a673_level0_col8" class="col_heading level0 col8" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a673_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_5a673_row0_col0" class="data row0 col0" >1.060000</td>
#       <td id="T_5a673_row0_col1" class="data row0 col1" >0.880000</td>
#       <td id="T_5a673_row0_col2" class="data row0 col2" >0.682000</td>
#       <td id="T_5a673_row0_col3" class="data row0 col3" >0.538000</td>
#       <td id="T_5a673_row0_col4" class="data row0 col4" >0.419000</td>
#       <td id="T_5a673_row0_col5" class="data row0 col5" >0.273000</td>
#       <td id="T_5a673_row0_col6" class="data row0 col6" >0.209000</td>
#       <td id="T_5a673_row0_col7" class="data row0 col7" >0.138000</td>
#       <td id="T_5a673_row0_col8" class="data row0 col8" >0.118000</td>
#     </tr>
#     <tr>
#       <th id="T_5a673_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_5a673_row1_col0" class="data row1 col0" >1.068000</td>
#       <td id="T_5a673_row1_col1" class="data row1 col1" >0.870000</td>
#       <td id="T_5a673_row1_col2" class="data row1 col2" >0.660000</td>
#       <td id="T_5a673_row1_col3" class="data row1 col3" >0.509000</td>
#       <td id="T_5a673_row1_col4" class="data row1 col4" >0.406000</td>
#       <td id="T_5a673_row1_col5" class="data row1 col5" >0.267000</td>
#       <td id="T_5a673_row1_col6" class="data row1 col6" >0.196000</td>
#       <td id="T_5a673_row1_col7" class="data row1 col7" >0.128000</td>
#       <td id="T_5a673_row1_col8" class="data row1 col8" >0.117000</td>
#     </tr>
#   </tbody>
# </table>

# %%
bca_unknowns = bca.loc[:, ['ctrl', 'ko']]
bca_unknowns.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_22510">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22510_level0_col0" class="col_heading level0 col0" >ctrl</th>
#       <th id="T_22510_level0_col1" class="col_heading level0 col1" >ko</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22510_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_22510_row0_col0" class="data row0 col0" >0.317000</td>
#       <td id="T_22510_row0_col1" class="data row0 col1" >0.263000</td>
#     </tr>
#     <tr>
#       <th id="T_22510_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_22510_row1_col0" class="data row1 col0" >0.290000</td>
#       <td id="T_22510_row1_col1" class="data row1 col1" >0.245000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's see how the two resulting DataFrames look now.

# %% [markdown]
# <h2>Correct for background absorbance</h2>

# %% [markdown]
# Now let's correct for background absorbance using the mean of the background replicates.

# %%
bca_std_corr = bca_standard - bca_standard.loc[:,0].mean()

# %%
bca_std_corr
# Out:
#       2.0     1.5     1.0    0.75     0.5    0.25   0.125   0.025       0
# A  0.9425  0.7625  0.5645  0.4205  0.3015  0.1555  0.0915  0.0205  0.0005
# B  0.9505  0.7525  0.5425  0.3915  0.2885  0.1495  0.0785  0.0105 -0.0005

# %%
bca_unk_corr = bca_unknowns - bca_standard.loc[:,0].mean()

# %%
bca_unk_corr.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_454bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_454bc_level0_col0" class="col_heading level0 col0" >ctrl</th>
#       <th id="T_454bc_level0_col1" class="col_heading level0 col1" >ko</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_454bc_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_454bc_row0_col0" class="data row0 col0" >0.199500</td>
#       <td id="T_454bc_row0_col1" class="data row0 col1" >0.145500</td>
#     </tr>
#     <tr>
#       <th id="T_454bc_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_454bc_row1_col0" class="data row1 col0" >0.172500</td>
#       <td id="T_454bc_row1_col1" class="data row1 col1" >0.127500</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <h2>Run a linear regression analysis</h2>

# %% [markdown]
# With your mean corrected absorbances, use <code>stats.linregress()</code> to run a linear regression analysis using your protein standards. <a href="https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.linregress.html" rel="noopener noreferrer"><u>Documentation for <code>stats.linregress()</code> can be found here.</u></a>

# %%
bca_std_corr.mean()
# Out:
# 2.0      9.465000e-01
# 1.5      7.575000e-01
# 1.0      5.535000e-01
# 0.75     4.060000e-01
# 0.5      2.950000e-01
# 0.25     1.525000e-01
# 0.125    8.500000e-02
# 0.025    1.550000e-02
# 0        6.938894e-18
# dtype: float64

# %%
bca_std_corr.loc['mean',:] = bca_std_corr.mean()

# %%
bca_std_corr.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_6a800">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a800_level0_col0" class="col_heading level0 col0" >2.000000</th>
#       <th id="T_6a800_level0_col1" class="col_heading level0 col1" >1.500000</th>
#       <th id="T_6a800_level0_col2" class="col_heading level0 col2" >1.000000</th>
#       <th id="T_6a800_level0_col3" class="col_heading level0 col3" >0.750000</th>
#       <th id="T_6a800_level0_col4" class="col_heading level0 col4" >0.500000</th>
#       <th id="T_6a800_level0_col5" class="col_heading level0 col5" >0.250000</th>
#       <th id="T_6a800_level0_col6" class="col_heading level0 col6" >0.125000</th>
#       <th id="T_6a800_level0_col7" class="col_heading level0 col7" >0.025000</th>
#       <th id="T_6a800_level0_col8" class="col_heading level0 col8" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a800_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_6a800_row0_col0" class="data row0 col0" >0.942500</td>
#       <td id="T_6a800_row0_col1" class="data row0 col1" >0.762500</td>
#       <td id="T_6a800_row0_col2" class="data row0 col2" >0.564500</td>
#       <td id="T_6a800_row0_col3" class="data row0 col3" >0.420500</td>
#       <td id="T_6a800_row0_col4" class="data row0 col4" >0.301500</td>
#       <td id="T_6a800_row0_col5" class="data row0 col5" >0.155500</td>
#       <td id="T_6a800_row0_col6" class="data row0 col6" >0.091500</td>
#       <td id="T_6a800_row0_col7" class="data row0 col7" >0.020500</td>
#       <td id="T_6a800_row0_col8" class="data row0 col8" >0.000500</td>
#     </tr>
#     <tr>
#       <th id="T_6a800_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_6a800_row1_col0" class="data row1 col0" >0.950500</td>
#       <td id="T_6a800_row1_col1" class="data row1 col1" >0.752500</td>
#       <td id="T_6a800_row1_col2" class="data row1 col2" >0.542500</td>
#       <td id="T_6a800_row1_col3" class="data row1 col3" >0.391500</td>
#       <td id="T_6a800_row1_col4" class="data row1 col4" >0.288500</td>
#       <td id="T_6a800_row1_col5" class="data row1 col5" >0.149500</td>
#       <td id="T_6a800_row1_col6" class="data row1 col6" >0.078500</td>
#       <td id="T_6a800_row1_col7" class="data row1 col7" >0.010500</td>
#       <td id="T_6a800_row1_col8" class="data row1 col8" >-0.000500</td>
#     </tr>
#     <tr>
#       <th id="T_6a800_level0_row2" class="row_heading level0 row2" >mean</th>
#       <td id="T_6a800_row2_col0" class="data row2 col0" >0.946500</td>
#       <td id="T_6a800_row2_col1" class="data row2 col1" >0.757500</td>
#       <td id="T_6a800_row2_col2" class="data row2 col2" >0.553500</td>
#       <td id="T_6a800_row2_col3" class="data row2 col3" >0.406000</td>
#       <td id="T_6a800_row2_col4" class="data row2 col4" >0.295000</td>
#       <td id="T_6a800_row2_col5" class="data row2 col5" >0.152500</td>
#       <td id="T_6a800_row2_col6" class="data row2 col6" >0.085000</td>
#       <td id="T_6a800_row2_col7" class="data row2 col7" >0.015500</td>
#       <td id="T_6a800_row2_col8" class="data row2 col8" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
bca_unk_corr.loc['mean',:] = bca_unk_corr.mean()

# %%
bca_unk_corr.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_1e33f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e33f_level0_col0" class="col_heading level0 col0" >ctrl</th>
#       <th id="T_1e33f_level0_col1" class="col_heading level0 col1" >ko</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e33f_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_1e33f_row0_col0" class="data row0 col0" >0.199500</td>
#       <td id="T_1e33f_row0_col1" class="data row0 col1" >0.145500</td>
#     </tr>
#     <tr>
#       <th id="T_1e33f_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_1e33f_row1_col0" class="data row1 col0" >0.172500</td>
#       <td id="T_1e33f_row1_col1" class="data row1 col1" >0.127500</td>
#     </tr>
#     <tr>
#       <th id="T_1e33f_level0_row2" class="row_heading level0 row2" >mean</th>
#       <td id="T_1e33f_row2_col0" class="data row2 col0" >0.186000</td>
#       <td id="T_1e33f_row2_col1" class="data row2 col1" >0.136500</td>
#     </tr>
#   </tbody>
# </table>

# %%
list(bca_std_corr.columns)
# Out:
# [2.0, 1.5, 1.0, 0.75, 0.5, 0.25, 0.125, 0.025, 0]

# %%
bca_std_reg = stats.linregress(list(bca_std_corr.columns),
                               bca_std_corr.loc['mean',:]
                              )

# %% [markdown]
# <h2>Calculate the concentration of your unknowns</h2>

# %% [markdown]
# If you dig into the documentation for <code>stats.linregress()</code>, you'll find that it returns an object that contains various attributes. The ones that we're interested in for calculating the concentration of our unknown samples are the <code>slope</code> and the <code>intercept</code>. Recall from MCB201A, that we can then use these values to calculate our protein concentrations because we have the absorbance measurements of our unknown samples.
#
#
# We can use the equation for a line:
#
# ```
# y = mx + b
# ```
#
# Where <code>m</code> is the <code>slope</code>, and <code>b</code> is the <code>intercept</code>, and <code>y</code> is our unknown's mean corrected absorbance value.
#
# See if you can calculate the protein concentrations of your unknown and assign the resulting values to a new row in your unknown sample's DataFrame.

# %%
m = bca_std_reg.slope
b = bca_std_reg.intercept

# %%
y = (bca_unk_corr.loc['mean',:] - b)/m

# %%
y
# Out:
# ctrl    0.327197
# ko      0.224005
# Name: mean, dtype: float64

# %% [markdown]
# <h2>Plot protein standards, linear regression model, and unknowns</h2>

# %% [markdown]
# For your homework assignment, you plotted a scatterplot of your mean corrected absorbance values for your protein standards. Here, you'll make use of the <code>sns.regplot()</code> function to not only plot the protein standards but also the linear regression model derived from your standards. <a href="https://seaborn.pydata.org/generated/seaborn.regplot.html" rel="noopener noreferrer"><u>Documentation for <code>sns.regplot()</code> can be found here.</u></a>
#
# Then plot your unknown protein samples on top of your linear regression plot, and distinguish your unknowns using a different color.

# %%
sns.regplot(x=list(bca_std_corr.columns),
            y=bca_std_corr.loc['mean',:],
            ci=None,
            scatter_kws={'visible':False}
           )

sns.scatterplot(x=y,
                y=bca_unk_corr.loc['mean',:],
                color='r',
                s=36
               )
# Out:
# <Axes: xlabel='mean', ylabel='mean'>

# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Exercise #2 - Linear regression to evaluate correlation</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 975px;"></hr>

# %% [markdown]
# Let's now load in our class xenograft data again, and this time, we can run a linear regression analysis to determine if there is a correlation between tumor weight and tumor volume. We can run this analysis first for our control samples and then our TAZ KO samples and determine if there TAZ KO could change the strength of this correlation.
#
# First import the class xenograft data. We can use the same file that we used in 2-1.

# %%
tumor_data = pd.read_csv('./data/class_xenograft_data.csv')

# %% [markdown]
# As usual, let's do a quick sanity check.

# %%
tumor_data.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_0d40c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d40c_level0_col0" class="col_heading level0 col0" >control_engraftment</th>
#       <th id="T_0d40c_level0_col1" class="col_heading level0 col1" >control_weight</th>
#       <th id="T_0d40c_level0_col2" class="col_heading level0 col2" >control_volume</th>
#       <th id="T_0d40c_level0_col3" class="col_heading level0 col3" >tazko_engraftment</th>
#       <th id="T_0d40c_level0_col4" class="col_heading level0 col4" >tazko_weight</th>
#       <th id="T_0d40c_level0_col5" class="col_heading level0 col5" >tazko_volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d40c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0d40c_row0_col0" class="data row0 col0" >engraft</td>
#       <td id="T_0d40c_row0_col1" class="data row0 col1" >0.222500</td>
#       <td id="T_0d40c_row0_col2" class="data row0 col2" >1356.480000</td>
#       <td id="T_0d40c_row0_col3" class="data row0 col3" >engraft</td>
#       <td id="T_0d40c_row0_col4" class="data row0 col4" >0.023900</td>
#       <td id="T_0d40c_row0_col5" class="data row0 col5" >200.960000</td>
#     </tr>
#     <tr>
#       <th id="T_0d40c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0d40c_row1_col0" class="data row1 col0" >engraft</td>
#       <td id="T_0d40c_row1_col1" class="data row1 col1" >0.101600</td>
#       <td id="T_0d40c_row1_col2" class="data row1 col2" >502.400000</td>
#       <td id="T_0d40c_row1_col3" class="data row1 col3" >engraft</td>
#       <td id="T_0d40c_row1_col4" class="data row1 col4" >0.047600</td>
#       <td id="T_0d40c_row1_col5" class="data row1 col5" >439.600000</td>
#     </tr>
#     <tr>
#       <th id="T_0d40c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0d40c_row2_col0" class="data row2 col0" >engraft</td>
#       <td id="T_0d40c_row2_col1" class="data row2 col1" >0.288800</td>
#       <td id="T_0d40c_row2_col2" class="data row2 col2" >2411.520000</td>
#       <td id="T_0d40c_row2_col3" class="data row2 col3" >engraft</td>
#       <td id="T_0d40c_row2_col4" class="data row2 col4" >0.012200</td>
#       <td id="T_0d40c_row2_col5" class="data row2 col5" >109.900000</td>
#     </tr>
#     <tr>
#       <th id="T_0d40c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0d40c_row3_col0" class="data row3 col0" >engraft</td>
#       <td id="T_0d40c_row3_col1" class="data row3 col1" >0.077800</td>
#       <td id="T_0d40c_row3_col2" class="data row3 col2" >439.600000</td>
#       <td id="T_0d40c_row3_col3" class="data row3 col3" >engraft</td>
#       <td id="T_0d40c_row3_col4" class="data row3 col4" >0.075400</td>
#       <td id="T_0d40c_row3_col5" class="data row3 col5" >376.800000</td>
#     </tr>
#     <tr>
#       <th id="T_0d40c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0d40c_row4_col0" class="data row4 col0" >engraft</td>
#       <td id="T_0d40c_row4_col1" class="data row4 col1" >0.080200</td>
#       <td id="T_0d40c_row4_col2" class="data row4 col2" >602.880000</td>
#       <td id="T_0d40c_row4_col3" class="data row4 col3" >not_engraft</td>
#       <td id="T_0d40c_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_0d40c_row4_col5" class="data row4 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0d40c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0d40c_row5_col0" class="data row5 col0" >engraft</td>
#       <td id="T_0d40c_row5_col1" class="data row5 col1" >0.818000</td>
#       <td id="T_0d40c_row5_col2" class="data row5 col2" >401.920000</td>
#       <td id="T_0d40c_row5_col3" class="data row5 col3" >not_engraft</td>
#       <td id="T_0d40c_row5_col4" class="data row5 col4" >nan</td>
#       <td id="T_0d40c_row5_col5" class="data row5 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0d40c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0d40c_row6_col0" class="data row6 col0" >engraft</td>
#       <td id="T_0d40c_row6_col1" class="data row6 col1" >0.680000</td>
#       <td id="T_0d40c_row6_col2" class="data row6 col2" >133.973333</td>
#       <td id="T_0d40c_row6_col3" class="data row6 col3" >not_engraft</td>
#       <td id="T_0d40c_row6_col4" class="data row6 col4" >nan</td>
#       <td id="T_0d40c_row6_col5" class="data row6 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0d40c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0d40c_row7_col0" class="data row7 col0" >engraft</td>
#       <td id="T_0d40c_row7_col1" class="data row7 col1" >0.020900</td>
#       <td id="T_0d40c_row7_col2" class="data row7 col2" >263.760000</td>
#       <td id="T_0d40c_row7_col3" class="data row7 col3" >not_engraft</td>
#       <td id="T_0d40c_row7_col4" class="data row7 col4" >nan</td>
#       <td id="T_0d40c_row7_col5" class="data row7 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0d40c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0d40c_row8_col0" class="data row8 col0" >engraft</td>
#       <td id="T_0d40c_row8_col1" class="data row8 col1" >0.132300</td>
#       <td id="T_0d40c_row8_col2" class="data row8 col2" >1172.266667</td>
#       <td id="T_0d40c_row8_col3" class="data row8 col3" >not_engraft</td>
#       <td id="T_0d40c_row8_col4" class="data row8 col4" >nan</td>
#       <td id="T_0d40c_row8_col5" class="data row8 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0d40c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0d40c_row9_col0" class="data row9 col0" >engraft</td>
#       <td id="T_0d40c_row9_col1" class="data row9 col1" >0.129300</td>
#       <td id="T_0d40c_row9_col2" class="data row9 col2" >753.600000</td>
#       <td id="T_0d40c_row9_col3" class="data row9 col3" >not_engraft</td>
#       <td id="T_0d40c_row9_col4" class="data row9 col4" >nan</td>
#       <td id="T_0d40c_row9_col5" class="data row9 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0d40c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0d40c_row10_col0" class="data row10 col0" >engraft</td>
#       <td id="T_0d40c_row10_col1" class="data row10 col1" >0.365600</td>
#       <td id="T_0d40c_row10_col2" class="data row10 col2" >2461.760000</td>
#       <td id="T_0d40c_row10_col3" class="data row10 col3" >not_engraft</td>
#       <td id="T_0d40c_row10_col4" class="data row10 col4" >nan</td>
#       <td id="T_0d40c_row10_col5" class="data row10 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0d40c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0d40c_row11_col0" class="data row11 col0" >engraft</td>
#       <td id="T_0d40c_row11_col1" class="data row11 col1" >0.079100</td>
#       <td id="T_0d40c_row11_col2" class="data row11 col2" >598.693333</td>
#       <td id="T_0d40c_row11_col3" class="data row11 col3" >not_engraft</td>
#       <td id="T_0d40c_row11_col4" class="data row11 col4" >nan</td>
#       <td id="T_0d40c_row11_col5" class="data row11 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0d40c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0d40c_row12_col0" class="data row12 col0" >engraft</td>
#       <td id="T_0d40c_row12_col1" class="data row12 col1" >0.078200</td>
#       <td id="T_0d40c_row12_col2" class="data row12 col2" >628.000000</td>
#       <td id="T_0d40c_row12_col3" class="data row12 col3" >not_engraft</td>
#       <td id="T_0d40c_row12_col4" class="data row12 col4" >nan</td>
#       <td id="T_0d40c_row12_col5" class="data row12 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0d40c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0d40c_row13_col0" class="data row13 col0" >engraft</td>
#       <td id="T_0d40c_row13_col1" class="data row13 col1" >0.072600</td>
#       <td id="T_0d40c_row13_col2" class="data row13 col2" >535.893333</td>
#       <td id="T_0d40c_row13_col3" class="data row13 col3" >not_engraft</td>
#       <td id="T_0d40c_row13_col4" class="data row13 col4" >nan</td>
#       <td id="T_0d40c_row13_col5" class="data row13 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0d4

# %% [markdown]
# We can just quickly re-update our DataFrame to convert grams to milligrams for our tumor weights.
#
# For those of you who want a slight challenge, see if you can do this in a single line to convert all the weight values from grams to milligrams. This will make use of <code>pd.Series.str.contains()</code> to generate a boolean output, which you can then use with <code>.loc[]</code> to pull just the rows related to weight. You can then make use of multiplicative assignment to update these values in the original DataFrame.
#
# <a href="https://pandas.pydata.org/docs/reference/api/pandas.Series.str.contains.html" rel="noopener noreferrer"><u>Documentation for <code>pd.Series.str.contains()</code> can be found here.</u></a>

# %%
for col in tumor_data.columns:
    if 'weight' in col:
        tumor_data[col] = pd.to_numeric(tumor_data[col], errors='coerce')*1000

# %%
tumor_data.loc[:, tumor_data.columns.str.contains('weight')] *= 1000

# %%
tumor_data
# Out:
#    control_engraftment  control_weight  control_volume tazko_engraftment  \
# 0              engraft           222.5     1356.480000           engraft
# 1              engraft           101.6      502.400000           engraft
# 2              engraft           288.8     2411.520000           engraft
# 3              engraft            77.8      439.600000           engraft
# 4              engraft            80.2      602.880000       not_engraft
# 5              engraft           818.0      401.920000       not_engraft
# 6              engraft           680.0      133.973333       not_engraft
# 7              engraft            20.9      263.760000       not_engraft
# 8              engraft           132.3     1172.266667       not_engraft
# 9              engraft           129.3      753.600000       not_engraft
# 10             engraft           365.6     2461.760000       not_engraft
# 11             engraft            79.1      598.693333       not_engraft
# 12             engraft            78.2      628.000000       not_engraft
# 13             engraft            72.6      535.893333       not_engraft
# 14             engraft           280.4     1130.400000       not_engraft
# 15             engraft            55.5      234.453333       not_engraft
# 16             engraft            37.1      150.720000       not_engraft
# 17             engraft            17.9       83.733333       not_engraft
# 18         not_engraft             NaN             NaN               NaN
#
#     tazko_weight  tazko_volume
# 0           23.9        200.96
# 1           47.6        439.60
# 2           12.2        109.90
# 3           75.4        376.80
# 4            NaN           NaN
# 5            NaN           NaN
# 6            NaN           NaN
# 7            NaN           NaN
# 8            NaN           NaN
# 9            NaN           NaN
# 10           NaN           NaN
# 11           NaN           NaN
# 12           NaN           NaN
# 13           NaN           NaN
# 14           NaN           NaN
# 15           NaN           NaN
# 16           NaN           NaN
# 17           NaN           NaN
# 18           NaN           NaN

# %% [markdown]
# <h2>Determine if there is a correlation between control tumor weights and volumes</h2>

# %% [markdown]
# Let's now make use of <code>stats.linregress()</code> to evaluate the strength of the relationship between tumor weights and volumes for our control samples first. Recall that <code>stats.linregress()</code> generates an object containing multiple attributes. We pulled out the <code>slope</code> and the <code>intercept</code> in exercise #1, and for this exercise, we'll pull out the <code>rvalue</code>, which is the Pearson correlation coefficient which we can then use to calculate the R&sup2; value.

# %%
correlation_results = stats.linregress(tumor_data['control_volume'].dropna(),
                                       tumor_data['control_weight'].dropna()
                                      )
ctrl_rvalue = correlation_results.rvalue

ctrl_rvalue = ctrl_rvalue**2

ctrl_rvalue
# Out:
# np.float64(0.02881124245280505)

# %%
ko_correlation_results = stats.linregress(tumor_data['tazko_volume'],
                                          tumor_data['tazko_weight'],
                                          nan_policy='omit'
                                         )
(ko_correlation_results.rvalue)**2
# Out:
# np.float64(0.6905670150616773)

# %% [markdown]
# Let's take a look at the regression model too using <code>sns.regplot()</code>.

# %%
sns.regplot(x=tumor_data['control_volume'].dropna(),
            y=tumor_data['control_weight'].dropna(),
            ci=None,
            scatter_kws={'visible':True}
           )
# Out:
# <Axes: xlabel='control_volume', ylabel='control_weight'>

# %%
sns.regplot(data=tumor_data,
            x='tazko_volume',
            y='tazko_weight',
            ci=None,
            scatter_kws={'visible':True}
           )
# Out:
# <Axes: xlabel='tazko_volume', ylabel='tazko_weight'>

# %% [markdown]
# <h2>Determine if there is a correlation between TAZ KO tumor weights and volumes</h2>

# %% [markdown]
# Let's do the same for our TAZ KO tumors.

# %% [markdown]
# At a preliminary glance, what does our data tell us about whether or not TAZ KO influences this correlation?

# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Additional operating system functionalities</h1>
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 800px;"></hr>

# %% [markdown]
# <h2>Make directories</h2>

# %% [markdown]
# Recall from earlier notebooks, where we made use of the <code>os</code> module to change directories, get our current working directory, and load in multiple files into our notebook for analysis. We can also perform additional operating system functions including making new directories. This can be helpful when you want to keep your outputs organized and have set directories created to hold different outputs, so you don't need to create them each time you run an analysis.
#
# Here, we can use the <code>os.mkdir()</code> function to make a new directory. <a href="https://docs.python.org/3/library/os.html#os.mkdir" rel="noopener noreferrer"><u>Documentation for <code>os.mkdir()</code> can be found here.</u></a>
#
# This function will make a new directory according to the file path specified as long as the parent directories exist. For our purposes, we can test out making a new directory in our current working directory, so all we need to specify is the name of the directory.
#
# Let's first see where our notebook's current working directory is.

# %%
os.getcwd()
# Out:
# '/home/jovyan/MCB201B_F2025/Week_2'

# %% [markdown]
# Now let's make a new directory called <code>mcb201b_modules</code>. We will use this directory in a subsequent section of this notebook.
#
# You can specify the name of the directory as a string when using the <code>os.mkdir()</code> function.

# %%
os.mkdir('mcb201b_modules')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 os.mkdir('mcb201b_modules')
#
# FileExistsError: [Errno 17] File exists: 'mcb201b_modules'

# %% [markdown]
# Now try re-running that code cell again and see what happens. You can see that if the directory already exists, you'll get a <code style="background-color: #FFDDDD; color: #FF0000;">FileExistsError</code>. To get around this, we can make use of the <code>try</code> keyword and provide it with a way to handle the error by using the <code>except</code> and <code>pass</code> keyword.

# %%
try: 
    os.mkdir('mcb201b_modules')
except FileExistsError:
    pass

print('hi')
# Out:
# hi

# %% [markdown]
# <h2>Setting up a base name</h2>

# %% [markdown]
# While not necessarily a specific operating system function, it can be helpful when you want to analyze multiple files to be able to set up a base name that will be shared between all the outputs that are generated when you analyze a data file. For today's class, we'll be analyzing a dataset that was generated from hypothetical testing of different small molecules. Since it's a number of different data files, it can be helpful to distinguish the analysis outputs from one another.
#
# What we can do is to be consistent in how we format our file names, so we can readily use it to create a base name for that respective file's outputs.
#
# Let's use what we know so far to pull in file names from a small molecule screen under the file path <code>./data/small_mol_mtt_data</code>.

# %%
file_names = os.listdir('./data/small_mol_mtt_data')

file_names.sort()

# %% [markdown]
# Let's pull in just our .csv file names.

# %%
final_file_names = []

for name in file_names:
    if '.csv' in name:
        final_file_names.append(name)

print(final_file_names)
# Out:
# ['CHEMBL1180725_MTT.csv', 'CHEMBL1618660_MTT.csv', 'CHEMBL2022903_MTT.csv', 'CHEMBL2153191_MTT.csv', 'CHEMBL3402520_MTT.csv', 'CHEMBL3740500_MTT.csv', 'CHEMBL386630_MTT.csv', 'CHEMBL4297215_MTT.csv', 'CHEMBL4633566_MTT.csv', 'CHEMBL4794972_MTT.csv', 'CHEMBL514201_MTT.csv', 'CHEMBL530345_MTT.csv']

# %% [markdown]
# Recall that the file names are strings, so we can take advantage of The way strings are handled in Python to allow us to generate a base name that adapts to each file. Each letter of a string functions like an element of a list, so we can pull just the information we want from a file name.
#
# Let's use just the first file name as an example.

# %%
print(final_file_names[1])

print(final_file_names[1].replace('_MTT.csv', ''))
# Out:
# CHEMBL1618660_MTT.csv
# CHEMBL1618660

# %%
new_list = []
for name in final_file_names:
    new_list.append(name.replace('_MTT.csv', ''))


print(new_list)

new_list[0] + '_summary_log.txt'
# Out:
# ['CHEMBL1180725', 'CHEMBL1618660', 'CHEMBL2022903', 'CHEMBL2153191', 'CHEMBL3402520', 'CHEMBL3740500', 'CHEMBL386630', 'CHEMBL4297215', 'CHEMBL4633566', 'CHEMBL4794972', 'CHEMBL514201', 'CHEMBL530345']
# 'CHEMBL1180725_summary_log.txt'

# %%
for name in final_file_names:
    base_name = name.replace('_MTT.csv', '')
    print(base_name)
    print(base_name + '_summary_log.txt')

# print(new_list)

# new_list[0] + '_summary_log.txt'
# Out:
# CHEMBL1180725
# CHEMBL1180725_summary_log.txt
# CHEMBL1618660
# CHEMBL1618660_summary_log.txt
# CHEMBL2022903
# CHEMBL2022903_summary_log.txt
# CHEMBL2153191
# CHEMBL2153191_summary_log.txt
# CHEMBL3402520
# CHEMBL3402520_summary_log.txt
# CHEMBL3740500
# CHEMBL3740500_summary_log.txt
# CHEMBL386630
# CHEMBL386630_summary_log.txt
# CHEMBL4297215
# CHEMBL4297215_summary_log.txt
# CHEMBL4633566
# CHEMBL4633566_summary_log.txt
# CHEMBL4794972
# CHEMBL4794972_summary_log.txt
# CHEMBL514201
# CHEMBL514201_summary_log.txt
# CHEMBL530345
# CHEMBL530345_summary_log.txt

# %% [markdown]
# What can we do if we just wanted to pull out the small molecule identifier from our file name?

# %% [markdown]
# Let's see if that will work for all our file names.

# %% [markdown]
# Now all we need to do if we want to use this base name for naming our output files is to combine it with an appropriate suffix.

# %% [markdown]
# <h2>Writing output summary logs</h2>

# %% [markdown]
# Something that you may want to do while analyzing multiple data files is to also have Python output a log or summary of the analysis results, so you can refer back to that summary log to understand what was going on during the analysis and what the outputs were. To have Python write to a file, you can make use of the <code>with</code> keyword and the built-in <code>open()</code> function to open a file up (or create a new one if it doesn't exist). <a href="https://docs.python.org/3/library/functions.html#open" rel="noopener noreferrer"><u>Documentation for <code>open()</code> can be found here.</u></a>
#
# Digging into the documentation for <code>open()</code>, you can see that there are different modes under which the <code>open()</code> function can operate. Two common modes are <code>'w'</code>, which is to write from the beginning of the file (and overwriting any previous information), and <code>'a'</code> which appends onto the file's existing information.
#
# The <code>with</code> keyword serves to automatically close out the file that you open/create with the <code>open()</code> function, so you don't have to separately remember to close the file. We will then use the <code>as</code> keyword to set a variable name to our open file.
#
# With the file open, you can then make use of your file's variable name and the <code>write()</code> method to write into that file.
#
# We can give that a try here to output a plain text .txt file in this week's <code>output</code> directory.

# %%
with open('./outputs/liebchen.txt', 'w') as liebchen_file:
    liebchen_file.write('')

# %% [markdown]
# Let's then see what happens if we use the append mode <code>'a'</code> instead of the write mode <code>'w'</code>.

# %%
with open('./outputs/liebchen.txt', 'a') as liebchen_file:
    liebchen_file.write('\nMEOW! MEOW!')

# %% [markdown]
# What happens if you re-run the cell multiple times? Compare that to when we were in the write mode.

# %% [markdown]
# Now what could we do if we wanted to have line breaks?

# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Creating a basic module</h1>
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 800px;"></hr>

# %% [markdown]
# Recall from our data visualization notebooks that we set up a nice function for putting together a publication quality figure that includes descriptive statistics overlaid on it as well as annotations to indicate the results of our statistical analysis. Since it would be inconvenient to have to recopy that block of code into each file that we want to run it, we can set up our own basic module that defines this function. Recall that our Python packages like <code>numpy</code> and <code>pandas</code> contain within them a bunch of functions that have been defined and can be imported into our notebooks or Python files to allow those blocks of code to be readily used.
#
# We can similarly set up our own module for our annotated swarmplot. I've copied below our swarmplot code, and all we'll need to do is to make some minor adjustments to give it additional flexibility and allow it to use other packages. Then we can set up our module as its own .py Python file.

# %%
#Import needed packages for our module
import numpy 
import pandas
import matplotlib.pyplot
import seaborn
import os

#Define our function for our module
def swarmplot_annotation(dataset, col_list, conclusion, y_axislabel, file_name):
    
    fig, ax = matplotlib.pyplot.subplots()
    dot_colors = ['#777777', '#E64B35']
    
    seaborn.swarmplot(data=dataset[col_list],
                  s=6,
                  palette=dot_colors,
                  zorder=0
                 )
    
    seaborn.barplot(data=dataset[col_list],
                estimator=numpy.mean,
                alpha=0,
                errorbar='se',
                capsize=0.3,
                err_kws={'linewidth': 1,
                         'color': 'k'}
               )
    
    seaborn.boxplot(data=dataset[col_list],
                showmeans=True,
                meanline=True,
                width=0.5,
                meanprops={'linewidth': 1,
                           'color': 'k',
                           'linestyle': '-'
                          },
                medianprops={'visible': False},
                whiskerprops={'visible': False},
                showfliers=False,
                showbox=False,
                showcaps=False
               )
    
    #####################################
    x1, x2 = 0, 1
    y_max = numpy.max(dataset[col_list].max())
    adjustment = y_max*1.1
    h = y_max*0.05
    
    matplotlib.pyplot.plot([x1, x1, x2, x2], [adjustment, adjustment + h, adjustment + h, adjustment], color='k')
    #####################################
    
    #####################################
    if conclusion.pvalue < 0.0005:
        pvalue_star = '***'
    elif conclusion.pvalue < 0.005:
        pvalue_star = '**'
    elif conclusion.pvalue < 0.05:
        pvalue_star = '*'
    else:
        pvalue_star = 'ns'
    
    matplotlib.pyplot.text((x1+x2)/2 , adjustment+(h*1.25), pvalue_star, ha='center', va='bottom', color='k', size=12)
    #####################################
    
    ax.set_ylabel(y_axislabel,
                  size=14
                 )
    
    ax.set_xticks([0,1],
                  col_list,  #Make a little bit more generalizable
                  rotation=35,
                  ha='right',
                  size=12
                 )
    matplotlib.pyplot.yticks(size=12)
    
    fig.set_size_inches(3, 4)
    fig.set_dpi(300)
    
    seaborn.despine()
    matplotlib.pyplot.show()

    #Let's make a directory for our plot
    try:
        os.mkdir('plots')
    except FileExistError:
        pass

    #We'll save our plot to our 'plots' directory
    fig.savefig(f'./plots/{file_name}.pdf', bbox_inches='tight')

    return None

# %% [markdown]
# The function as it is now isn't too useful for us to import, so we'll need to set up it's own .py Python file.
#
# To set up for this, navigate into <code>mcb201b_modules</code> using your left-hand File Browser. Then open up a new Launcher. Recall that Python packages are indicated by a <code>&lowbar;&lowbar;init&lowbar;&lowbar;.py</code> file. Within <code>mcb201b_modules</code> create a new Python file using the Launcher. By default, the newly created .py file will be <code>Untitled.py</code>. Go ahead and save the empty .py file, and you'll be prompted to rename it. Rename the file to <code>&lowbar;&lowbar;init&lowbar;&lowbar;.py</code> (the "init" is flanked by two underscores).
#
# Now the Python interpreter will know that our <code>mcb201b_modules</code> directory is a package that can be imported. Now create another new Python file. This one will be our basic module containing our <code>swarmplot_annotation()</code> function.
#
# In this new file, copy over our updated definition including the <code>import</code> operations to make sure that dependencies are included. Save the .py file as <code>mcb201b_swarmplot_annotated.py</code>.

# %% [markdown]
# <h2>Import our basic module</h2>

# %% [markdown]
# Let's see if we're able to import our module. First we'll want to make sure that we're back into our <code>Week_2</code> directory.

# %%
os.getcwd()
# Out:
# '/home/jovyan/MCB201B_F2025/Week_2'

# %% [markdown]
# Then we can import our module with the <code>import</code> function, and we can import it as <code>mcb201b</code>.

# %%
import mcb201b_modules.mcb201b_swarmplot_annotated as mcb201b

# %% [markdown]
# We can do a quick check by calling up <code>mcb201b</code> object to see if it is recognized as a module with the correct file path.

# %%
mcb201b
# Out:
# <module 'mcb201b_modules.mcb201b_swarmplot_annotated' from '/home/jovyan/MCB201B_F2025/Week_2/mcb201b_modules/mcb201b_swarmplot_annotated.py'>

# %% [markdown]
# We can then check to see if our function is defined.

# %%
mcb201b.swarmplot_annotation
# Out:
# <function mcb201b_modules.mcb201b_swarmplot_annotated.swarmplot_annotation(dataset, col_list, conclusion, y_axislabel, file_name)>

# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Setting up a Python script</h1>
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 800px;"></hr>

# %% [markdown]
# With our module looking like it's ready to go, we can start putting together a basic Python script. We'll make use of everything we've learned so far from MCB201A's Exp 16 to today to set up this script and run an analysis of a dataset from a small molecule test.
#
# To get ourselves started, let's use the File Browser and navigate back to our <code>Week_2</code> directory. Then let's use the Launcher to start up a new .py file. We can name the Python file <code>small_mol_mtt_script.py</code>, and we will shift over to working in that Python file as we set up our script. While working in our <code>small_mol_mtt_script.py</code> file, we will open up a console editor allowing us to test our code much in the same way you can do in RStudio for those of you who have more familiarity with R and RStudio.
#
# We might also sometimes jump back into our notebooks to find some code that we can use in our script.

# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Running your Python script</h1>
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 800px;"></hr>

# %% [markdown]
# With our script set up, we can simply go into Terminal, confirm that we're in our <code>Week_2</code> directory, and run our Python script through Terminal by invoking the Python interpreter and executing our <code>small_mol_mtt_script.py</code> file.
#
# <pre style="width: 350px; margin-top: 15px; margin-bottom: 15px; color: #000000; background-color: #EEEEEE; border: 1px solid; border-color: #AAAAAA; padding: 10px; border-radius: 15px; font-size: 12px;">python small_mol_mtt_script.py</pre>
#
# And if all goes well, you should be able to run the analysis on all the small molecule data files.
