# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Week 12 Assignment</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# <strong><u>Due: Saturday, November 22nd at 11:59PM</u></strong>
#
# <strong><u>Total points: 5 pts</u></strong>
#
# <strong><u>To turn in your assignment:</u></strong>
# <ol>
#     <li>Complete assignment and make sure you have all the outputs requested for the notebook</li>
#     <li>Go to your server's file directory and locate the <code>week_12_homework</code> directory containing this notebook</li>
#     <li>Right click and select <strong>Download as an Archive</strong> to download the <code>week_12_homework</code> directory as a ZIP folder. Do not mix up with <strong>Download Current Folder as an Archive</strong></li>
#     <li>Upload your ZIP folder to your individual feedback Google Drive folder under <code>MCB201B</code></li>
# </ol>
#
# <strong><u>How this assignment will be graded:</u></strong>
#
# You will be graded on whether or not you have <u>all requested outputs in this notebook</u> and if your output is correct. You will also be graded on if your code is expected to be able to run without errors. There can be more than one correct way to answer a question. If you find that you prefer to separate your answer for a single question into multiple code cells, feel free to do so.
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %%
library(DESeq2)
library(ggplot2)
BiocManager::install("mixOmics")
BiocManager::install("hexbin")
BiocManager::install("vsn")

# %% [markdown]
# <h1>Question 1</h1>

# %% [markdown]
# 1pt

# %% [markdown]
# Generate a class dataset using all group's replicate counts data (from their full files), which can be found in the shared directory under <code>~/shared/2025-fall/courses/1547808/rna-seq/full-counts</code> then import your full class counts matrix into this R notebook along with a conditions matrix. Filter out non-expressed genes and create a <code>DESeqDataSet</code> using the full counts matrix and conditions matrix.

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# <h1>Question 2</h1>

# %% [markdown]
# 1pt

# %% [markdown]
# In the code cell below, pull out the size factors for each sample and output it into this notebook.

# %% [markdown]
# In the code cell below, pull out the first five rows of your normalized counts from your <code>DESeqDataSet</code>, and output it into this notebook.

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# <h1>Question 3</h1>

# %% [markdown]
# 1pt

# %% [markdown]
# Perform a regularized log transformation on your <code>DESeqDataSet</code>, and plot the ranks of means along the x-axis and the standard deviation along the y-axis for each gene using hexagonal bins.

# %% [markdown]
# Identify the top 5 genes with the greatest variance and output them into this notebook.

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# <h1>Question 4</h1>

# %% [markdown]
# 1pt

# %% [markdown]
# Use the top <u>500</u> genes to perform a principal component analysis for our class's full dataset. Output into this notebook the proportion of explained variance for ten principal components.

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>

# %% [markdown]
# <h1>Question 5</h1>

# %% [markdown]
# 1pt

# %% [markdown]
# Plot a biplot for the first two principal components from your principal component analysis in question 4. Label each dot with the sample's condition and group number.

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 98%;"></hr>
